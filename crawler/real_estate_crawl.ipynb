# %%
import requests
import pandas as pd
import time
import datetime
import random
import sys, os
this_path = '/home/ibi/Documents/GitHub/mas291-project/'
sys.path.append(this_path)
os.chdir(this_path)
print(os.getcwd())
# Out:
# /home/ibi/Documents/GitHub/mas291-project

# %%
def dynamic_delay(minimum=1.0, maximum=3.0):
    return random.uniform(minimum, maximum)

def exponential_backoff_retry(request_func, max_retries=6):
    base_wait = 2
    for attempt in range(max_retries):
        try:
            response = request_func()
            if response.ok:
                time.sleep(dynamic_delay(1, 2))
                return response
        except Exception as e:
            print(f"Request failed with exception {e}. Attempt {attempt + 1}/{max_retries}.")
        
        time.sleep(base_wait * (2 ** attempt) + dynamic_delay())

    return None

# %%
def scrape_properties(city_slug, city_name, status=["for_sale", "ready_to_build"]):
    url = 'https://www.realtor.com/api/v1/rdc_search_srp?client_id=rdc-search-for-sale-search&schema=vesta'
    headers = {"content-type": "application/json"}
    limit = 200
    all_properties = []
    total_checked = 0
    earliest_date = datetime.datetime.strptime('1995-01-01', "%Y-%m-%d")
    current_date = datetime.datetime.now()

    def send_request(body):
        return requests.post(url, headers=headers, json=body)

    if "sold" in status:
        while current_date > earliest_date:
            start_date = current_date - datetime.timedelta(days=365)
            last_total = None

            while True:
                query = {
                    "sold_date": {"min": start_date.strftime("%Y-%m-%d"), "max": current_date.strftime("%Y-%m-%d")},
                    "status": status,
                    "search_location": {"location": city_name},
                    "type": ["single_family"]
                }

                graphql_query = """
                    query ConsumerSearchQuery(
                        $query: HomeSearchCriteria!
                        $limit: Int
                        $offset: Int
                        $search_promotion: SearchPromotionInput
                        $sort: [SearchAPISort]
                        $sort_type: SearchSortType
                        $client_data: JSON
                        $bucket: SearchAPIBucket
                        ) {
                        home_search: home_search(
                            query: $query
                            sort: $sort
                            limit: $limit
                            offset: $offset
                            sort_type: $sort_type
                            client_data: $client_data
                            bucket: $bucket
                            search_promotion: $search_promotion
                        ) {
                            count
                            total
                            search_promotion {
                            names
                            slots
                            promoted_properties {
                                id
                                from_other_page
                            }
                            }
                            mortgage_params {
                            interest_rate
                            }
                            properties: results {
                            property_id
                            list_price
                            search_promotions {
                                name
                                asset_id
                            }
                            primary_photo(https: true) {
                                href
                            }
                            rent_to_own {
                                right_to_purchase
                                rent
                            }
                            listing_id
                            matterport
                            virtual_tours {
                                href
                                type
                            }
                            status
                            products {
                                products
                                brand_name
                            }
                            source {
                                id
                                type
                                spec_id
                                plan_id
                                agents {
                                office_name
                                }
                            }
                            lead_attributes {
                                show_contact_an_agent
                                opcity_lead_attributes {
                                cashback_enabled
                                flip_the_market_enabled
                                }
                                lead_type
                                ready_connect_mortgage {
                                show_contact_a_lender
                                show_veterans_united
                                }
                            }
                            community {
                                description {
                                name
                                }
                                property_id
                                permalink
                                advertisers {
                                office {
                                    hours
                                    phones {
                                    type
                                    number
                                    primary
                                    trackable
                                    }
                                }
                                }
                                promotions {
                                description
                                href
                                headline
                                }
                            }
                            permalink
                            price_reduced_amount
                            description {
                                name
                                beds
                                baths_consolidated
                                sqft
                                lot_sqft
                                baths_max
                                baths_min
                                beds_min
                                beds_max
                                sqft_min
                                sqft_max
                                type
                                sub_type
                                sold_price
                                sold_date
                            }
                            location {
                                street_view_url
                                address {
                                line
                                postal_code
                                state
                                state_code
                                city
                                coordinate {
                                    lat
                                    lon
                                }
                                }
                                county {
                                name
                                fips_code
                                }
                            }
                            open_houses {
                                start_date
                                end_date
                            }
                            branding {
                                type
                                name
                                photo
                            }
                            flags {
                                is_coming_soon
                                is_new_listing(days: 14)
                                is_price_reduced(days: 30)
                                is_foreclosure
                                is_new_construction
                                is_pending
                                is_contingent
                            }
                            list_date
                            photos(limit: 2, https: true) {
                                href
                            }
                            advertisers {
                                type
                                builder {
                                name
                                href
                                logo
                                }
                            }
                            }
                        }
                        commute_polygon: get_commute_polygon(query: $query) {
                            areas {
                            id
                            breakpoints {
                                width
                                height
                                zoom
                            }
                            radius
                            center {
                                lat
                                lng
                            }
                            }
                            boundary
                        }
                        }
                """

                body = {
                    "query": graphql_query,
                    "variables": {
                        "geoSupportedSlug": city_slug,
                        "query": query,
                        "client_data": {"device_data": {"device_type": "desktop"}},
                        "limit": limit,
                        "offset": 0,
                        "sort": [{"field": "sold_date", "direction": "desc"}],
                        "search_promotion": {"names": ["CITY"], "slots": [], "promoted_properties": []}
                    },
                    "isClient": True,
                    "visitor_id": "7ffa9c49-550f-4c23-aa1b-e93786671450"
                }

                response = exponential_backoff_retry(lambda: send_request(body))
                if response is None or 'data' not in response.json() or 'home_search' not in response.json()['data'] or response.json()['data']['home_search'] is None:
                    print("Error: Invalid response structure or missing data.")
                    print(response.json() if response else "No response")
                    break

                data = response.json()
                api_total = data['data']['home_search']['total']
                print(f"Total properties in {city_name} sold between {start_date.strftime('%Y-%m-%d')} and {current_date.strftime('%Y-%m-%d')}: {api_total}")

                if api_total > 10000:
                    start_date += datetime.timedelta(days=30)
                    time.sleep(dynamic_delay(5, 10))
                else:
                    if last_total is None or api_total > last_total:
                        last_total = api_total
                        start_date -= datetime.timedelta(days=1)
                        time.sleep(dynamic_delay(5, 10))
                    else:
                        break
                    
            offset = 0
            while offset < api_total:
                body['variables']['offset'] = offset
                response = exponential_backoff_retry(lambda: send_request(body))
                if response is None:
                    print("Failed to fetch data after retries.")
                    break
                data = response.json()
                current_batch = data['data']['home_search']['properties']
                all_properties.extend(current_batch)
                total_checked += len(current_batch)
                print(f"Fetched {len(current_batch)} properties this batch. Total checked: {total_checked}.")
                offset += limit
                time.sleep(dynamic_delay(2, 3))

            current_date = start_date - datetime.timedelta(days=1)
            time.sleep(dynamic_delay(5, 10))

    else:
        offset = 0
        api_total = None
        first_batch = True

        query = {
            "status": status,
            "search_location": {
                "location": city_name
            },
            "type": ["single_family"]
        }

        graphql_query = """
            query ConsumerSearchQuery(
                $query: HomeSearchCriteria!
                $limit: Int
                $offset: Int
                $search_promotion: SearchPromotionInput
                $sort: [SearchAPISort]
                $sort_type: SearchSortType
                $client_data: JSON
                $bucket: SearchAPIBucket
                ) {
                home_search: home_search(
                    query: $query
                    sort: $sort
                    limit: $limit
                    offset: $offset
                    sort_type: $sort_type
                    client_data: $client_data
                    bucket: $bucket
                    search_promotion: $search_promotion
                ) {
                    count
                    total
                    search_promotion {
                    names
                    slots
                    promoted_properties {
                        id
                        from_other_page
                    }
                    }
                    mortgage_params {
                    interest_rate
                    }
                    properties: results {
                    property_id
                    list_price
                    search_promotions {
                        name
                        asset_id
                    }
                    primary_photo(https: true) {
                        href
                    }
                    rent_to_own {
                        right_to_purchase
                        rent
                    }
                    listing_id
                    matterport
                    virtual_tours {
                        href
                        type
                    }
                    status
                    products {
                        products
                        brand_name
                    }
                    source {
                        id
                        type
                        spec_id
                        plan_id
                        agents {
                        office_name
                        }
                    }
                    lead_attributes {
                        show_contact_an_agent
                        opcity_lead_attributes {
                        cashback_enabled
                        flip_the_market_enabled
                        }
                        lead_type
                        ready_connect_mortgage {
                        show_contact_a_lender
                        show_veterans_united
                        }
                    }
                    community {
                        description {
                        name
                        }
                        property_id
                        permalink
                        advertisers {
                        office {
                            hours
                            phones {
                            type
                            number
                            primary
                            trackable
                            }
                        }
                        }
                        promotions {
                        description
                        href
                        headline
                        }
                    }
                    permalink
                    price_reduced_amount
                    description {
                        name
                        beds
                        baths_consolidated
                        sqft
                        lot_sqft
                        baths_max
                        baths_min
                        beds_min
                        beds_max
                        sqft_min
                        sqft_max
                        type
                        sub_type
                        sold_price
                        sold_date
                    }
                    location {
                        street_view_url
                        address {
                        line
                        postal_code
                        state
                        state_code
                        city
                        coordinate {
                            lat
                            lon
                        }
                        }
                        county {
                        name
                        fips_code
                        }
                    }
                    open_houses {
                        start_date
                        end_date
                    }
                    branding {
                        type
                        name
                        photo
                    }
                    flags {
                        is_coming_soon
                        is_new_listing(days: 14)
                        is_price_reduced(days: 30)
                        is_foreclosure
                        is_new_construction
                        is_pending
                        is_contingent
                    }
                    list_date
                    photos(limit: 2, https: true) {
                        href
                    }
                    advertisers {
                        type
                        builder {
                        name
                        href
                        logo
                        }
                    }
                    }
                }
                commute_polygon: get_commute_polygon(query: $query) {
                    areas {
                    id
                    breakpoints {
                        width
                        height
                        zoom
                    }
                    radius
                    center {
                        lat
                        lng
                    }
                    }
                    boundary
                }
                }
        """

        while api_total is None or offset < api_total:
            body = {
                "query": graphql_query,
                "variables": {
                    "geoSupportedSlug": city_slug,
                    "query": query,
                    "client_data": {"device_data": {"device_type": "desktop"}},
                    "limit": limit,
                    "offset": offset,
                    "sort_type": "relevant",
                    "search_promotion": {"names": ["CITY"], "slots": [], "promoted_properties": []}
                },
                "isClient": True,
                "visitor_id": "7ffa9c49-550f-4c23-aa1b-e93786671450"
            }

            response = exponential_backoff_retry(lambda: send_request(body))
            if response is None:
                print("Failed to fetch data after retries.")
                break

            data = response.json()

            if api_total is None:
                api_total = data['data']['home_search']['total']
                if first_batch:
                    print(f"Total properties available for sale in {city_name}: {api_total}")
                    first_batch = False
                    
            properties = data['data']['home_search']['properties']
            all_properties.extend(properties)
            total_checked += len(properties)
            print(f"Fetched {len(properties)} selling properties currently. Total available: {api_total}. Total checked: {total_checked}.")
            offset += limit
            time.sleep(dynamic_delay(2, 3))

    return {
        "total_properties_checked": total_checked,
        "properties": all_properties
    }

chicago_data = scrape_properties("Chicago_IL", "Chicago, IL")
print(f"Done fetching {chicago_data['total_properties_checked']} properties selling in Chicago.")
time.sleep(dynamic_delay(50, 60))

chicago_data_sold = scrape_properties("Chicago_IL", "Chicago, IL", ["sold"])
print(f"Done fetching {chicago_data_sold['total_properties_checked']} sold properties in Chicago.")
time.sleep(dynamic_delay(300, 600))

new_york_data = scrape_properties("New-York_NY", "New York, NY")
print(f"Done fetching {new_york_data['total_properties_checked']} properties selling in New York.")
time.sleep(dynamic_delay(50, 60))

new_york_data_sold = scrape_properties("New-York_NY", "New York, NY", ["sold"])
print(f"Done fetching {new_york_data_sold['total_properties_checked']} sold properties in New York.")
# Out:
# Total properties available for sale in Chicago, IL: 3092
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 200.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 400.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 600.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 800.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 1000.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 1200.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 1400.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 1600.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 1800.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 2000.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 2200.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 2400.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 2600.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 2800.
# Fetched 200 selling properties currently. Total available: 3092. Total checked: 3000.
# Fetched 92 selling properties currently. Total available: 3092. Total checked: 3092.
# Done fetching 3092 properties selling in Chicago.
# Total properties in Chicago, IL sold between 2023-07-07 and 2024-07-06: 8085
# Total properties in Chicago, IL sold between 2023-07-06 and 2024-07-06: 8119
# Total properties in Chicago, IL sold between 2023-07-05 and 2024-07-06: 8140
# Total properties in Chicago, IL sold between 2023-07-04 and 2024-07-06: 8140
# Fetched 200 properties this batch. Total checked: 200.
# Fetched 200 properties this batch. Total checked: 400.
# Fetched 200 properties this batch. Total checked: 600.
# Fetched 200 properties this batch. Total checked: 800.
# Fetched 200 properties this batch. Total checked: 1000.
# Fetched 200 properties this batch. Total checked: 1200.
# Fetched 200 properties this batch. Total checked: 1400.
# Fetched 200 properties this batch. Total checked: 1600.
# Fetched 200 properties this batch. Total checked: 1800.
# Fetched 200 properties this batch. Total checked: 2000.
# Fetched 200 properties this batch. Total checked: 2200.
# Fetched 200 properties this batch. Total checked: 2400.
# Fetched 200 properties this batch. Total checked: 2600.
# Fetched 200 properties this batch. Total checked: 2800.
# Fetched 200 properties this batch. Total checked: 3000.
# Fetched 200 properties this batch. Total checked: 3200.
# Fetched 200 properties this batch. Total checked: 3400.
# Fetched 200 properties this batch. Total checked: 3600.
# Fetched 200 properties this batch. Total checked: 3800.
# Fetched 200 properties this batch. Total checked: 4000.
# Fetched 200 properties this batch. Total checked: 4200.
# Fetched 200 properties this batch. Total checked: 4400.
# Fetched 200 properties this batch. Total checked: 4600.
# Fetched 200 properties this batch. Total checked: 4800.
# Fetched 200 properties this batch. Total checked: 5000.
# Fetched 200 properties this batch. Total checked: 5200.
# Fetched 200 properties this batch. Total checked: 5400.
# Fetched 200 properties this batch. Total checked: 5600.
# Fetched 200 properties this batch. Total checked: 5800.
# Fetched 200 properties this batch. Total checked: 6000.
# Fetched 200 properties this batch. Total checked: 6200.
# Fetched 200 properties this batch. Total checked: 6400.
# Fetched 200 properties this batch. Total checked: 6600.
# Fetched 200 properties this batch. Total checked: 6800.
# Fetched 200 properties this batch. Total checked: 7000.
# Fetched 200 properties this batch. Total checked: 7200.
# Fetched 200 properties this batch. Total checked: 7400.
# Fetched 200 properties this batch. Total checked: 7600.
# Fetched 200 properties this batch. Total checked: 7800.
# Fetched 200 properties this batch. Total checked: 8000.
# Fetched 140 properties this batch. Total checked: 8140.
# Total properties in Chicago, IL sold between 2022-07-03 and 2023-07-03: 9475
# Total properties in Chicago, IL sold between 2022-07-02 and 2023-07-03: 9475
# Fetched 200 properties this batch. Total checked: 8340.
# Fetched 200 properties this batch. Total checked: 8540.
# Fetched 200 properties this batch. Total checked: 8740.
# Fetched 200 properties this batch. Total checked: 8940.
# Fetched 200 properties this batch. Total checked: 9140.
# Fetched 200 properties this batch. Total checked: 9340.
# Fetched 200 properties this batch. Total checked: 9540.
# Fetched 200 properties this batch. Total checked: 9740.
# Fetched 200 properties this batch. Total checked: 9940.
# Fetched 200 properties this batch. Total checked: 10140.
# Fetched 200 properties this batch. Total checked: 10340.
# Fetched 200 properties this batch. Total checked: 10540.
# Fetched 200 properties this batch. Total checked: 10740.
# Fetched 200 properties this batch. Total checked: 10940.
# Fetched 200 properties this batch. Total checked: 11140.
# Fetched 200 properties this batch. Total checked: 11340.
# Fetched 200 properties this batch. Total checked: 11540.
# Fetched 200 properties this batch. Total checked: 11740.
# Fetched 200 properties this batch. Total checked: 11940.
# Fetched 200 properties this batch. Total checked: 12140.
# Fetched 200 properties this batch. Total checked: 12340.
# Fetched 200 properties this batch. Total checked: 12540.
# Fetched 200 properties this batch. Total checked: 12740.
# Fetched 200 properties this batch. Total checked: 12940.
# Fetched 200 properties this batch. Total checked: 13140.
# Fetched 200 properties this batch. Total checked: 13340.
# Fetched 200 properties this batch. Total checked: 13540.
# Fetched 200 properties this batch. Total checked: 13740.
# Fetched 200 properties this batch. Total checked: 13940.
# Fetched 200 properties this batch. Total checked: 14140.
# Fetched 200 properties this batch. Total checked: 14340.
# Fetched 200 properties this batch. Total checked: 14540.
# Fetched 200 properties this batch. Total checked: 14740.
# Fetched 200 properties this batch. Total checked: 14940.
# Fetched 200 properties this batch. Total checked: 15140.
# Fetched 200 properties this batch. Total checked: 15340.
# Fetched 200 properties this batch. Total checked: 15540.
# Fetched 200 properties this batch. Total checked: 15740.
# Fetched 200 properties this batch. Total checked: 15940.
# Fetched 200 properties this batch. Total checked: 16140.
# Fetched 200 properties this batch. Total checked: 16340.
# Fetched 200 properties this batch. Total checked: 16540.
# Fetched 200 properties this batch. Total checked: 16740.
# Fetched 200 properties this batch. Total checked: 16940.
# Fetched 200 properties this batch. Total checked: 17140.
# Fetched 200 properties this batch. Total checked: 17340.
# Fetched 200 properties this batch. Total checked: 17540.
# Fetched 75 properties this batch. Total checked: 17615.
# Total properties in Chicago, IL sold between 2021-07-01 and 2022-07-01: 13586
# Total properties in Chicago, IL sold between 2021-07-31 and 2022-07-01: 12315
# Total properties in Chicago, IL sold between 2021-08-30 and 2022-07-01: 11214
# Total properties in Chicago, IL sold between 2021-09-29 and 2022-07-01: 9939
# Total properties in Chicago, IL sold between 2021-09-28 and 2022-07-01: 9995
# Total properties in Chicago, IL sold between 2021-09-27 and 2022-07-01: 10053
# Total properties in Chicago, IL sold between 2021-10-27 and 2022-07-01: 8856
# Fetched 200 properties this batch. Total checked: 17815.
# Fetched 200 properties this batch. Total checked: 18015.
# Fetched 200 properties this batch. Total checked: 18215.
# Fetched 200 properties this batch. Total checked: 18415.
# Fetched 200 properties this batch. Total checked: 18615.
# Fetched 200 properties this batch. Total checked: 18815.
# Fetched 200 properties this batch. Total checked: 19015.
# Fetched 200 properties this batch. Total checked: 19215.
# Fetched 200 properties this batch. Total checked: 19415.
# Fetched 200 properties this batch. Total checked: 19615.
# Fetched 200 properties this batch. Total checked: 19815.
# Fetched 200 properties this batch. Total checked: 20015.
# Fetched 200 properties this batch. Total checked: 20215.
# Fetched 200 properties this batch. Total checked: 20415.
# Fetched 200 properties this batch. Total checked: 20615.
# Fetched 200 properties this batch. Total checked: 20815.
# Fetched 200 properties this batch. Total checked: 21015.
# Fetched 200 properties this batch. Total checked: 21215.
# Fetched 200 properties this batch. Total checked: 21415.
# Fetched 200 properties this batch. Total checked: 21615.
# Fetched 200 properties this batch. Total checked: 21815.
# Fetched 200 properties this batch. Total checked: 22015.
# Fetched 200 properties this batch. Total checked: 22215.
# Fetched 200 properties this batch. Total checked: 22415.
# Fetched 200 properties this batch. Total checked: 22615.
# Fetched 200 properties this batch. Total checked: 22815.
# Fetched 200 properties this batch. Total checked: 23015.
# Fetched 200 properties this batch. Total checked: 23215.
# Fetched 200 properties this batch. Total checked: 23415.
# Fetched 200 properties this batch. Total checked: 23615.
# Fetched 200 properties this batch. Total checked: 23815.
# Fetched 200 properties this batch. Total checked: 24015.
# Fetched 200 properties this batch. Total checked: 24215.
# Fetched 200 properties this batch. Total checked: 24415.
# Fetched 200 properties this batch. Total checked: 24615.
# Fetched 200 properties this batch. Total checked: 24815.
# Fetched 200 properties this batch. Total checked: 25015.
# Fetched 200 properties this batch. Total checked: 25215.
# Fetched 200 properties this batch. Total checked: 25415.
# Fetched 200 properties this batch. Total checked: 25615.
# Fetched 200 properties this batch. Total checked: 25815.
# Fetched 200 properties this batch. Total checked: 26015.
# Fetched 200 properties this batch. Total checked: 26215.
# Fetched 200 properties this batch. Total checked: 26415.
# Fetched 56 properties this batch. Total checked: 26471.
# Total properties in Chicago, IL sold between 2020-10-26 and 2021-10-26: 13598
# Total properties in Chicago, IL sold between 2020-11-25 and 2021-10-26: 12230
# Total properties in Chicago, IL sold between 2020-12-25 and 2021-10-26: 11440
# Total properties in Chicago, IL sold between 2021-01-24 and 2021-10-26: 10379
# Total properties in Chicago, IL sold between 2021-02-23 and 2021-10-26: 9321
# Total properties in Chicago, IL sold between 2021-02-22 and 2021-10-26: 9368
# Total properties in Chicago, IL sold between 2021-02-21 and 2021-10-26: 9368
# Fetched 200 properties this batch. Total checked: 26671.
# Fetched 200 properties this batch. Total checked: 26871.
# Fetched 200 properties this batch. Total checked: 27071.
# Fetched 200 properties this batch. Total checked: 27271.
# Fetched 200 properties this batch. Total checked: 27471.
# Fetched 200 properties this batch. Total checked: 27671.
# Fetched 200 properties this batch. Total checked: 27871.
# Fetched 200 properties this batch. Total checked: 28071.
# Fetched 200 properties this batch. Total checked: 28271.
# Fetched 200 properties this batch. Total checked: 28471.
# Fetched 200 properties this batch. Total checked: 28671.
# Fetched 200 properties this batch. Total checked: 28871.
# Fetched 200 properties this batch. Total checked: 29071.
# Fetched 200 properties this batch. Total checked: 29271.
# Fetched 200 properties this batch. Total checked: 29471.
# Fetched 200 properties this batch. Total checked: 29671.
# Fetched 200 properties this batch. Total checked: 29871.
# Fetched 200 properties this batch. Total checked: 30071.
# Fetched 200 properties this batch. Total checked: 30271.
# Fetched 200 properties this batch. Total checked: 30471.
# Fetched 200 properties this batch. Total checked: 30671.
# Fetched 200 properties this batch. Total checked: 30871.
# Fetched 200 properties this batch. Total checked: 31071.
# Fetched 200 properties this batch. Total checked: 31271.
# Fetched 200 properties this batch. Total checked: 31471.
# Fetched 200 properties this batch. Total checked: 31671.
# Fetched 200 properties this batch. Total checked: 31871.
# Fetched 200 properties this batch. Total checked: 32071.
# Fetched 200 properties this batch. Total checked: 32271.
# Fetched 200 properties this batch. Total checked: 32471.
# Fetched 200 properties this batch. Total checked: 32671.
# Fetched 200 properties this batch. Total checked: 32871.
# Fetched 200 properties this batch. Total checked: 33071.
# Fetched 200 properties this batch. Total checked: 33271.
# Fetched 200 properties this batch. Total checked: 33471.
# Fetched 200 properties this batch. Total checked: 33671.
# Fetched 200 properties this batch. Total checked: 33871.
# Fetched 200 properties this batch. Total checked: 34071.
# Fetched 200 properties this batch. Total checked: 34271.
# Fetched 200 properties this batch. Total checked: 34471.
# Fetched 200 properties this batch. Total checked: 34671.
# Fetched 200 properties this batch. Total checked: 34871.
# Fetched 200 properties this batch. Total checked: 35071.
# Fetched 200 properties this batch. Total checked: 35271.
# Fetched 200 properties this batch. Total checked: 35471.
# Fetched 200 properties this batch. Total checked: 35671.
# Fetched 168 properties this batch. Total checked: 35839.
# Total properties in Chicago, IL sold between 2020-02-21 and 2021-02-20: 9578
# Total properties in Chicago, IL sold between 2020-02-20 and 2021-02-20: 9607
# Total properties in Chicago, IL sold between 2020-02-19 and 2021-02-20: 9632
# Total properties in Chicago, IL sold between 2020-02-18 and 2021-02-20: 9665
# Total properties in Chicago, IL sold between 2020-02-17 and 2021-02-20: 9668
# Total properties in Chicago, IL sold between 2020-02-16 and 2021-02-20: 9668
# Fetched 200 properties this batch. Total checked: 36039.
# Fetched 200 properties this batch. Total checked: 36239.
# Fetched 200 properties this batch. Total checked: 36439.
# Fetched 200 properties this batch. Total checked: 36639.
# Fetched 200 properties this batch. Total checked: 36839.
# Fetched 200 properties this batch. Total checked: 37039.
# Fetched 200 properties this batch. Total checked: 37239.
# Fetched 200 properties this batch. Total checked: 37439.
# Fetched 200 properties this batch. Total checked: 37639.
# Fetched 200 properties this batch. Total checked: 37839.
# Fetched 200 properties this batch. Total checked: 38039.
# Fetched 200 properties this batch. Total checked: 38239.
# Fetched 200 properties this batch. Total checked: 38439.
# Fetched 200 properties this batch. Total checked: 38639.
# Fetched 200 properties this batch. Total checked: 38839.
# Fetched 200 properties this batch. Total checked: 39039.
# Fetched 200 properties this batch. Total checked: 39239.
# Fetched 200 properties this batch. Total checked: 39439.
# Fetched 200 properties this batch. Total checked: 39639.
# Fetched 200 properties this batch. Total checked: 39839.
# Fetched 200 properties this batch. Total checked: 40039.
# Fetched 200 properties this batch. Total checked: 40239.
# Fetched 200 properties this batch. Total checked: 40439.
# Fetched 200 properties this batch. Total checked: 40639.
# Fetched 200 properties this batch. Total checked: 40839.
# Fetched 200 properties this batch. Total checked: 41039.
# Fetched 200 properties this batch. Total checked: 41239.
# Fetched 200 properties this batch. Total checked: 41439.
# Fetched 200 properties this batch. Total checked: 41639.
# Fetched 200 properties this batch. Total checked: 41839.
# Fetched 200 properties this batch. Total checked: 42039.
# Fetched 200 properties this batch. Total checked: 42239.
# Fetched 200 properties this batch. Total checked: 42439.
# Fetched 200 properties this batch. Total checked: 42639.
# Fetched 200 properties this batch. Total checked: 42839.
# Fetched 200 properties this batch. Total checked: 43039.
# Fetched 200 properties this batch. Total checked: 43239.
# Fetched 200 properties this batch. Total checked: 43439.
# Fetched 200 properties this batch. Total checked: 43639.
# Fetched 200 properties this batch. Total checked: 43839.
# Fetched 200 properties this batch. Total checked: 44039.
# Fetched 200 properties this batch. Total checked: 44239.
# Fetched 200 properties this batch. Total checked: 44439.
# Fetched 200 properties this batch. Total checked: 44639.
# Fetched 200 properties this batch. Total checked: 44839.
# Fetched 200 properties this batch. Total checked: 45039.
# Fetched 200 properties this batch. Total checked: 45239.
# Fetched 200 properties this batch. Total checked: 45439.
# Fetched 68 properties this batch. Total checked: 45507.
# Total properties in Chicago, IL sold between 2019-02-15 and 2020-02-15: 9432
# Total properties in Chicago, IL sold between 2019-02-14 and 2020-02-15: 9454
# Total properties in Chicago, IL sold between 2019-02-13 and 2020-02-15: 9474
# Total properties in Chicago, IL sold between 2019-02-12 and 2020-02-15: 9490
# Total properties in Chicago, IL sold between 2019-02-11 and 2020-02-15: 9513
# Total properties in Chicago, IL sold between 2019-02-10 and 2020-02-15: 9513
# Fetched 200 properties this batch. Total checked: 45707.
# Fetched 200 properties this batch. Total checked: 45907.
# Fetched 200 properties this batch. Total checked: 46107.
# Fetched 200 properties this batch. Total checked: 46307.
# Fetched 200 properties this batch. Total checked: 46507.
# Fetched 200 properties this batch. Total checked: 46707.
# Fetched 200 properties this batch. Total checked: 46907.
# Fetched 200 properties this batch. Total checked: 47107.
# Fetched 200 properties this batch. Total checked: 47307.
# Fetched 200 properties this batch. Total checked: 47507.
# Fetched 200 properties this batch. Total checked: 47707.
# Fetched 200 properties this batch. Total checked: 47907.
# Fetched 200 properties this batch. Total checked: 48107.
# Fetched 200 properties this batch. Total checked: 48307.
# Fetched 200 properties this batch. Total checked: 48507.
# Fetched 200 properties this batch. Total checked: 48707.
# Fetched 200 properties this batch. Total checked: 48907.
# Fetched 200 properties this batch. Total checked: 49107.
# Fetched 200 properties this batch. Total checked: 49307.
# Fetched 200 properties this batch. Total checked: 49507.
# Fetched 200 properties this batch. Total checked: 49707.
# Fetched 200 properties this batch. Total checked: 49907.
# Fetched 200 properties this batch. Total checked: 50107.
# Fetched 200 properties this batch. Total checked: 50307.
# Fetched 200 properties this batch. Total checked: 50507.
# Fetched 200 properties this batch. Total checked: 50707.
# Fetched 200 properties this batch. Total checked: 50907.
# Fetched 200 properties this batch. Total checked: 51107.
# Fetched 200 properties this batch. Total checked: 51307.
# Fetched 200 properties this batch. Total checked: 51507.
# Fetched 200 properties this batch. Total checked: 51707.
# Fetched 200 properties this batch. Total checked: 51907.
# Fetched 200 properties this batch. Total checked: 52107.
# Fetched 200 properties this batch. Total checked: 52307.
# Fetched 200 properties this batch. Total checked: 52507.
# Fetched 200 properties this batch. Total checked: 52707.
# Fetched 200 properties this batch. Total checked: 52907.
# Fetched 200 properties this batch. Total checked: 53107.
# Fetched 200 properties this batch. Total checked: 53307.
# Fetched 200 properties this batch. Total checked: 53507.
# Fetched 200 properties this batch. Total checked: 53707.
# Fetched 200 properties this batch. Total checked: 53907.
# Fetched 200 properties this batch. Total checked: 54107.
# Fetched 200 properties this batch. Total checked: 54307.
# Fetched 200 properties this batch. Total checked: 54507.
# Fetched 200 properties this batch. Total checked: 54707.
# Fetched 200 properties this batch. Total checked: 54907.
# Fetched 113 properties this batch. Total checked: 55020.
# Total properties in Chicago, IL sold between 2018-02-09 and 2019-02-09: 9043
# Total properties in Chicago, IL sold between 2018-02-08 and 2019-02-09: 9053
# Total properties in Chicago, IL sold between 2018-02-07 and 2019-02-09: 9083
# Total properties in Chicago, IL sold between 2018-02-06 and 2019-02-09: 9117
# Total properties in Chicago, IL sold between 2018-02-05 and 2019-02-09: 9123
# Total properties in Chicago, IL sold between 2018-02-04 and 2019-02-09: 9123
# Fetched 200 properties this batch. Total checked: 55220.
# Fetched 200 properties this batch. Total checked: 55420.
# Fetched 200 properties this batch. Total checked: 55620.
# Fetched 200 properties this batch. Total checked: 55820.
# Fetched 200 properties this batch. Total checked: 56020.
# Fetched 200 properties this batch. Total checked: 56220.
# Fetched 200 properties this batch. Total checked: 56420.
# Fetched 200 properties this batch. Total checked: 56620.
# Fetched 200 properties this batch. Total checked: 56820.
# Fetched 200 properties this batch. Total checked: 57020.
# Fetched 200 properties this batch. Total checked: 57220.
# Fetched 200 properties this batch. Total checked: 57420.
# Fetched 200 properties this batch. Total checked: 57620.
# Fetched 200 properties this batch. Total checked: 57820.
# Fetched 200 properties this batch. Total checked: 58020.
# Fetched 200 properties this batch. Total checked: 58220.
# Fetched 200 properties this batch. Total checked: 58420.
# Fetched 200 properties this batch. Total checked: 58620.
# Fetched 200 properties this batch. Total checked: 58820.
# Fetched 200 properties this batch. Total checked: 59020.
# Fetched 200 properties this batch. Total checked: 59220.
# Fetched 200 properties this batch. Total checked: 59420.
# Fetched 200 properties this batch. Total checked: 59620.
# Fetched 200 properties this batch. Total checked: 59820.
# Fetched 200 properties this batch. Total checked: 60020.
# Fetched 200 properties this batch. Total checked: 60220.
# Fetched 200 properties this batch. Total checked: 60420.
# Fetched 200 properties this batch. Total checked: 60620.
# Fetched 200 properties this batch. Total checked: 60820.
# Fetched 200 properties this batch. Total checked: 61020.
# Fetched 200 properties this batch. Total checked: 61220.
# Fetched 200 properties this batch. Total checked: 61420.
# Fetched 200 properties this batch. Total checked: 61620.
# Fetched 200 properties this batch. Total checked: 61820.
# Fetched 200 properties this batch. Total checked: 62020.
# Fetched 200 properties this batch. Total checked: 62220.
# Fetched 200 properties this batch. Total checked: 62420.
# Fetched 200 properties this batch. Total checked: 62620.
# Fetched 200 properties this batch. Total checked: 62820.
# Fetched 200 properties this batch. Total checked: 63020.
# Fetched 200 properties this batch. Total checked: 63220.
# Fetched 200 properties this batch. Total checked: 63420.
# Fetched 200 properties this batch. Total checked: 63620.
# Fetched 200 properties this batch. Total checked: 63820.
# Fetched 200 properties this batch. Total checked: 64020.
# Fetched 123 properties this batch. Total checked: 64143.
# Total properties in Chicago, IL sold between 2017-02-03 and 2018-02-03: 7772
# Total properties in Chicago, IL sold between 2017-02-02 and 2018-02-03: 7794
# Total properties in Chicago, IL sold between 2017-02-01 and 2018-02-03: 7814
# Total properties in Chicago, IL sold between 2017-01-31 and 2018-02-03: 7844
# Total properties in Chicago, IL sold between 2017-01-30 and 2018-02-03: 7884
# Total properties in Chicago, IL sold between 2017-01-29 and 2018-02-03: 7884
# Fetched 200 properties this batch. Total checked: 64343.
# Fetched 200 properties this batch. Total checked: 64543.
# Fetched 200 properties this batch. Total checked: 64743.
# Fetched 200 properties this batch. Total checked: 64943.
# Fetched 200 properties this batch. Total checked: 65143.
# Fetched 200 properties this batch. Total checked: 65343.
# Fetched 200 properties this batch. Total checked: 65543.
# Fetched 200 properties this batch. Total checked: 65743.
# Fetched 200 properties this batch. Total checked: 65943.
# Fetched 200 properties this batch. Total checked: 66143.
# Fetched 200 properties this batch. Total checked: 66343.
# Fetched 200 properties this batch. Total checked: 66543.
# Fetched 200 properties this batch. Total checked: 66743.
# Fetched 200 properties this batch. Total checked: 66943.
# Fetched 200 properties this batch. Total checked: 67143.
# Fetched 200 properties this batch. Total checked: 67343.
# Fetched 200 properties this batch. Total checked: 67543.
# Fetched 200 properties this batch. Total checked: 67743.
# Fetched 200 properties this batch. Total checked: 67943.
# Fetched 200 properties this batch. Total checked: 68143.
# Fetched 200 properties this batch. Total checked: 68343.
# Fetched 200 properties this batch. Total checked: 68543.
# Fetched 200 properties this batch. Total checked: 68743.
# Fetched 200 properties this batch. Total checked: 68943.
# Fetched 200 properties this batch. Total checked: 69143.
# Fetched 200 properties this batch. Total checked: 69343.
# Fetched 200 properties this batch. Total checked: 69543.
# Fetched 200 properties this batch. Total checked: 69743.
# Fetched 200 properties this batch. Total checked: 69943.
# Fetched 200 properties this batch. Total checked: 70143.
# Fetched 200 properties this batch. Total checked: 70343.
# Fetched 200 properties this batch. Total checked: 70543.
# Fetched 200 properties this batch. Total checked: 70743.
# Fetched 200 properties this batch. Total checked: 70943.
# Fetched 200 properties this batch. Total checked: 71143.
# Fetched 200 properties this batch. Total checked: 71343.
# Fetched 200 properties this batch. Total checked: 71543.
# Fetched 200 properties this batch. Total checked: 71743.
# Fetched 200 properties this batch. Total checked: 71943.
# Fetched 84 properties this batch. Total checked: 72027.
# Total properties in Chicago, IL sold between 2016-01-29 and 2017-01-28: 7996
# Total properties in Chicago, IL sold between 2016-01-28 and 2017-01-28: 8013
# Total properties in Chicago, IL sold between 2016-01-27 and 2017-01-28: 8042
# Total properties in Chicago, IL sold between 2016-01-26 and 2017-01-28: 8066
# Total properties in Chicago, IL sold between 2016-01-25 and 2017-01-28: 8083
# Total properties in Chicago, IL sold between 2016-01-24 and 2017-01-28: 8083
# Fetched 200 properties this batch. Total checked: 72227.
# Fetched 200 properties this batch. Total checked: 72427.
# Fetched 200 properties this batch. Total checked: 72627.
# Fetched 200 properties this batch. Total checked: 72827.
# Fetched 200 properties this batch. Total checked: 73027.
# Fetched 200 properties this batch. Total checked: 73227.
# Fetched 200 properties this batch. Total checked: 73427.
# Fetched 200 properties this batch. Total checked: 73627.
# Fetched 200 properties this batch. Total checked: 73827.
# Fetched 200 properties this batch. Total checked: 74027.
# Fetched 200 properties this batch. Total checked: 74227.
# Fetched 200 properties this batch. Total checked: 74427.
# Fetched 200 properties this batch. Total checked: 74627.
# Fetched 200 properties this batch. Total checked: 74827.
# Fetched 200 properties this batch. Total checked: 75027.
# Fetched 200 properties this batch. Total checked: 75227.
# Fetched 200 properties this batch. Total checked: 75427.
# Fetched 200 properties this batch. Total checked: 75627.
# Fetched 200 properties this batch. Total checked: 75827.
# Fetched 200 properties this batch. Total checked: 76027.
# Fetched 200 properties this batch. Total checked: 76227.
# Fetched 200 properties this batch. Total checked: 76427.
# Fetched 200 properties this batch. Total checked: 76627.
# Fetched 200 properties this batch. Total checked: 76827.
# Fetched 200 properties this batch. Total checked: 77027.
# Fetched 200 properties this batch. Total checked: 77227.
# Fetched 200 properties this batch. Total checked: 77427.
# Fetched 200 properties this batch. Total checked: 77627.
# Fetched 200 properties this batch. Total checked: 77827.
# Fetched 200 properties this batch. Total checked: 78027.
# Fetched 200 properties this batch. Total checked: 78227.
# Fetched 200 properties this batch. Total checked: 78427.
# Fetched 200 properties this batch. Total checked: 78627.
# Fetched 200 properties this batch. Total checked: 78827.
# Fetched 200 properties this batch. Total checked: 79027.
# Fetched 200 properties this batch. Total checked: 79227.
# Fetched 200 properties this batch. Total checked: 79427.
# Fetched 200 properties this batch. Total checked: 79627.
# Fetched 200 properties this batch. Total checked: 79827.
# Fetched 200 properties this batch. Total checked: 80027.
# Fetched 83 properties this batch. Total checked: 80110.
# Total properties in Chicago, IL sold between 2015-01-23 and 2016-01-23: 7388
# Total properties in Chicago, IL sold between 2015-01-22 and 2016-01-23: 7413
# Total properties in Chicago, IL sold between 2015-01-21 and 2016-01-23: 7436
# Total properties in Chicago, IL sold between 2015-01-20 and 2016-01-23: 7450
# Total properties in Chicago, IL sold between 2015-01-19 and 2016-01-23: 7453
# Total properties in Chicago, IL sold between 2015-01-18 and 2016-01-23: 7453
# Fetched 200 properties this batch. Total checked: 80310.
# Fetched 200 properties this batch. Total checked: 80510.
# Fetched 200 properties this batch. Total checked: 80710.
# Fetched 200 properties this batch. Total checked: 80910.
# Fetched 200 properties this batch. Total checked: 81110.
# Fetched 200 properties this batch. Total checked: 81310.
# Fetched 200 properties this batch. Total checked: 81510.
# Fetched 200 properties this batch. Total checked: 81710.
# Fetched 200 properties this batch. Total checked: 81910.
# Fetched 200 properties this batch. Total checked: 82110.
# Fetched 200 properties this batch. Total checked: 82310.
# Fetched 200 properties this batch. Total checked: 82510.
# Fetched 200 properties this batch. Total checked: 82710.
# Fetched 200 properties this batch. Total checked: 82910.
# Fetched 200 properties this batch. Total checked: 83110.
# Fetched 200 properties this batch. Total checked: 83310.
# Fetched 200 properties this batch. Total checked: 83510.
# Fetched 200 properties this batch. Total checked: 83710.
# Fetched 200 properties this batch. Total checked: 83910.
# Fetched 200 properties this batch. Total checked: 84110.
# Fetched 200 properties this batch. Total checked: 84310.
# Fetched 200 properties this batch. Total checked: 84510.
# Fetched 200 properties this batch. Total checked: 84710.
# Fetched 200 properties this batch. Total checked: 84910.
# Fetched 200 properties this batch. Total checked: 85110.
# Fetched 200 properties this batch. Total checked: 85310.
# Fetched 200 properties this batch. Total checked: 85510.
# Fetched 200 properties this batch. Total checked: 85710.
# Fetched 200 properties this batch. Total checked: 85910.
# Fetched 200 properties this batch. Total checked: 86110.
# Fetched 200 properties this batch. Total checked: 86310.
# Fetched 200 properties this batch. Total checked: 86510.
# Fetched 200 properties this batch. Total checked: 86710.
# Fetched 200 properties this batch. Total checked: 86910.
# Fetched 200 properties this batch. Total checked: 87110.
# Fetched 200 properties this batch. Total checked: 87310.
# Fetched 200 properties this batch. Total checked: 87510.
# Fetched 53 properties this batch. Total checked: 87563.
# Total properties in Chicago, IL sold between 2014-01-17 and 2015-01-17: 4050
# Total properties in Chicago, IL sold between 2014-01-16 and 2015-01-17: 4050
# Fetched 200 properties this batch. Total checked: 87763.
# Fetched 200 properties this batch. Total checked: 87963.
# Fetched 200 properties this batch. Total checked: 88163.
# Fetched 200 properties this batch. Total checked: 88363.
# Fetched 200 properties this batch. Total checked: 88563.
# Fetched 200 properties this batch. Total checked: 88763.
# Fetched 200 properties this batch. Total checked: 88963.
# Fetched 200 properties this batch. Total checked: 89163.
# Fetched 200 properties this batch. Total checked: 89363.
# Fetched 200 properties this batch. Total checked: 89563.
# Fetched 200 properties this batch. Total checked: 89763.
# Fetched 200 properties this batch. Total checked: 89963.
# Fetched 200 properties this batch. Total checked: 90163.
# Fetched 200 properties this batch. Total checked: 90363.
# Fetched 200 properties this batch. Total checked: 90563.
# Fetched 200 properties this batch. Total checked: 90763.
# Fetched 200 properties this batch. Total checked: 90963.
# Fetched 200 properties this batch. Total checked: 91163.
# Fetched 200 properties this batch. Total checked: 91363.
# Fetched 200 properties this batch. Total checked: 91563.
# Fetched 50 properties this batch. Total checked: 91613.
# Total properties in Chicago, IL sold between 2013-01-15 and 2014-01-15: 0
# Total properties in Chicago, IL sold between 2013-01-14 and 2014-01-15: 0
# Total properties in Chicago, IL sold between 2012-01-14 and 2013-01-13: 0
# Total properties in Chicago, IL sold between 2012-01-13 and 2013-01-13: 0
# Total properties in Chicago, IL sold between 2011-01-12 and 2012-01-12: 0
# Total properties in Chicago, IL sold between 2011-01-11 and 2012-01-12: 0
# Total properties in Chicago, IL sold between 2010-01-10 and 2011-01-10: 0
# Total properties in Chicago, IL sold between 2010-01-09 and 2011-01-10: 0
# Total properties in Chicago, IL sold between 2009-01-08 and 2010-01-08: 0
# Total properties in Chicago, IL sold between 2009-01-07 and 2010-01-08: 0
# Total properties in Chicago, IL sold between 2008-01-07 and 2009-01-06: 0
# Total properties in Chicago, IL sold between 2008-01-06 and 2009-01-06: 0
# Total properties in Chicago, IL sold between 2007-01-05 and 2008-01-05: 0
# Total properties in Chicago, IL sold between 2007-01-04 and 2008-01-05: 0
# Total properties in Chicago, IL sold between 2006-01-03 and 2007-01-03: 0
# Total properties in Chicago, IL sold between 2006-01-02 and 2007-01-03: 0
# Total properties in Chicago, IL sold between 2005-01-01 and 2006-01-01: 0
# Total properties in Chicago, IL sold between 2004-12-31 and 2006-01-01: 0
# Total properties in Chicago, IL sold between 2003-12-31 and 2004-12-30: 0
# Total properties in Chicago, IL sold between 2003-12-30 and 2004-12-30: 0
# Total properties in Chicago, IL sold between 2002-12-29 and 2003-12-29: 0
# Total properties in Chicago, IL sold between 2002-12-28 and 2003-12-29: 0
# Total properties in Chicago, IL sold between 2001-12-27 and 2002-12-27: 0
# Total properties in Chicago, IL sold between 2001-12-26 and 2002-12-27: 0
# Total properties in Chicago, IL sold between 2000-12-25 and 2001-12-25: 0
# Total properties in Chicago, IL sold between 2000-12-24 and 2001-12-25: 0
# Total properties in Chicago, IL sold between 1999-12-24 and 2000-12-23: 0
# Total properties in Chicago, IL sold between 1999-12-23 and 2000-12-23: 0
# Total properties in Chicago, IL sold between 1998-12-22 and 1999-12-22: 0
# Total properties in Chicago, IL sold between 1998-12-21 and 1999-12-22: 0
# Total properties in Chicago, IL sold between 1997-12-20 and 1998-12-20: 0
# Total properties in Chicago, IL sold between 1997-12-19 and 1998-12-20: 0
# Total properties in Chicago, IL sold between 1996-12-18 and 1997-12-18: 0
# Total properties in Chicago, IL sold between 1996-12-17 and 1997-12-18: 0
# Total properties in Chicago, IL sold between 1995-12-17 and 1996-12-16: 0
# Total properties in Chicago, IL sold between 1995-12-16 and 1996-12-16: 0
# Total properties in Chicago, IL sold between 1994-12-15 and 1995-12-15: 0
# Total properties in Chicago, IL sold between 1994-12-14 and 1995-12-15: 0
# Done fetching 91613 sold properties in Chicago since 1995-01.
# Total properties available for sale in New York, NY: 4804
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 200.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 400.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 600.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 800.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 1000.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 1200.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 1400.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 1600.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 1800.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 2000.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 2200.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 2400.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 2600.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 2800.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 3000.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 3200.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 3400.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 3600.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 3800.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 4000.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 4200.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 4400.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 4600.
# Fetched 200 selling properties currently. Total available: 4804. Total checked: 4800.
# Fetched 4 selling properties currently. Total available: 4804. Total checked: 4804.
# Done fetching 4804 properties selling in New York.
# Total properties in New York, NY sold between 2023-07-07 and 2024-07-06: 4199
# Total properties in New York, NY sold between 2023-07-06 and 2024-07-06: 4217
# Total properties in New York, NY sold between 2023-07-05 and 2024-07-06: 4239
# Total properties in New York, NY sold between 2023-07-04 and 2024-07-06: 4239
# Fetched 200 properties this batch. Total checked: 200.
# Fetched 200 properties this batch. Total checked: 400.
# Fetched 200 properties this batch. Total checked: 600.
# Fetched 200 properties this batch. Total checked: 800.
# Fetched 200 properties this batch. Total checked: 1000.
# Fetched 200 properties this batch. Total checked: 1200.
# Fetched 200 properties this batch. Total checked: 1400.
# Fetched 200 properties this batch. Total checked: 1600.
# Fetched 200 properties this batch. Total checked: 1800.
# Fetched 200 properties this batch. Total checked: 2000.
# Fetched 200 properties this batch. Total checked: 2200.
# Fetched 200 properties this batch. Total checked: 2400.
# Fetched 200 properties this batch. Total checked: 2600.
# Fetched 200 properties this batch. Total checked: 2800.
# Fetched 200 properties this batch. Total checked: 3000.
# Fetched 200 properties this batch. Total checked: 3200.
# Fetched 200 properties this batch. Total checked: 3400.
# Fetched 200 properties this batch. Total checked: 3600.
# Fetched 200 properties this batch. Total checked: 3800.
# Fetched 200 properties this batch. Total checked: 4000.
# Fetched 200 properties this batch. Total checked: 4200.
# Fetched 39 properties this batch. Total checked: 4239.
# Total properties in New York, NY sold between 2022-07-03 and 2023-07-03: 8237
# Total properties in New York, NY sold between 2022-07-02 and 2023-07-03: 8241
# Total properties in New York, NY sold between 2022-07-01 and 2023-07-03: 8297
# Total properties in New York, NY sold between 2022-06-30 and 2023-07-03: 8381
# Total properties in New York, NY sold between 2022-06-29 and 2023-07-03: 8466
# Total properties in New York, NY sold between 2022-06-28 and 2023-07-03: 8517
# Total properties in New York, NY sold between 2022-06-27 and 2023-07-03: 8559
# Total properties in New York, NY sold between 2022-06-26 and 2023-07-03: 8559
# Fetched 200 properties this batch. Total checked: 4439.
# Fetched 200 properties this batch. Total checked: 4639.
# Fetched 200 properties this batch. Total checked: 4839.
# Fetched 200 properties this batch. Total checked: 5039.
# Fetched 200 properties this batch. Total checked: 5239.
# Fetched 200 properties this batch. Total checked: 5439.
# Fetched 200 properties this batch. Total checked: 5639.
# Fetched 200 properties this batch. Total checked: 5839.
# Fetched 200 properties this batch. Total checked: 6039.
# Fetched 200 properties this batch. Total checked: 6239.
# Fetched 200 properties this batch. Total checked: 6439.
# Fetched 200 properties this batch. Total checked: 6639.
# Fetched 200 properties this batch. Total checked: 6839.
# Fetched 200 properties this batch. Total checked: 7039.
# Fetched 200 properties this batch. Total checked: 7239.
# Fetched 200 properties this batch. Total checked: 7439.
# Fetched 200 properties this batch. Total checked: 7639.
# Fetched 200 properties this batch. Total checked: 7839.
# Fetched 200 properties this batch. Total checked: 8039.
# Fetched 200 properties this batch. Total checked: 8239.
# Fetched 200 properties this batch. Total checked: 8439.
# Fetched 200 properties this batch. Total checked: 8639.
# Fetched 200 properties this batch. Total checked: 8839.
# Fetched 200 properties this batch. Total checked: 9039.
# Fetched 200 properties this batch. Total checked: 9239.
# Fetched 200 properties this batch. Total checked: 9439.
# Fetched 200 properties this batch. Total checked: 9639.
# Fetched 200 properties this batch. Total checked: 9839.
# Fetched 200 properties this batch. Total checked: 10039.
# Fetched 200 properties this batch. Total checked: 10239.
# Fetched 200 properties this batch. Total checked: 10439.
# Fetched 200 properties this batch. Total checked: 10639.
# Fetched 200 properties this batch. Total checked: 10839.
# Fetched 200 properties this batch. Total checked: 11039.
# Fetched 200 properties this batch. Total checked: 11239.
# Fetched 200 properties this batch. Total checked: 11439.
# Fetched 200 properties this batch. Total checked: 11639.
# Fetched 200 properties this batch. Total checked: 11839.
# Fetched 200 properties this batch. Total checked: 12039.
# Fetched 200 properties this batch. Total checked: 12239.
# Fetched 200 properties this batch. Total checked: 12439.
# Fetched 200 properties this batch. Total checked: 12639.
# Fetched 159 properties this batch. Total checked: 12798.
# Total properties in New York, NY sold between 2021-06-25 and 2022-06-25: 11718
# Total properties in New York, NY sold between 2021-07-25 and 2022-06-25: 10652
# Total properties in New York, NY sold between 2021-08-24 and 2022-06-25: 9554
# Total properties in New York, NY sold between 2021-08-23 and 2022-06-25: 9595
# Total properties in New York, NY sold between 2021-08-22 and 2022-06-25: 9596
# Total properties in New York, NY sold between 2021-08-21 and 2022-06-25: 9597
# Total properties in New York, NY sold between 2021-08-20 and 2022-06-25: 9645
# Total properties in New York, NY sold between 2021-08-19 and 2022-06-25: 9698
# Total properties in New York, NY sold between 2021-08-18 and 2022-06-25: 9741
# Total properties in New York, NY sold between 2021-08-17 and 2022-06-25: 9788
# Total properties in New York, NY sold between 2021-08-16 and 2022-06-25: 9849
# Total properties in New York, NY sold between 2021-08-15 and 2022-06-25: 9849
# Fetched 200 properties this batch. Total checked: 12998.
# Fetched 200 properties this batch. Total checked: 13198.
# Fetched 200 properties this batch. Total checked: 13398.
# Fetched 200 properties this batch. Total checked: 13598.
# Fetched 200 properties this batch. Total checked: 13798.
# Fetched 200 properties this batch. Total checked: 13998.
# Fetched 200 properties this batch. Total checked: 14198.
# Fetched 200 properties this batch. Total checked: 14398.
# Fetched 200 properties this batch. Total checked: 14598.
# Fetched 200 properties this batch. Total checked: 14798.
# Fetched 200 properties this batch. Total checked: 14998.
# Fetched 200 properties this batch. Total checked: 15198.
# Fetched 200 properties this batch. Total checked: 15398.
# Fetched 200 properties this batch. Total checked: 15598.
# Fetched 200 properties this batch. Total checked: 15798.
# Fetched 200 properties this batch. Total checked: 15998.
# Fetched 200 properties this batch. Total checked: 16198.
# Fetched 200 properties this batch. Total checked: 16398.
# Fetched 200 properties this batch. Total checked: 16598.
# Fetched 200 properties this batch. Total checked: 16798.
# Fetched 200 properties this batch. Total checked: 16998.
# Fetched 200 properties this batch. Total checked: 17198.
# Fetched 200 properties this batch. Total checked: 17398.
# Fetched 200 properties this batch. Total checked: 17598.
# Fetched 200 properties this batch. Total checked: 17798.
# Fetched 200 properties this batch. Total checked: 17998.
# Fetched 200 properties this batch. Total checked: 18198.
# Fetched 200 properties this batch. Total checked: 18398.
# Fetched 200 properties this batch. Total checked: 18598.
# Fetched 200 properties this batch. Total checked: 18798.
# Fetched 200 properties this batch. Total checked: 18998.
# Fetched 200 properties this batch. Total checked: 19198.
# Fetched 200 properties this batch. Total checked: 19398.
# Fetched 200 properties this batch. Total checked: 19598.
# Fetched 200 properties this batch. Total checked: 19798.
# Fetched 200 properties this batch. Total checked: 19998.
# Fetched 200 properties this batch. Total checked: 20198.
# Fetched 200 properties this batch. Total checked: 20398.
# Fetched 200 properties this batch. Total checked: 20598.
# Fetched 200 properties this batch. Total checked: 20798.
# Fetched 200 properties this batch. Total checked: 20998.
# Fetched 200 properties this batch. Total checked: 21198.
# Fetched 200 properties this batch. Total checked: 21398.
# Fetched 200 properties this batch. Total checked: 21598.
# Fetched 200 properties this batch. Total checked: 21798.
# Fetched 200 properties this batch. Total checked: 21998.
# Fetched 200 properties this batch. Total checked: 22198.
# Fetched 200 properties this batch. Total checked: 22398.
# Fetched 200 properties this batch. Total checked: 22598.
# Fetched 49 properties this batch. Total checked: 22647.
# Total properties in New York, NY sold between 2020-08-14 and 2021-08-14: 10501
# Total properties in New York, NY sold between 2020-09-13 and 2021-08-14: 10021
# Total properties in New York, NY sold between 2020-10-13 and 2021-08-14: 9388
# Total properties in New York, NY sold between 2020-10-12 and 2021-08-14: 9393
# Total properties in New York, NY sold between 2020-10-11 and 2021-08-14: 9393
# Fetched 200 properties this batch. Total checked: 22847.
# Fetched 200 properties this batch. Total checked: 23047.
# Fetched 200 properties this batch. Total checked: 23247.
# Fetched 200 properties this batch. Total checked: 23447.
# Fetched 200 properties this batch. Total checked: 23647.
# Fetched 200 properties this batch. Total checked: 23847.
# Fetched 200 properties this batch. Total checked: 24047.
# Fetched 200 properties this batch. Total checked: 24247.
# Fetched 200 properties this batch. Total checked: 24447.
# Fetched 200 properties this batch. Total checked: 24647.
# Fetched 200 properties this batch. Total checked: 24847.
# Fetched 200 properties this batch. Total checked: 25047.
# Fetched 200 properties this batch. Total checked: 25247.
# Fetched 200 properties this batch. Total checked: 25447.
# Fetched 200 properties this batch. Total checked: 25647.
# Fetched 200 properties this batch. Total checked: 25847.
# Fetched 200 properties this batch. Total checked: 26047.
# Fetched 200 properties this batch. Total checked: 26247.
# Fetched 200 properties this batch. Total checked: 26447.
# Fetched 200 properties this batch. Total checked: 26647.
# Fetched 200 properties this batch. Total checked: 26847.
# Fetched 200 properties this batch. Total checked: 27047.
# Fetched 200 properties this batch. Total checked: 27247.
# Fetched 200 properties this batch. Total checked: 27447.
# Fetched 200 properties this batch. Total checked: 27647.
# Fetched 200 properties this batch. Total checked: 27847.
# Fetched 200 properties this batch. Total checked: 28047.
# Fetched 200 properties this batch. Total checked: 28247.
# Fetched 200 properties this batch. Total checked: 28447.
# Fetched 200 properties this batch. Total checked: 28647.
# Fetched 200 properties this batch. Total checked: 28847.
# ...
# Fetched 200 properties this batch. Total checked: 44213.
# Fetched 200 properties this batch. Total checked: 44413.
# Fetched 200 properties this batch. Total checked: 44613.
# Fetched 200 properties this batch. Total checked: 44813.
# Fetched 200 properties this batch. Total checked: 45013.
# Fetched 200 properties this batch. Total checked: 45213.
# Fetched 200 properties this batch. Total checked: 45413.
# Fetched 200 properties this batch. Total checked: 45613.
# Fetched 200 properties this batch. Total checked: 45813.
# Fetched 200 properties this batch. Total checked: 46013.
# Fetched 200 properties this batch. Total checked: 46213.
# Fetched 157 properties this batch. Total checked: 46370.
# Total properties in New York, NY sold between 2017-09-29 and 2018-09-29: 8520
# Total properties in New York, NY sold between 2017-09-28 and 2018-09-29: 8552
# Total properties in New York, NY sold between 2017-09-27 and 2018-09-29: 8572
# Total properties in New York, NY sold between 2017-09-26 and 2018-09-29: 8610
# Total properties in New York, NY sold between 2017-09-25 and 2018-09-29: 8649
# Total properties in New York, NY sold between 2017-09-24 and 2018-09-29: 8649
# Fetched 200 properties this batch. Total checked: 46570.
# Fetched 200 properties this batch. Total checked: 46770.
# Fetched 200 properties this batch. Total checked: 46970.
# Fetched 200 properties this batch. Total checked: 47170.
# Fetched 200 properties this batch. Total checked: 47370.
# Fetched 200 properties this batch. Total checked: 47570.
# Fetched 200 properties this batch. Total checked: 47770.
# Fetched 200 properties this batch. Total checked: 47970.
# Fetched 200 properties this batch. Total checked: 48170.
# Fetched 200 properties this batch. Total checked: 48370.
# Fetched 200 properties this batch. Total checked: 48570.
# Fetched 200 properties this batch. Total checked: 48770.
# Fetched 200 properties this batch. Total checked: 48970.
# Fetched 200 properties this batch. Total checked: 49170.
# Fetched 200 properties this batch. Total checked: 49370.
# Fetched 200 properties this batch. Total checked: 49570.
# Fetched 200 properties this batch. Total checked: 49770.
# Fetched 200 properties this batch. Total checked: 49970.
# Fetched 200 properties this batch. Total checked: 50170.
# Fetched 200 properties this batch. Total checked: 50370.
# Fetched 200 properties this batch. Total checked: 50570.
# Fetched 200 properties this batch. Total checked: 50770.
# Fetched 200 properties this batch. Total checked: 50970.
# Fetched 200 properties this batch. Total checked: 51170.
# Fetched 200 properties this batch. Total checked: 51370.
# Fetched 200 properties this batch. Total checked: 51570.
# Fetched 200 properties this batch. Total checked: 51770.
# Fetched 200 properties this batch. Total checked: 51970.
# Fetched 200 properties this batch. Total checked: 52170.
# Fetched 200 properties this batch. Total checked: 52370.
# Fetched 200 properties this batch. Total checked: 52570.
# Fetched 200 properties this batch. Total checked: 52770.
# Fetched 200 properties this batch. Total checked: 52970.
# Fetched 200 properties this batch. Total checked: 53170.
# Fetched 200 properties this batch. Total checked: 53370.
# Fetched 200 properties this batch. Total checked: 53570.
# Fetched 200 properties this batch. Total checked: 53770.
# Fetched 200 properties this batch. Total checked: 53970.
# Fetched 200 properties this batch. Total checked: 54170.
# Fetched 200 properties this batch. Total checked: 54370.
# Fetched 200 properties this batch. Total checked: 54570.
# Fetched 200 properties this batch. Total checked: 54770.
# Fetched 200 properties this batch. Total checked: 54970.
# Fetched 49 properties this batch. Total checked: 55019.
# Total properties in New York, NY sold between 2016-09-23 and 2017-09-23: 8452
# Total properties in New York, NY sold between 2016-09-22 and 2017-09-23: 8484
# Total properties in New York, NY sold between 2016-09-21 and 2017-09-23: 8527
# Total properties in New York, NY sold between 2016-09-20 and 2017-09-23: 8564
# Total properties in New York, NY sold between 2016-09-19 and 2017-09-23: 8593
# Total properties in New York, NY sold between 2016-09-18 and 2017-09-23: 8593
# Fetched 200 properties this batch. Total checked: 55219.
# Fetched 200 properties this batch. Total checked: 55419.
# Fetched 200 properties this batch. Total checked: 55619.
# Fetched 200 properties this batch. Total checked: 55819.
# Fetched 200 properties this batch. Total checked: 56019.
# Fetched 200 properties this batch. Total checked: 56219.
# Fetched 200 properties this batch. Total checked: 56419.
# Fetched 200 properties this batch. Total checked: 56619.
# Fetched 200 properties this batch. Total checked: 56819.
# Fetched 200 properties this batch. Total checked: 57019.
# Fetched 200 properties this batch. Total checked: 57219.
# Fetched 200 properties this batch. Total checked: 57419.
# Fetched 200 properties this batch. Total checked: 57619.
# Fetched 200 properties this batch. Total checked: 57819.
# Fetched 200 properties this batch. Total checked: 58019.
# Fetched 200 properties this batch. Total checked: 58219.
# Fetched 200 properties this batch. Total checked: 58419.
# Fetched 200 properties this batch. Total checked: 58619.
# Fetched 200 properties this batch. Total checked: 58819.
# Fetched 200 properties this batch. Total checked: 59019.
# Fetched 200 properties this batch. Total checked: 59219.
# Fetched 200 properties this batch. Total checked: 59419.
# Fetched 200 properties this batch. Total checked: 59619.
# Fetched 200 properties this batch. Total checked: 59819.
# Fetched 200 properties this batch. Total checked: 60019.
# Fetched 200 properties this batch. Total checked: 60219.
# Fetched 200 properties this batch. Total checked: 60419.
# Fetched 200 properties this batch. Total checked: 60619.
# Fetched 200 properties this batch. Total checked: 60819.
# Fetched 200 properties this batch. Total checked: 61019.
# Fetched 200 properties this batch. Total checked: 61219.
# Fetched 200 properties this batch. Total checked: 61419.
# Fetched 200 properties this batch. Total checked: 61619.
# Fetched 200 properties this batch. Total checked: 61819.
# Fetched 200 properties this batch. Total checked: 62019.
# Fetched 200 properties this batch. Total checked: 62219.
# Fetched 200 properties this batch. Total checked: 62419.
# Fetched 200 properties this batch. Total checked: 62619.
# Fetched 200 properties this batch. Total checked: 62819.
# Fetched 200 properties this batch. Total checked: 63019.
# Fetched 200 properties this batch. Total checked: 63219.
# Fetched 200 properties this batch. Total checked: 63419.
# Fetched 193 properties this batch. Total checked: 63612.
# Total properties in New York, NY sold between 2015-09-18 and 2016-09-17: 8035
# Total properties in New York, NY sold between 2015-09-17 and 2016-09-17: 8079
# Total properties in New York, NY sold between 2015-09-16 and 2016-09-17: 8132
# Total properties in New York, NY sold between 2015-09-15 and 2016-09-17: 8170
# Total properties in New York, NY sold between 2015-09-14 and 2016-09-17: 8209
# Total properties in New York, NY sold between 2015-09-13 and 2016-09-17: 8209
# Fetched 200 properties this batch. Total checked: 63812.
# Fetched 200 properties this batch. Total checked: 64012.
# Fetched 200 properties this batch. Total checked: 64212.
# Fetched 200 properties this batch. Total checked: 64412.
# Fetched 200 properties this batch. Total checked: 64612.
# Fetched 200 properties this batch. Total checked: 64812.
# Fetched 200 properties this batch. Total checked: 65012.
# Fetched 200 properties this batch. Total checked: 65212.
# Fetched 200 properties this batch. Total checked: 65412.
# Fetched 200 properties this batch. Total checked: 65612.
# Fetched 200 properties this batch. Total checked: 65812.
# Fetched 200 properties this batch. Total checked: 66012.
# Fetched 200 properties this batch. Total checked: 66212.
# Fetched 200 properties this batch. Total checked: 66412.
# Fetched 200 properties this batch. Total checked: 66612.
# Fetched 200 properties this batch. Total checked: 66812.
# Fetched 200 properties this batch. Total checked: 67012.
# Fetched 200 properties this batch. Total checked: 67212.
# Fetched 200 properties this batch. Total checked: 67412.
# Fetched 200 properties this batch. Total checked: 67612.
# Fetched 200 properties this batch. Total checked: 67812.
# Fetched 200 properties this batch. Total checked: 68012.
# Fetched 200 properties this batch. Total checked: 68212.
# Fetched 200 properties this batch. Total checked: 68412.
# Fetched 200 properties this batch. Total checked: 68612.
# Fetched 200 properties this batch. Total checked: 68812.
# Fetched 200 properties this batch. Total checked: 69012.
# Fetched 200 properties this batch. Total checked: 69212.
# Fetched 200 properties this batch. Total checked: 69412.
# Fetched 200 properties this batch. Total checked: 69612.
# Fetched 200 properties this batch. Total checked: 69812.
# Fetched 200 properties this batch. Total checked: 70012.
# Fetched 200 properties this batch. Total checked: 70212.
# Fetched 200 properties this batch. Total checked: 70412.
# Fetched 200 properties this batch. Total checked: 70612.
# Fetched 200 properties this batch. Total checked: 70812.
# Fetched 200 properties this batch. Total checked: 71012.
# Fetched 200 properties this batch. Total checked: 71212.
# Fetched 200 properties this batch. Total checked: 71412.
# Fetched 200 properties this batch. Total checked: 71612.
# Fetched 200 properties this batch. Total checked: 71812.
# Fetched 9 properties this batch. Total checked: 71821.
# Total properties in New York, NY sold between 2014-09-12 and 2015-09-12: 7001
# Total properties in New York, NY sold between 2014-09-11 and 2015-09-12: 7025
# Total properties in New York, NY sold between 2014-09-10 and 2015-09-12: 7047
# Total properties in New York, NY sold between 2014-09-09 and 2015-09-12: 7067
# Total properties in New York, NY sold between 2014-09-08 and 2015-09-12: 7089
# Total properties in New York, NY sold between 2014-09-07 and 2015-09-12: 7090
# Total properties in New York, NY sold between 2014-09-06 and 2015-09-12: 7091
# Total properties in New York, NY sold between 2014-09-05 and 2015-09-12: 7117
# Total properties in New York, NY sold between 2014-09-04 and 2015-09-12: 7140
# Total properties in New York, NY sold between 2014-09-03 and 2015-09-12: 7171
# Total properties in New York, NY sold between 2014-09-02 and 2015-09-12: 7192
# Total properties in New York, NY sold between 2014-09-01 and 2015-09-12: 7195
# Total properties in New York, NY sold between 2014-08-31 and 2015-09-12: 7195
# Fetched 200 properties this batch. Total checked: 72021.
# Fetched 200 properties this batch. Total checked: 72221.
# Fetched 200 properties this batch. Total checked: 72421.
# Fetched 200 properties this batch. Total checked: 72621.
# Fetched 200 properties this batch. Total checked: 72821.
# Fetched 200 properties this batch. Total checked: 73021.
# Fetched 200 properties this batch. Total checked: 73221.
# Fetched 200 properties this batch. Total checked: 73421.
# Fetched 200 properties this batch. Total checked: 73621.
# Fetched 200 properties this batch. Total checked: 73821.
# Fetched 200 properties this batch. Total checked: 74021.
# Fetched 200 properties this batch. Total checked: 74221.
# Fetched 200 properties this batch. Total checked: 74421.
# Fetched 200 properties this batch. Total checked: 74621.
# Fetched 200 properties this batch. Total checked: 74821.
# Fetched 200 properties this batch. Total checked: 75021.
# Fetched 200 properties this batch. Total checked: 75221.
# Fetched 200 properties this batch. Total checked: 75421.
# Fetched 200 properties this batch. Total checked: 75621.
# Fetched 200 properties this batch. Total checked: 75821.
# Fetched 200 properties this batch. Total checked: 76021.
# Fetched 200 properties this batch. Total checked: 76221.
# Fetched 200 properties this batch. Total checked: 76421.
# Fetched 200 properties this batch. Total checked: 76621.
# Fetched 200 properties this batch. Total checked: 76821.
# Fetched 200 properties this batch. Total checked: 77021.
# Fetched 200 properties this batch. Total checked: 77221.
# Fetched 200 properties this batch. Total checked: 77421.
# Fetched 200 properties this batch. Total checked: 77621.
# Fetched 200 properties this batch. Total checked: 77821.
# Fetched 200 properties this batch. Total checked: 78021.
# Fetched 200 properties this batch. Total checked: 78221.
# Fetched 200 properties this batch. Total checked: 78421.
# Fetched 200 properties this batch. Total checked: 78621.
# Fetched 200 properties this batch. Total checked: 78821.
# Fetched 195 properties this batch. Total checked: 79016.
# Total properties in New York, NY sold between 2013-08-30 and 2014-08-30: 1312
# Total properties in New York, NY sold between 2013-08-29 and 2014-08-30: 1312
# Fetched 200 properties this batch. Total checked: 79216.
# Fetched 200 properties this batch. Total checked: 79416.
# Fetched 200 properties this batch. Total checked: 79616.
# Fetched 200 properties this batch. Total checked: 79816.
# Fetched 200 properties this batch. Total checked: 80016.
# Fetched 200 properties this batch. Total checked: 80216.
# Fetched 112 properties this batch. Total checked: 80328.
# Total properties in New York, NY sold between 2012-08-28 and 2013-08-28: 0
# Total properties in New York, NY sold between 2012-08-27 and 2013-08-28: 0
# Total properties in New York, NY sold between 2011-08-27 and 2012-08-26: 0
# Total properties in New York, NY sold between 2011-08-26 and 2012-08-26: 0
# Total properties in New York, NY sold between 2010-08-25 and 2011-08-25: 0
# Total properties in New York, NY sold between 2010-08-24 and 2011-08-25: 0
# Total properties in New York, NY sold between 2009-08-23 and 2010-08-23: 0
# Total properties in New York, NY sold between 2009-08-22 and 2010-08-23: 0
# Total properties in New York, NY sold between 2008-08-21 and 2009-08-21: 0
# Total properties in New York, NY sold between 2008-08-20 and 2009-08-21: 0
# Total properties in New York, NY sold between 2007-08-20 and 2008-08-19: 0
# Total properties in New York, NY sold between 2007-08-19 and 2008-08-19: 0
# Total properties in New York, NY sold between 2006-08-18 and 2007-08-18: 0
# Total properties in New York, NY sold between 2006-08-17 and 2007-08-18: 0
# Total properties in New York, NY sold between 2005-08-16 and 2006-08-16: 0
# Total properties in New York, NY sold between 2005-08-15 and 2006-08-16: 0
# Total properties in New York, NY sold between 2004-08-14 and 2005-08-14: 0
# Total properties in New York, NY sold between 2004-08-13 and 2005-08-14: 0
# Total properties in New York, NY sold between 2003-08-13 and 2004-08-12: 0
# Total properties in New York, NY sold between 2003-08-12 and 2004-08-12: 0
# Total properties in New York, NY sold between 2002-08-11 and 2003-08-11: 0
# Total properties in New York, NY sold between 2002-08-10 and 2003-08-11: 0
# Total properties in New York, NY sold between 2001-08-09 and 2002-08-09: 0
# Total properties in New York, NY sold between 2001-08-08 and 2002-08-09: 0
# Total properties in New York, NY sold between 2000-08-07 and 2001-08-07: 0
# Total properties in New York, NY sold between 2000-08-06 and 2001-08-07: 0
# Total properties in New York, NY sold between 1999-08-06 and 2000-08-05: 0
# Total properties in New York, NY sold between 1999-08-05 and 2000-08-05: 0
# Total properties in New York, NY sold between 1998-08-04 and 1999-08-04: 0
# Total properties in New York, NY sold between 1998-08-03 and 1999-08-04: 0
# Total properties in New York, NY sold between 1997-08-02 and 1998-08-02: 0
# Total properties in New York, NY sold between 1997-08-01 and 1998-08-02: 0
# Total properties in New York, NY sold between 1996-07-31 and 1997-07-31: 0
# Total properties in New York, NY sold between 1996-07-30 and 1997-07-31: 0
# Total properties in New York, NY sold between 1995-07-30 and 1996-07-29: 0
# Total properties in New York, NY sold between 1995-07-29 and 1996-07-29: 0
# Total properties in New York, NY sold between 1994-07-28 and 1995-07-28: 0
# Total properties in New York, NY sold between 1994-07-27 and 1995-07-28: 0
# Done fetching 80328 sold properties in New York since 1995-01.

# %%
chicago_json = chicago_data['properties']
chicago_selling = pd.DataFrame(chicago_json)
chicago_selling.head()
# Out:
#   property_id  list_price search_promotions  \
# 0  7109976785    215000.0              None
# 1  9462841010    340000.0              None
# 2  7365488014    134900.0              None
# 3  7477995453     69000.0              None
# 4  7913610721    479900.0              None
#
#                                        primary_photo rent_to_own  listing_id  \
# 0  {'href': 'https://ap.rdcpix.com/696e87b0527eda...        None  2966364640
# 1  {'href': 'https://ap.rdcpix.com/82ea120aaba299...        None  2968097446
# 2  {'href': 'https://ap.rdcpix.com/43237d8f85b1ea...        None  2969248556
# 3  {'href': 'https://ap.rdcpix.com/b929df4ff05fb0...        None  2969234513
# 4  {'href': 'https://ap.rdcpix.com/c70a366ad55262...        None  2969241582
#
#    matterport                                      virtual_tours    status  \
# 0       False                                               None  for_sale
# 1       False  [{'href': 'https://kuula.co/share/5vfHt/collec...  for_sale
# 2       False                                               None  for_sale
# 3       False                                               None  for_sale
# 4       False                                               None  for_sale
#
#                                             products  ...  \
# 0  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 1  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 2  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 3  {'products': ['core.agent', 'core.broker', 'co...  ...
# 4  {'products': ['core.agent', 'core.broker', 'co...  ...
#
#                                           permalink price_reduced_amount  \
# 0   9906-S-Seeley-Ave_Chicago_IL_60643_M71099-76785                  NaN
# 1  650-N-Ridgeway-Ave_Chicago_IL_60624_M94628-41010                  NaN
# 2   5519-W-Gladys-Ave_Chicago_IL_60644_M73654-88014                  NaN
# 3    5237-S-Morgan-St_Chicago_IL_60609_M74779-95453                  NaN
# 4    2633-W-Howard-St_Chicago_IL_60645_M79136-10721                  NaN
#
#                                          description  \
# 0  {'name': None, 'beds': 3, 'baths_consolidated'...
# 1  {'name': None, 'beds': 3, 'baths_consolidated'...
# 2  {'name': None, 'beds': 3, 'baths_consolidated'...
# 3  {'name': None, 'beds': 3, 'baths_consolidated'...
# 4  {'name': None, 'beds': 3, 'baths_consolidated'...
#
#                                             location  open_houses  \
# 0  {'street_view_url': 'https://maps.googleapis.c...         None
# 1  {'street_view_url': 'https://maps.googleapis.c...         None
# 2  {'street_view_url': 'https://maps.googleapis.c...         None
# 3  {'street_view_url': 'https://maps.googleapis.c...         None
# 4  {'street_view_url': 'https://maps.googleapis.c...         None
#
#                                             branding  \
# 0  [{'type': 'Office', 'name': 'P.R.S. Associates...
# 1  [{'type': 'Office', 'name': 'Inherent Homes LL...
# 2  [{'type': 'Office', 'name': 'Parkvue Realty Co...
# 3  [{'type': 'Office', 'name': 'JENNINGS REALTY,I...
# 4  [{'type': 'Office', 'name': 'Sky High Real Est...
#
#                                                flags  \
# 0  {'is_coming_soon': None, 'is_new_listing': Fal...
# 1  {'is_coming_soon': None, 'is_new_listing': Fal...
# 2  {'is_coming_soon': None, 'is_new_listing': Tru...
# 3  {'is_coming_soon': None, 'is_new_listing': Tru...
# 4  {'is_coming_soon': None, 'is_new_listing': Tru...
#
#                      list_date  \
# 0  2024-04-18T17:33:51.000000Z
# 1  2024-06-03T19:03:15.000000Z
# 2  2024-07-05T21:12:51.000000Z
# 3  2024-07-05T14:48:50.000000Z
# 4  2024-07-05T17:50:39.000000Z
#
#                                               photos  \
# 0  [{'href': 'https://ap.rdcpix.com/696e87b0527ed...
# 1  [{'href': 'https://ap.rdcpix.com/82ea120aaba29...
# 2  [{'href': 'https://ap.rdcpix.com/43237d8f85b1e...
# 3  [{'href': 'https://ap.rdcpix.com/b929df4ff05fb...
# 4  [{'href': 'https://ap.rdcpix.com/c70a366ad5526...
#
#                              advertisers
# 0  [{'type': 'seller', 'builder': None}]
# 1  [{'type': 'seller', 'builder': None}]
# 2  [{'type': 'seller', 'builder': None}]
# 3  [{'type': 'seller', 'builder': None}]
# 4  [{'type': 'seller', 'builder': None}]
#
# [5 rows x 23 columns]

# %%
chicago_sold_json = chicago_data_sold['properties']
chicago_sold = pd.DataFrame(chicago_sold_json)
chicago_sold.head()
# Out:
#   property_id  list_price search_promotions  \
# 0  9016962474   1199000.0              None
# 1  8304938977    365000.0              None
# 2  7638203850    250000.0              None
# 3  8620945945    215000.0              None
# 4  8688450280     99900.0              None
#
#                                        primary_photo rent_to_own  listing_id  \
# 0  {'href': 'https://ap.rdcpix.com/33a21ffbb65e7d...        None  2969239196
# 1  {'href': 'https://ap.rdcpix.com/ca916ac9fbebe3...        None  2968325620
# 2  {'href': 'https://ap.rdcpix.com/6b035feede013a...        None  2967945980
# 3  {'href': 'https://ap.rdcpix.com/105c64da6141b6...        None  2963388318
# 4  {'href': 'https://ap.rdcpix.com/11b4d8082e779a...        None  2964640416
#
#    matterport                                      virtual_tours status  \
# 0       False                                               None   sold
# 1       False                                               None   sold
# 2       False  [{'href': 'https://tours.databasedads.com/4605...   sold
# 3       False                                               None   sold
# 4       False                                               None   sold
#
#                                             products  ...  \
# 0  {'products': ['core.agent', 'core.broker', 'co...  ...
# 1  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 2  {'products': ['core.agent', 'core.broker', 'co...  ...
# 3  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 4  {'products': ['core.agent', 'co_broke'], 'bran...  ...
#
#                                            permalink price_reduced_amount  \
# 0  3052-N-Spaulding-Ave_Chicago_IL_60618_M90169-6...                  NaN
# 1   5248-S-Kostner-Ave_Chicago_IL_60632_M83049-38977                  NaN
# 2   10330-S-Whipple-St_Chicago_IL_60655_M76382-03850                  NaN
# 3    9137-S-Halsted-St_Chicago_IL_60620_M86209-45945                  NaN
# 4     11730-S-State-St_Chicago_IL_60628_M86884-50280                  NaN
#
#                                          description  \
# 0  {'name': None, 'beds': 3, 'baths_consolidated'...
# 1  {'name': None, 'beds': 3, 'baths_consolidated'...
# 2  {'name': None, 'beds': 2, 'baths_consolidated'...
# 3  {'name': None, 'beds': 3, 'baths_consolidated'...
# 4  {'name': None, 'beds': 4, 'baths_consolidated'...
#
#                                             location  open_houses  \
# 0  {'street_view_url': 'https://maps.googleapis.c...         None
# 1  {'street_view_url': 'https://maps.googleapis.c...         None
# 2  {'street_view_url': 'https://maps.googleapis.c...         None
# 3  {'street_view_url': 'https://maps.googleapis.c...         None
# 4  {'street_view_url': 'https://maps.googleapis.c...         None
#
#                                             branding  \
# 0  [{'type': 'Office', 'name': 'Jameson Sotheby's...
# 1  [{'type': 'Office', 'name': 'XR Realty', 'phot...
# 2  [{'type': 'Office', 'name': 'Berkshire Hathawa...
# 3  [{'type': 'Office', 'name': 'Abs Property Cons...
# 4  [{'type': 'Office', 'name': 'Chicago Real Esta...
#
#                                                flags  \
# 0  {'is_coming_soon': None, 'is_new_listing': Fal...
# 1  {'is_coming_soon': None, 'is_new_listing': Fal...
# 2  {'is_coming_soon': None, 'is_new_listing': Fal...
# 3  {'is_coming_soon': None, 'is_new_listing': Fal...
# 4  {'is_coming_soon': None, 'is_new_listing': Fal...
#
#                      list_date  \
# 0  2024-07-05T16:46:20.000000Z
# 1  2024-06-09T14:51:48.000000Z
# 2  2024-05-30T13:32:07.000000Z
# 3  2024-01-22T22:48:51.000000Z
# 4  2024-03-02T04:33:46.000000Z
#
#                                               photos  \
# 0  [{'href': 'https://ap.rdcpix.com/33a21ffbb65e7...
# 1  [{'href': 'https://ap.rdcpix.com/ca916ac9fbebe...
# 2  [{'href': 'https://ap.rdcpix.com/6b035feede013...
# 3  [{'href': 'https://ap.rdcpix.com/105c64da6141b...
# 4  [{'href': 'https://ap.rdcpix.com/11b4d8082e779...
#
#                              advertisers
# 0  [{'type': 'seller', 'builder': None}]
# 1  [{'type': 'seller', 'builder': None}]
# 2  [{'type': 'seller', 'builder': None}]
# 3  [{'type': 'seller', 'builder': None}]
# 4  [{'type': 'seller', 'builder': None}]
#
# [5 rows x 23 columns]

# %%
new_york_json = new_york_data['properties']
new_york_selling = pd.DataFrame(new_york_json)
new_york_selling.head()
# Out:
#   property_id  list_price search_promotions  \
# 0  3243883955      260000              None
# 1  3974591407       99000              None
# 2  3536803586      250000              None
# 3  3204384532      275000              None
# 4  3767233034      899000              None
#
#                                        primary_photo rent_to_own  listing_id  \
# 0  {'href': 'https://ap.rdcpix.com/777a0a838fb235...        None  2962223385
# 1  {'href': 'https://ap.rdcpix.com/625c0dbb654a69...        None  2965322798
# 2  {'href': 'https://ap.rdcpix.com/9febd1c13274aa...        None  2961898884
# 3  {'href': 'https://ap.rdcpix.com/bdbd7e0b94a143...        None  2926324318
# 4  {'href': 'https://ap.rdcpix.com/d345414133f77c...        None  2967745369
#
#    matterport                                      virtual_tours    status  \
# 0       False                                               None  for_sale
# 1       False                                               None  for_sale
# 2       False                                               None  for_sale
# 3       False                                               None  for_sale
# 4       False  [{'href': 'https://app.doaudiotours.com/unbran...  for_sale
#
#                                             products  ...  \
# 0  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 1  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 2  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 3  {'products': ['co_broke'], 'brand_name': 'basi...  ...
# 4  {'products': ['core.agent', 'co_broke'], 'bran...  ...
#
#                                            permalink price_reduced_amount  \
# 0  620-Sinclair-Ave_Staten-Island_NY_10312_M32438...                  NaN
# 1   77-City-Blvd_Staten-Island_NY_10301_M39745-91407                  NaN
# 2     24005-147th-Ave_Rosedale_NY_11422_M35368-03586                  NaN
# 3       579-E-29th-St_Brooklyn_NY_11210_M32043-84532                  NaN
# 4  182-Benedict-Ave_Staten-Island_NY_10314_M37672...                  NaN
#
#                                          description  \
# 0  {'name': None, 'beds': 4, 'baths_consolidated'...
# 1  {'name': None, 'beds': 3, 'baths_consolidated'...
# 2  {'name': None, 'beds': 4, 'baths_consolidated'...
# 3  {'name': None, 'beds': 4, 'baths_consolidated'...
# 4  {'name': None, 'beds': 4, 'baths_consolidated'...
#
#                                             location  open_houses  \
# 0  {'street_view_url': 'https://maps.googleapis.c...         None
# 1  {'street_view_url': 'https://maps.googleapis.c...         None
# 2  {'street_view_url': 'https://maps.googleapis.c...         None
# 3  {'street_view_url': 'https://maps.googleapis.c...         None
# 4  {'street_view_url': 'https://maps.googleapis.c...         None
#
#                                             branding  \
# 0  [{'type': 'Office', 'name': 'Sowae Corp', 'pho...
# 1  [{'type': 'Office', 'name': 'NYC SHORT SALES B...
# 2  [{'type': 'Office', 'name': 'Sowae Corp', 'pho...
# 3  [{'type': 'Office', 'name': 'ONLY NINE REALTY ...
# 4  [{'type': 'Office', 'name': 'Staten Island Pre...
#
#                                                flags  \
# 0  {'is_coming_soon': None, 'is_new_listing': Fal...
# 1  {'is_coming_soon': None, 'is_new_listing': Fal...
# 2  {'is_coming_soon': None, 'is_new_listing': Fal...
# 3  {'is_coming_soon': None, 'is_new_listing': Fal...
# 4  {'is_coming_soon': None, 'is_new_listing': Fal...
#
#                      list_date  \
# 0  2023-12-04T23:24:59.000000Z
# 1  2024-03-20T18:26:05.000000Z
# 2  2023-11-21T20:27:17.000000Z
# 3  2021-02-24T19:23:01.000000Z
# 4  2024-05-24T18:45:25.000000Z
#
#                                               photos  \
# 0  [{'href': 'https://ap.rdcpix.com/777a0a838fb23...
# 1  [{'href': 'https://ap.rdcpix.com/625c0dbb654a6...
# 2  [{'href': 'https://ap.rdcpix.com/9febd1c13274a...
# 3  [{'href': 'https://ap.rdcpix.com/bdbd7e0b94a14...
# 4  [{'href': 'https://ap.rdcpix.com/d345414133f77...
#
#                              advertisers
# 0  [{'type': 'seller', 'builder': None}]
# 1  [{'type': 'seller', 'builder': None}]
# 2  [{'type': 'seller', 'builder': None}]
# 3  [{'type': 'seller', 'builder': None}]
# 4  [{'type': 'seller', 'builder': None}]
#
# [5 rows x 23 columns]

# %%
new_york_sold_json = new_york_data_sold['properties']
new_york_sold = pd.DataFrame(new_york_sold_json)
new_york_sold.head()
# Out:
#   property_id  list_price search_promotions  \
# 0  3476436735    549999.0              None
# 1  4136891435   1500000.0              None
# 2  4877937449    559000.0              None
# 3  4669261316   1099000.0              None
# 4  4114846597    968000.0              None
#
#                                        primary_photo rent_to_own  listing_id  \
# 0  {'href': 'https://ap.rdcpix.com/046e20b2fc7528...        None  2965831609
# 1  {'href': 'https://ap.rdcpix.com/1cc7bfa051a25c...        None  2959454563
# 2  {'href': 'https://ap.rdcpix.com/f069417e235ee9...        None  2959829830
# 3  {'href': 'https://ap.rdcpix.com/0752b5f9fbeac8...        None  2958513934
# 4  {'href': 'https://ap.rdcpix.com/d2eadd13e0f856...        None  2965127141
#
#    matterport                                      virtual_tours status  \
# 0       False  [{'href': 'https://youtu.be/yyKSXSQyIFc', 'typ...   sold
# 1       False                                               None   sold
# 2       False                                               None   sold
# 3       False                                               None   sold
# 4       False                                               None   sold
#
#                                             products  ...  \
# 0  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 1  {'products': ['co_broke'], 'brand_name': 'basi...  ...
# 2  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 3  {'products': ['core.agent', 'core.broker', 'li...  ...
# 4  {'products': ['core.agent', 'core.broker', 'co...  ...
#
#                                            permalink price_reduced_amount  \
# 0  274-Dixon-Ave_Staten-Island_NY_10303_M34764-36735                  NaN
# 1      1273-E-10th-St_Brooklyn_NY_11230_M41368-91435                  NaN
# 2     132-Elm-St_Staten-Island_NY_10310_M48779-37449              10000.0
# 3      1714-E-29th-St_Brooklyn_NY_11229_M46692-61316              50000.0
# 4       4744-189th-St_Flushing_NY_11358_M41148-46597              30000.0
#
#                                          description  \
# 0  {'name': None, 'beds': 3, 'baths_consolidated'...
# 1  {'name': None, 'beds': 4, 'baths_consolidated'...
# 2  {'name': None, 'beds': 4, 'baths_consolidated'...
# 3  {'name': None, 'beds': 3, 'baths_consolidated'...
# 4  {'name': None, 'beds': 3, 'baths_consolidated'...
#
#                                             location  open_houses  \
# 0  {'street_view_url': 'https://maps.googleapis.c...         None
# 1  {'street_view_url': 'https://maps.googleapis.c...         None
# 2  {'street_view_url': 'https://maps.googleapis.c...         None
# 3  {'street_view_url': 'https://maps.googleapis.c...         None
# 4  {'street_view_url': 'https://maps.googleapis.c...         None
#
#                                             branding  \
# 0  [{'type': 'Office', 'name': 'Martino Realty Gr...
# 1  [{'type': 'Office', 'name': 'BRISMAN REALTY', ...
# 2  [{'type': 'Office', 'name': 'Coldwell Banker A...
# 3  [{'type': 'Office', 'name': 'RE MAX Edge', 'ph...
# 4  [{'type': 'Office', 'name': 'Maureen Folan R E...
#
#                                                flags  \
# 0  {'is_coming_soon': None, 'is_new_listing': Fal...
# 1  {'is_coming_soon': None, 'is_new_listing': Fal...
# 2  {'is_coming_soon': None, 'is_new_listing': Fal...
# 3  {'is_coming_soon': None, 'is_new_listing': Fal...
# 4  {'is_coming_soon': None, 'is_new_listing': Fal...
#
#                      list_date  \
# 0  2024-04-05T15:12:40.000000Z
# 1  2023-09-07T17:45:51.000000Z
# 2  2023-09-20T15:50:10.000000Z
# 3  2023-08-09T18:18:27.000000Z
# 4  2024-03-14T15:14:11.000000Z
#
#                                               photos  \
# 0  [{'href': 'https://ap.rdcpix.com/046e20b2fc752...
# 1  [{'href': 'https://ap.rdcpix.com/1cc7bfa051a25...
# 2  [{'href': 'https://ap.rdcpix.com/f069417e235ee...
# 3  [{'href': 'https://ap.rdcpix.com/0752b5f9fbeac...
# 4  [{'href': 'https://ap.rdcpix.com/d2eadd13e0f85...
#
#                              advertisers
# 0  [{'type': 'seller', 'builder': None}]
# 1  [{'type': 'seller', 'builder': None}]
# 2  [{'type': 'seller', 'builder': None}]
# 3  [{'type': 'seller', 'builder': None}]
# 4  [{'type': 'seller', 'builder': None}]
#
# [5 rows x 23 columns]

# %%
def extract_data(properties):
    extracted_data = []

    for property in properties:
        id = property.get('property_id', None)
        permalink = property.get('permalink', None)
        post_link = "https://www.realtor.com/realestateandhomes-detail/" + permalink if permalink else None
        price = property.get('list_price', None)

        list_date = property.get('list_date', None)
        list_date = list_date.split('T')[0] if list_date else None

        location = property.get('location', {})
        address_line = location.get('address', {}).get('line', None)
        city = location.get('address', {}).get('city', None)
        state_code = location.get('address', {}).get('state_code', None)
        postal_code = location.get('address', {}).get('postal_code', None)
        address = f"{address_line}, {city}, {state_code} {postal_code}" if all([address_line, city, state_code, postal_code]) else None

        status = property.get('status', None)
        status = status.upper() if status else None

        if status == "SOLD":
            sold_date = property.get('description', {}).get('sold_date', None)
            if list_date and sold_date:
                list_date = datetime.datetime.strptime(list_date, "%Y-%m-%d")
                sold_date = datetime.datetime.strptime(sold_date, "%Y-%m-%d")
                days_until_sold = (sold_date - list_date).days
                sold_date = sold_date.strftime("%Y-%m-%d")
                list_date = list_date.strftime("%Y-%m-%d")
            else:
                days_until_sold = None
        else:
            sold_date = "Not sold yet"
            days_until_sold = "Not sold yet"

        description = property.get('description', {})
        area = description.get('sqft', None)
        bedrooms = description.get('beds', None)
        bathrooms = description.get('baths_consolidated', None)

        coordinate = location.get('address', {}).get('coordinate', None)
        latitude = coordinate['lat'] if coordinate else None
        longitude = coordinate['lon'] if coordinate else None

        extracted_data.append({
            'Data Source': 'https://www.realtor.com/',
            'ID': id,
            'Post link': post_link,
            'List date': list_date,
            'Sold date': sold_date,
            'Days until sold': days_until_sold,
            'Price': price,
            'Address': address,
            'Status': status,
            'Area': area,
            'Bedrooms': bedrooms,
            'Bathrooms': bathrooms,
            'Latitude': latitude,
            'Longitude': longitude
        })

    return extracted_data

batch = [chicago_json, chicago_sold_json, new_york_json, new_york_sold_json]
extracted_batches = [[], [], [], []]

for i, properties in enumerate(batch):
    extracted_batches[i] = extract_data(properties)

# %%
chicago_selling_extracted = pd.DataFrame(extracted_batches[0])
chicago_selling_extracted.head()
# Out:
#                 Data Source          ID  \
# 0  https://www.realtor.com/  7109976785
# 1  https://www.realtor.com/  9462841010
# 2  https://www.realtor.com/  7365488014
# 3  https://www.realtor.com/  7477995453
# 4  https://www.realtor.com/  7913610721
#
#                                            Post link   List date  \
# 0  https://www.realtor.com/realestateandhomes-det...  2024-04-18
# 1  https://www.realtor.com/realestateandhomes-det...  2024-06-03
# 2  https://www.realtor.com/realestateandhomes-det...  2024-07-05
# 3  https://www.realtor.com/realestateandhomes-det...  2024-07-05
# 4  https://www.realtor.com/realestateandhomes-det...  2024-07-05
#
#       Sold date Days until sold     Price  \
# 0  Not sold yet    Not sold yet  215000.0
# 1  Not sold yet    Not sold yet  340000.0
# 2  Not sold yet    Not sold yet  134900.0
# 3  Not sold yet    Not sold yet   69000.0
# 4  Not sold yet    Not sold yet  479900.0
#
#                                  Address    Status    Area  Bedrooms  \
# 0   9906 S Seeley Ave, Chicago, IL 60643  FOR_SALE  1567.0         3
# 1  650 N Ridgeway Ave, Chicago, IL 60624  FOR_SALE  1445.0         3
# 2   5519 W Gladys Ave, Chicago, IL 60644  FOR_SALE  1120.0         3
# 3    5237 S Morgan St, Chicago, IL 60609  FOR_SALE  1006.0         3
# 4    2633 W Howard St, Chicago, IL 60645  FOR_SALE  2280.0         3
#
#   Bathrooms   Latitude  Longitude
# 0         2  41.713489 -87.673732
# 1         2        NaN        NaN
# 2         1  41.875399 -87.762458
# 3         1  41.798562 -87.649779
# 4         2  42.019140 -87.696208

# %%
chicago_sold_extracted = pd.DataFrame(extracted_batches[1])
chicago_sold_extracted.head()
# Out:
#                 Data Source          ID  \
# 0  https://www.realtor.com/  9016962474
# 1  https://www.realtor.com/  8304938977
# 2  https://www.realtor.com/  7638203850
# 3  https://www.realtor.com/  8620945945
# 4  https://www.realtor.com/  8688450280
#
#                                            Post link   List date   Sold date  \
# 0  https://www.realtor.com/realestateandhomes-det...  2024-07-05  2024-07-05
# 1  https://www.realtor.com/realestateandhomes-det...  2024-06-09  2024-07-05
# 2  https://www.realtor.com/realestateandhomes-det...  2024-05-30  2024-07-03
# 3  https://www.realtor.com/realestateandhomes-det...  2024-01-22  2024-07-03
# 4  https://www.realtor.com/realestateandhomes-det...  2024-03-02  2024-07-03
#
#    Days until sold      Price                                  Address Status  \
# 0              0.0  1199000.0  3052 N Spaulding Ave, Chicago, IL 60618   SOLD
# 1             26.0   365000.0    5248 S Kostner Ave, Chicago, IL 60632   SOLD
# 2             34.0   250000.0    10330 S Whipple St, Chicago, IL 60655   SOLD
# 3            163.0   215000.0     9137 S Halsted St, Chicago, IL 60620   SOLD
# 4            123.0    99900.0      11730 S State St, Chicago, IL 60628   SOLD
#
#      Area  Bedrooms Bathrooms   Latitude  Longitude
# 0  3387.0       3.0       3.5        NaN        NaN
# 1     NaN       3.0         3  41.797154 -87.733424
# 2   926.0       2.0         1  41.705251 -87.698129
# 3   988.0       3.0         2  41.727680 -87.643001
# 4  2000.0       4.0         2  41.680657 -87.623118

# %%
new_york_selling_extracted = pd.DataFrame(extracted_batches[2])
new_york_selling_extracted.head()
# Out:
#                 Data Source          ID  \
# 0  https://www.realtor.com/  3243883955
# 1  https://www.realtor.com/  3974591407
# 2  https://www.realtor.com/  3536803586
# 3  https://www.realtor.com/  3204384532
# 4  https://www.realtor.com/  3767233034
#
#                                            Post link   List date  \
# 0  https://www.realtor.com/realestateandhomes-det...  2023-12-04
# 1  https://www.realtor.com/realestateandhomes-det...  2024-03-20
# 2  https://www.realtor.com/realestateandhomes-det...  2023-11-21
# 3  https://www.realtor.com/realestateandhomes-det...  2021-02-24
# 4  https://www.realtor.com/realestateandhomes-det...  2024-05-24
#
#       Sold date Days until sold   Price  \
# 0  Not sold yet    Not sold yet  260000
# 1  Not sold yet    Not sold yet   99000
# 2  Not sold yet    Not sold yet  250000
# 3  Not sold yet    Not sold yet  275000
# 4  Not sold yet    Not sold yet  899000
#
#                                      Address    Status    Area  Bedrooms  \
# 0  620 Sinclair Ave, Staten Island, NY 10312  FOR_SALE  2015.0         4
# 1      77 City Blvd, Staten Island, NY 10301  FOR_SALE  1176.0         3
# 2         240-05 147 Ave, Rosedale, NY 11422  FOR_SALE  2304.0         4
# 3          579 E 29th St, Brooklyn, NY 11210  FOR_SALE     NaN         4
# 4  182 Benedict Ave, Staten Island, NY 10314  FOR_SALE  2352.0         4
#
#   Bathrooms   Latitude  Longitude
# 0         2  40.541781 -74.196109
# 1         1  40.628757 -74.104166
# 2         2  40.657539 -73.743602
# 3         1  40.636665 -73.948744
# 4         5  40.622440 -74.128401

# %%
new_york_sold_extracted = pd.DataFrame(extracted_batches[3])
new_york_sold_extracted.head()
# Out:
#                 Data Source          ID  \
# 0  https://www.realtor.com/  3476436735
# 1  https://www.realtor.com/  4136891435
# 2  https://www.realtor.com/  4877937449
# 3  https://www.realtor.com/  4669261316
# 4  https://www.realtor.com/  4114846597
#
#                                            Post link   List date   Sold date  \
# 0  https://www.realtor.com/realestateandhomes-det...  2024-04-05  2024-07-03
# 1  https://www.realtor.com/realestateandhomes-det...  2023-09-07  2024-07-03
# 2  https://www.realtor.com/realestateandhomes-det...  2023-09-20  2024-07-03
# 3  https://www.realtor.com/realestateandhomes-det...  2023-08-09  2024-07-03
# 4  https://www.realtor.com/realestateandhomes-det...  2024-03-14  2024-07-03
#
#    Days until sold      Price                                 Address Status  \
# 0             89.0   549999.0  274 Dixon Ave, Staten Island, NY 10303   SOLD
# 1            300.0  1500000.0      1273 E 10th St, Brooklyn, NY 11230   SOLD
# 2            287.0   559000.0     132 Elm St, Staten Island, NY 10310   SOLD
# 3            329.0  1099000.0      1714 E 29th St, Brooklyn, NY 11229   SOLD
# 4            111.0   968000.0        47-44 189 St, Flushing, NY 11358   SOLD
#
#      Area  Bedrooms Bathrooms   Latitude  Longitude
# 0  1205.0       3.0       1.5  40.628432 -74.151338
# 1  2015.0       4.0       1.5  40.618168 -73.964649
# 2  1292.0       4.0         2  40.638510 -74.114339
# 3  1660.0       3.0       2.5  40.609290 -73.944877
# 4     NaN       3.0         2  40.749657 -73.790139

# %%
chicago_selling_extracted.to_csv('data/crawled/chicago_realtor_selling.csv', index=False)
chicago_sold_extracted.to_csv('data/crawled/chicago_realtor_sold.csv', index=False)
new_york_selling_extracted.to_csv('data/crawled/new_york_realtor_selling.csv', index=False)
new_york_sold_extracted.to_csv('data/crawled/new_york_realtor_sold.csv', index=False)
