# %%
import requests
import pandas as pd
import time
import datetime
import random

# %%
def dynamic_delay(minimum=1.0, maximum=3.0):
    return random.uniform(minimum, maximum)

def exponential_backoff_retry(request_func, max_retries=6):
    base_wait = 2
    for attempt in range(max_retries):
        try:
            response = request_func()
            if response.ok:
                time.sleep(dynamic_delay(1, 2))
                return response
        except Exception as e:
            print(f"Request failed with exception {e}. Attempt {attempt + 1}/{max_retries}.")
        
        time.sleep(base_wait * (2 ** attempt) + dynamic_delay())

    return None

# %%
def scrape_properties(city_slug, city_name, status=["for_sale", "ready_to_build"], min_date="1995-01-01"):
    url = 'https://www.realtor.com/api/v1/rdc_search_srp?client_id=rdc-search-for-sale-search&schema=vesta'
    headers = {"content-type": "application/json"}
    limit = 200
    all_properties = []
    total_checked = 0
    earliest_date = datetime.datetime.strptime(min_date, "%Y-%m-%d")
    current_date = datetime.datetime.now()

    def send_request(body):
        return requests.post(url, headers=headers, json=body)

    if "sold" in status:
        while current_date > earliest_date:
            start_date = current_date - datetime.timedelta(days=365)
            last_total = None

            while True:
                query = {
                    "sold_date": {"min": start_date.strftime("%Y-%m-%d"), "max": current_date.strftime("%Y-%m-%d")},
                    "status": status,
                    "search_location": {"location": city_name},
                    "type": ["single_family"]
                }

                graphql_query = """
                    query ConsumerSearchQuery(
                        $query: HomeSearchCriteria!
                        $limit: Int
                        $offset: Int
                        $search_promotion: SearchPromotionInput
                        $sort: [SearchAPISort]
                        $sort_type: SearchSortType
                        $client_data: JSON
                        $bucket: SearchAPIBucket
                        ) {
                        home_search: home_search(
                            query: $query
                            sort: $sort
                            limit: $limit
                            offset: $offset
                            sort_type: $sort_type
                            client_data: $client_data
                            bucket: $bucket
                            search_promotion: $search_promotion
                        ) {
                            count
                            total
                            search_promotion {
                            names
                            slots
                            promoted_properties {
                                id
                                from_other_page
                            }
                            }
                            mortgage_params {
                            interest_rate
                            }
                            properties: results {
                            property_id
                            list_price
                            search_promotions {
                                name
                                asset_id
                            }
                            primary_photo(https: true) {
                                href
                            }
                            rent_to_own {
                                right_to_purchase
                                rent
                            }
                            listing_id
                            matterport
                            virtual_tours {
                                href
                                type
                            }
                            status
                            products {
                                products
                                brand_name
                            }
                            source {
                                id
                                type
                                spec_id
                                plan_id
                                agents {
                                office_name
                                }
                            }
                            lead_attributes {
                                show_contact_an_agent
                                opcity_lead_attributes {
                                cashback_enabled
                                flip_the_market_enabled
                                }
                                lead_type
                                ready_connect_mortgage {
                                show_contact_a_lender
                                show_veterans_united
                                }
                            }
                            community {
                                description {
                                name
                                }
                                property_id
                                permalink
                                advertisers {
                                office {
                                    hours
                                    phones {
                                    type
                                    number
                                    primary
                                    trackable
                                    }
                                }
                                }
                                promotions {
                                description
                                href
                                headline
                                }
                            }
                            permalink
                            price_reduced_amount
                            description {
                                name
                                beds
                                baths_consolidated
                                sqft
                                lot_sqft
                                baths_max
                                baths_min
                                beds_min
                                beds_max
                                sqft_min
                                sqft_max
                                type
                                sub_type
                                sold_price
                                sold_date
                            }
                            location {
                                street_view_url
                                address {
                                line
                                postal_code
                                state
                                state_code
                                city
                                coordinate {
                                    lat
                                    lon
                                }
                                }
                                county {
                                name
                                fips_code
                                }
                            }
                            open_houses {
                                start_date
                                end_date
                            }
                            branding {
                                type
                                name
                                photo
                            }
                            flags {
                                is_coming_soon
                                is_new_listing(days: 14)
                                is_price_reduced(days: 30)
                                is_foreclosure
                                is_new_construction
                                is_pending
                                is_contingent
                            }
                            list_date
                            photos(limit: 2, https: true) {
                                href
                            }
                            advertisers {
                                type
                                builder {
                                name
                                href
                                logo
                                }
                            }
                            }
                        }
                        commute_polygon: get_commute_polygon(query: $query) {
                            areas {
                            id
                            breakpoints {
                                width
                                height
                                zoom
                            }
                            radius
                            center {
                                lat
                                lng
                            }
                            }
                            boundary
                        }
                        }
                """

                body = {
                    "query": graphql_query,
                    "variables": {
                        "geoSupportedSlug": city_slug,
                        "query": query,
                        "client_data": {"device_data": {"device_type": "desktop"}},
                        "limit": limit,
                        "offset": 0,
                        "sort": [{"field": "sold_date", "direction": "desc"}],
                        "search_promotion": {"names": ["CITY"], "slots": [], "promoted_properties": []}
                    },
                    "isClient": True,
                    "visitor_id": "7ffa9c49-550f-4c23-aa1b-e93786671450"
                }

                response = exponential_backoff_retry(lambda: send_request(body))
                if response is None or 'data' not in response.json() or 'home_search' not in response.json()['data'] or response.json()['data']['home_search'] is None:
                    print("Error: Invalid response structure or missing data.")
                    print(response.json() if response else "No response")
                    break

                data = response.json()
                api_total = data['data']['home_search']['total']
                print(f"Total properties in {city_name} sold between {start_date.strftime('%Y-%m-%d')} and {current_date.strftime('%Y-%m-%d')}: {api_total}")

                if api_total > 10000:
                    start_date += datetime.timedelta(days=30)
                    time.sleep(dynamic_delay(5, 10))
                else:
                    if last_total is None or api_total > last_total:
                        last_total = api_total
                        start_date -= datetime.timedelta(days=1)
                        time.sleep(dynamic_delay(5, 10))
                    else:
                        break
                    
            offset = 0
            while offset < api_total:
                body['variables']['offset'] = offset
                response = exponential_backoff_retry(lambda: send_request(body))
                if response is None:
                    print("Failed to fetch data after retries.")
                    break
                data = response.json()
                current_batch = data['data']['home_search']['properties']
                all_properties.extend(current_batch)
                total_checked += len(current_batch)
                print(f"Fetched {len(current_batch)} properties this batch. Total checked: {total_checked}.")
                offset += limit
                time.sleep(dynamic_delay(2, 3))

            current_date = start_date - datetime.timedelta(days=1)
            time.sleep(dynamic_delay(5, 10))

    else:
        offset = 0
        api_total = None
        first_batch = True

        query = {
            "status": status,
            "search_location": {
                "location": city_name
            },
            "type": ["single_family"]
        }

        graphql_query = """
            query ConsumerSearchQuery(
                $query: HomeSearchCriteria!
                $limit: Int
                $offset: Int
                $search_promotion: SearchPromotionInput
                $sort: [SearchAPISort]
                $sort_type: SearchSortType
                $client_data: JSON
                $bucket: SearchAPIBucket
                ) {
                home_search: home_search(
                    query: $query
                    sort: $sort
                    limit: $limit
                    offset: $offset
                    sort_type: $sort_type
                    client_data: $client_data
                    bucket: $bucket
                    search_promotion: $search_promotion
                ) {
                    count
                    total
                    search_promotion {
                    names
                    slots
                    promoted_properties {
                        id
                        from_other_page
                    }
                    }
                    mortgage_params {
                    interest_rate
                    }
                    properties: results {
                    property_id
                    list_price
                    search_promotions {
                        name
                        asset_id
                    }
                    primary_photo(https: true) {
                        href
                    }
                    rent_to_own {
                        right_to_purchase
                        rent
                    }
                    listing_id
                    matterport
                    virtual_tours {
                        href
                        type
                    }
                    status
                    products {
                        products
                        brand_name
                    }
                    source {
                        id
                        type
                        spec_id
                        plan_id
                        agents {
                        office_name
                        }
                    }
                    lead_attributes {
                        show_contact_an_agent
                        opcity_lead_attributes {
                        cashback_enabled
                        flip_the_market_enabled
                        }
                        lead_type
                        ready_connect_mortgage {
                        show_contact_a_lender
                        show_veterans_united
                        }
                    }
                    community {
                        description {
                        name
                        }
                        property_id
                        permalink
                        advertisers {
                        office {
                            hours
                            phones {
                            type
                            number
                            primary
                            trackable
                            }
                        }
                        }
                        promotions {
                        description
                        href
                        headline
                        }
                    }
                    permalink
                    price_reduced_amount
                    description {
                        name
                        beds
                        baths_consolidated
                        sqft
                        lot_sqft
                        baths_max
                        baths_min
                        beds_min
                        beds_max
                        sqft_min
                        sqft_max
                        type
                        sub_type
                        sold_price
                        sold_date
                    }
                    location {
                        street_view_url
                        address {
                        line
                        postal_code
                        state
                        state_code
                        city
                        coordinate {
                            lat
                            lon
                        }
                        }
                        county {
                        name
                        fips_code
                        }
                    }
                    open_houses {
                        start_date
                        end_date
                    }
                    branding {
                        type
                        name
                        photo
                    }
                    flags {
                        is_coming_soon
                        is_new_listing(days: 14)
                        is_price_reduced(days: 30)
                        is_foreclosure
                        is_new_construction
                        is_pending
                        is_contingent
                    }
                    list_date
                    photos(limit: 2, https: true) {
                        href
                    }
                    advertisers {
                        type
                        builder {
                        name
                        href
                        logo
                        }
                    }
                    }
                }
                commute_polygon: get_commute_polygon(query: $query) {
                    areas {
                    id
                    breakpoints {
                        width
                        height
                        zoom
                    }
                    radius
                    center {
                        lat
                        lng
                    }
                    }
                    boundary
                }
                }
        """

        while api_total is None or offset < api_total:
            body = {
                "query": graphql_query,
                "variables": {
                    "geoSupportedSlug": city_slug,
                    "query": query,
                    "client_data": {"device_data": {"device_type": "desktop"}},
                    "limit": limit,
                    "offset": offset,
                    "sort_type": "relevant",
                    "search_promotion": {"names": ["CITY"], "slots": [], "promoted_properties": []}
                },
                "isClient": True,
                "visitor_id": "7ffa9c49-550f-4c23-aa1b-e93786671450"
            }

            response = exponential_backoff_retry(lambda: send_request(body))
            if response is None:
                print("Failed to fetch data after retries.")
                break

            data = response.json()

            if api_total is None:
                api_total = data['data']['home_search']['total']
                if first_batch:
                    print(f"Total properties available for sale in {city_name}: {api_total}")
                    first_batch = False
                    
            properties = data['data']['home_search']['properties']
            all_properties.extend(properties)
            total_checked += len(properties)
            print(f"Fetched {len(properties)} selling properties currently. Total available: {api_total}. Total checked: {total_checked}.")
            offset += limit
            time.sleep(dynamic_delay(2, 3))

    return {
        "total_properties_checked": total_checked,
        "properties": all_properties
    }

min_date = "1995-01-01"

chicago_data = scrape_properties("Chicago_IL", "Chicago, IL")
print(f"Done fetching {chicago_data['total_properties_checked']} properties selling in Chicago.")
time.sleep(dynamic_delay(50, 60))

chicago_data_sold = scrape_properties("Chicago_IL", "Chicago, IL", ["sold"], min_date=min_date)
print(f"Done fetching {chicago_data_sold['total_properties_checked']} sold properties in Chicago since {min_date.split('-')[0]}-{min_date.split('-')[1]}.")
time.sleep(dynamic_delay(50, 60))

new_york_data = scrape_properties("New-York_NY", "New York, NY")
print(f"Done fetching {new_york_data['total_properties_checked']} properties selling in New York.")
time.sleep(dynamic_delay(50, 60))

new_york_data_sold = scrape_properties("New-York_NY", "New York, NY", ["sold"], min_date=min_date)
print(f"Done fetching {new_york_data_sold['total_properties_checked']} sold properties in New York since {min_date.split('-')[0]}-{min_date.split('-')[1]}.")
# Out:
# Total properties available for sale in Chicago, IL: 3141
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 200.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 400.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 600.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 800.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 1000.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 1200.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 1400.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 1600.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 1800.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 2000.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 2200.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 2400.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 2600.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 2800.
# Fetched 200 selling properties currently. Total available: 3141. Total checked: 3000.
# Fetched 141 selling properties currently. Total available: 3141. Total checked: 3141.
# Done fetching 3141 properties selling in Chicago.
# Total properties in Chicago, IL sold between 2023-07-06 and 2024-07-05: 8105
# Total properties in Chicago, IL sold between 2023-07-05 and 2024-07-05: 8126
# Total properties in Chicago, IL sold between 2023-07-04 and 2024-07-05: 8126
# Fetched 200 properties this batch. Total checked: 200.
# Fetched 200 properties this batch. Total checked: 400.
# Fetched 200 properties this batch. Total checked: 600.
# Fetched 200 properties this batch. Total checked: 800.
# Fetched 200 properties this batch. Total checked: 1000.
# Fetched 200 properties this batch. Total checked: 1200.
# Fetched 200 properties this batch. Total checked: 1400.
# Fetched 200 properties this batch. Total checked: 1600.
# Fetched 200 properties this batch. Total checked: 1800.
# Fetched 200 properties this batch. Total checked: 2000.
# Fetched 200 properties this batch. Total checked: 2200.
# Fetched 200 properties this batch. Total checked: 2400.
# Fetched 200 properties this batch. Total checked: 2600.
# Fetched 200 properties this batch. Total checked: 2800.
# Fetched 200 properties this batch. Total checked: 3000.
# Fetched 200 properties this batch. Total checked: 3200.
# Fetched 200 properties this batch. Total checked: 3400.
# Fetched 200 properties this batch. Total checked: 3600.
# Fetched 200 properties this batch. Total checked: 3800.
# Fetched 200 properties this batch. Total checked: 4000.
# Fetched 200 properties this batch. Total checked: 4200.
# Fetched 200 properties this batch. Total checked: 4400.
# Fetched 200 properties this batch. Total checked: 4600.
# Fetched 200 properties this batch. Total checked: 4800.
# Fetched 200 properties this batch. Total checked: 5000.
# Fetched 200 properties this batch. Total checked: 5200.
# Fetched 200 properties this batch. Total checked: 5400.
# Fetched 200 properties this batch. Total checked: 5600.
# Fetched 200 properties this batch. Total checked: 5800.
# Fetched 200 properties this batch. Total checked: 6000.
# Fetched 200 properties this batch. Total checked: 6200.
# Fetched 200 properties this batch. Total checked: 6400.
# Fetched 200 properties this batch. Total checked: 6600.
# Fetched 200 properties this batch. Total checked: 6800.
# Fetched 200 properties this batch. Total checked: 7000.
# Fetched 200 properties this batch. Total checked: 7200.
# Fetched 200 properties this batch. Total checked: 7400.
# Fetched 200 properties this batch. Total checked: 7600.
# Fetched 200 properties this batch. Total checked: 7800.
# Fetched 200 properties this batch. Total checked: 8000.
# Fetched 126 properties this batch. Total checked: 8126.
# Total properties in Chicago, IL sold between 2022-07-03 and 2023-07-03: 9474
# Total properties in Chicago, IL sold between 2022-07-02 and 2023-07-03: 9474
# Fetched 200 properties this batch. Total checked: 8326.
# Fetched 200 properties this batch. Total checked: 8526.
# Fetched 200 properties this batch. Total checked: 8726.
# Fetched 200 properties this batch. Total checked: 8926.
# Fetched 200 properties this batch. Total checked: 9126.
# Fetched 200 properties this batch. Total checked: 9326.
# Fetched 200 properties this batch. Total checked: 9526.
# Fetched 200 properties this batch. Total checked: 9726.
# Fetched 200 properties this batch. Total checked: 9926.
# Fetched 200 properties this batch. Total checked: 10126.
# Fetched 200 properties this batch. Total checked: 10326.
# Fetched 200 properties this batch. Total checked: 10526.
# Fetched 200 properties this batch. Total checked: 10726.
# Fetched 200 properties this batch. Total checked: 10926.
# Fetched 200 properties this batch. Total checked: 11126.
# Fetched 200 properties this batch. Total checked: 11326.
# Fetched 200 properties this batch. Total checked: 11526.
# Fetched 200 properties this batch. Total checked: 11726.
# Fetched 200 properties this batch. Total checked: 11926.
# Fetched 200 properties this batch. Total checked: 12126.
# Fetched 200 properties this batch. Total checked: 12326.
# Fetched 200 properties this batch. Total checked: 12526.
# Fetched 200 properties this batch. Total checked: 12726.
# Fetched 200 properties this batch. Total checked: 12926.
# Fetched 200 properties this batch. Total checked: 13126.
# Fetched 200 properties this batch. Total checked: 13326.
# Fetched 200 properties this batch. Total checked: 13526.
# Fetched 200 properties this batch. Total checked: 13726.
# Fetched 200 properties this batch. Total checked: 13926.
# Fetched 200 properties this batch. Total checked: 14126.
# Fetched 200 properties this batch. Total checked: 14326.
# Fetched 200 properties this batch. Total checked: 14526.
# Fetched 200 properties this batch. Total checked: 14726.
# Fetched 200 properties this batch. Total checked: 14926.
# Fetched 200 properties this batch. Total checked: 15126.
# Fetched 200 properties this batch. Total checked: 15326.
# Fetched 200 properties this batch. Total checked: 15526.
# Fetched 200 properties this batch. Total checked: 15726.
# Fetched 200 properties this batch. Total checked: 15926.
# Fetched 200 properties this batch. Total checked: 16126.
# Fetched 200 properties this batch. Total checked: 16326.
# Fetched 200 properties this batch. Total checked: 16526.
# Fetched 200 properties this batch. Total checked: 16726.
# Fetched 200 properties this batch. Total checked: 16926.
# Fetched 200 properties this batch. Total checked: 17126.
# Fetched 200 properties this batch. Total checked: 17326.
# Fetched 200 properties this batch. Total checked: 17526.
# Fetched 74 properties this batch. Total checked: 17600.
# Total properties in Chicago, IL sold between 2021-07-01 and 2022-07-01: 13586
# Total properties in Chicago, IL sold between 2021-07-31 and 2022-07-01: 12315
# Total properties in Chicago, IL sold between 2021-08-30 and 2022-07-01: 11214
# Total properties in Chicago, IL sold between 2021-09-29 and 2022-07-01: 9939
# Total properties in Chicago, IL sold between 2021-09-28 and 2022-07-01: 9995
# Total properties in Chicago, IL sold between 2021-09-27 and 2022-07-01: 10053
# Total properties in Chicago, IL sold between 2021-10-27 and 2022-07-01: 8857
# Fetched 200 properties this batch. Total checked: 17800.
# Fetched 200 properties this batch. Total checked: 18000.
# Fetched 200 properties this batch. Total checked: 18200.
# Fetched 200 properties this batch. Total checked: 18400.
# Fetched 200 properties this batch. Total checked: 18600.
# Fetched 200 properties this batch. Total checked: 18800.
# Fetched 200 properties this batch. Total checked: 19000.
# Fetched 200 properties this batch. Total checked: 19200.
# Fetched 200 properties this batch. Total checked: 19400.
# Fetched 200 properties this batch. Total checked: 19600.
# Fetched 200 properties this batch. Total checked: 19800.
# Fetched 200 properties this batch. Total checked: 20000.
# Fetched 200 properties this batch. Total checked: 20200.
# Fetched 200 properties this batch. Total checked: 20400.
# Fetched 200 properties this batch. Total checked: 20600.
# Fetched 200 properties this batch. Total checked: 20800.
# Fetched 200 properties this batch. Total checked: 21000.
# Fetched 200 properties this batch. Total checked: 21200.
# Fetched 200 properties this batch. Total checked: 21400.
# Fetched 200 properties this batch. Total checked: 21600.
# Fetched 200 properties this batch. Total checked: 21800.
# Fetched 200 properties this batch. Total checked: 22000.
# Fetched 200 properties this batch. Total checked: 22200.
# Fetched 200 properties this batch. Total checked: 22400.
# Fetched 200 properties this batch. Total checked: 22600.
# Fetched 200 properties this batch. Total checked: 22800.
# Fetched 200 properties this batch. Total checked: 23000.
# Fetched 200 properties this batch. Total checked: 23200.
# Fetched 200 properties this batch. Total checked: 23400.
# Fetched 200 properties this batch. Total checked: 23600.
# Fetched 200 properties this batch. Total checked: 23800.
# Fetched 200 properties this batch. Total checked: 24000.
# Fetched 200 properties this batch. Total checked: 24200.
# Fetched 200 properties this batch. Total checked: 24400.
# Fetched 200 properties this batch. Total checked: 24600.
# Fetched 200 properties this batch. Total checked: 24800.
# Fetched 200 properties this batch. Total checked: 25000.
# Fetched 200 properties this batch. Total checked: 25200.
# Fetched 200 properties this batch. Total checked: 25400.
# Fetched 200 properties this batch. Total checked: 25600.
# Fetched 200 properties this batch. Total checked: 25800.
# Fetched 200 properties this batch. Total checked: 26000.
# Fetched 200 properties this batch. Total checked: 26200.
# Fetched 200 properties this batch. Total checked: 26400.
# Fetched 57 properties this batch. Total checked: 26457.
# Total properties in Chicago, IL sold between 2020-10-26 and 2021-10-26: 13595
# Total properties in Chicago, IL sold between 2020-11-25 and 2021-10-26: 12227
# Total properties in Chicago, IL sold between 2020-12-25 and 2021-10-26: 11437
# Total properties in Chicago, IL sold between 2021-01-24 and 2021-10-26: 10376
# Total properties in Chicago, IL sold between 2021-02-23 and 2021-10-26: 9318
# Total properties in Chicago, IL sold between 2021-02-22 and 2021-10-26: 9365
# Total properties in Chicago, IL sold between 2021-02-21 and 2021-10-26: 9365
# Fetched 200 properties this batch. Total checked: 26657.
# Fetched 200 properties this batch. Total checked: 26857.
# Fetched 200 properties this batch. Total checked: 27057.
# Fetched 200 properties this batch. Total checked: 27257.
# Fetched 200 properties this batch. Total checked: 27457.
# Fetched 200 properties this batch. Total checked: 27657.
# Fetched 200 properties this batch. Total checked: 27857.
# Fetched 200 properties this batch. Total checked: 28057.
# Fetched 200 properties this batch. Total checked: 28257.
# Fetched 200 properties this batch. Total checked: 28457.
# Fetched 200 properties this batch. Total checked: 28657.
# Fetched 200 properties this batch. Total checked: 28857.
# Fetched 200 properties this batch. Total checked: 29057.
# Fetched 200 properties this batch. Total checked: 29257.
# Fetched 200 properties this batch. Total checked: 29457.
# Fetched 200 properties this batch. Total checked: 29657.
# Fetched 200 properties this batch. Total checked: 29857.
# Fetched 200 properties this batch. Total checked: 30057.
# Fetched 200 properties this batch. Total checked: 30257.
# Fetched 200 properties this batch. Total checked: 30457.
# Fetched 200 properties this batch. Total checked: 30657.
# Fetched 200 properties this batch. Total checked: 30857.
# Fetched 200 properties this batch. Total checked: 31057.
# Fetched 200 properties this batch. Total checked: 31257.
# Fetched 200 properties this batch. Total checked: 31457.
# Fetched 200 properties this batch. Total checked: 31657.
# Fetched 200 properties this batch. Total checked: 31857.
# Fetched 200 properties this batch. Total checked: 32057.
# Fetched 200 properties this batch. Total checked: 32257.
# Fetched 200 properties this batch. Total checked: 32457.
# Fetched 200 properties this batch. Total checked: 32657.
# Fetched 200 properties this batch. Total checked: 32857.
# Fetched 200 properties this batch. Total checked: 33057.
# Fetched 200 properties this batch. Total checked: 33257.
# Fetched 200 properties this batch. Total checked: 33457.
# Fetched 200 properties this batch. Total checked: 33657.
# Fetched 200 properties this batch. Total checked: 33857.
# Fetched 200 properties this batch. Total checked: 34057.
# Fetched 200 properties this batch. Total checked: 34257.
# Fetched 200 properties this batch. Total checked: 34457.
# Fetched 200 properties this batch. Total checked: 34657.
# Fetched 200 properties this batch. Total checked: 34857.
# Fetched 200 properties this batch. Total checked: 35057.
# Fetched 200 properties this batch. Total checked: 35257.
# Fetched 200 properties this batch. Total checked: 35457.
# Fetched 200 properties this batch. Total checked: 35657.
# Fetched 165 properties this batch. Total checked: 35822.
# Total properties in Chicago, IL sold between 2020-02-21 and 2021-02-20: 9577
# Total properties in Chicago, IL sold between 2020-02-20 and 2021-02-20: 9606
# Total properties in Chicago, IL sold between 2020-02-19 and 2021-02-20: 9631
# Total properties in Chicago, IL sold between 2020-02-18 and 2021-02-20: 9664
# Total properties in Chicago, IL sold between 2020-02-17 and 2021-02-20: 9667
# Total properties in Chicago, IL sold between 2020-02-16 and 2021-02-20: 9667
# Fetched 200 properties this batch. Total checked: 36022.
# Fetched 200 properties this batch. Total checked: 36222.
# Fetched 200 properties this batch. Total checked: 36422.
# Fetched 200 properties this batch. Total checked: 36622.
# Fetched 200 properties this batch. Total checked: 36822.
# Fetched 200 properties this batch. Total checked: 37022.
# Fetched 200 properties this batch. Total checked: 37222.
# Fetched 200 properties this batch. Total checked: 37422.
# Fetched 200 properties this batch. Total checked: 37622.
# Fetched 200 properties this batch. Total checked: 37822.
# Fetched 200 properties this batch. Total checked: 38022.
# Fetched 200 properties this batch. Total checked: 38222.
# Fetched 200 properties this batch. Total checked: 38422.
# Fetched 200 properties this batch. Total checked: 38622.
# Fetched 200 properties this batch. Total checked: 38822.
# Fetched 200 properties this batch. Total checked: 39022.
# Fetched 200 properties this batch. Total checked: 39222.
# Fetched 200 properties this batch. Total checked: 39422.
# Fetched 200 properties this batch. Total checked: 39622.
# Fetched 200 properties this batch. Total checked: 39822.
# Fetched 200 properties this batch. Total checked: 40022.
# Fetched 200 properties this batch. Total checked: 40222.
# Fetched 200 properties this batch. Total checked: 40422.
# Fetched 200 properties this batch. Total checked: 40622.
# Fetched 200 properties this batch. Total checked: 40822.
# Fetched 200 properties this batch. Total checked: 41022.
# Fetched 200 properties this batch. Total checked: 41222.
# Fetched 200 properties this batch. Total checked: 41422.
# Fetched 200 properties this batch. Total checked: 41622.
# Fetched 200 properties this batch. Total checked: 41822.
# Fetched 200 properties this batch. Total checked: 42022.
# Fetched 200 properties this batch. Total checked: 42222.
# Fetched 200 properties this batch. Total checked: 42422.
# Fetched 200 properties this batch. Total checked: 42622.
# Fetched 200 properties this batch. Total checked: 42822.
# Fetched 200 properties this batch. Total checked: 43022.
# Fetched 200 properties this batch. Total checked: 43222.
# Fetched 200 properties this batch. Total checked: 43422.
# Fetched 200 properties this batch. Total checked: 43622.
# Fetched 200 properties this batch. Total checked: 43822.
# Fetched 200 properties this batch. Total checked: 44022.
# Fetched 200 properties this batch. Total checked: 44222.
# Fetched 200 properties this batch. Total checked: 44422.
# Fetched 200 properties this batch. Total checked: 44622.
# Fetched 200 properties this batch. Total checked: 44822.
# Fetched 200 properties this batch. Total checked: 45022.
# Fetched 200 properties this batch. Total checked: 45222.
# Fetched 200 properties this batch. Total checked: 45422.
# Fetched 67 properties this batch. Total checked: 45489.
# Total properties in Chicago, IL sold between 2019-02-15 and 2020-02-15: 9427
# Total properties in Chicago, IL sold between 2019-02-14 and 2020-02-15: 9449
# Total properties in Chicago, IL sold between 2019-02-13 and 2020-02-15: 9469
# Total properties in Chicago, IL sold between 2019-02-12 and 2020-02-15: 9485
# Total properties in Chicago, IL sold between 2019-02-11 and 2020-02-15: 9508
# Total properties in Chicago, IL sold between 2019-02-10 and 2020-02-15: 9508
# Fetched 200 properties this batch. Total checked: 45689.
# Fetched 200 properties this batch. Total checked: 45889.
# Fetched 200 properties this batch. Total checked: 46089.
# Fetched 200 properties this batch. Total checked: 46289.
# Fetched 200 properties this batch. Total checked: 46489.
# Fetched 200 properties this batch. Total checked: 46689.
# Fetched 200 properties this batch. Total checked: 46889.
# Fetched 200 properties this batch. Total checked: 47089.
# Fetched 200 properties this batch. Total checked: 47289.
# Fetched 200 properties this batch. Total checked: 47489.
# Fetched 200 properties this batch. Total checked: 47689.
# Fetched 200 properties this batch. Total checked: 47889.
# Fetched 200 properties this batch. Total checked: 48089.
# Fetched 200 properties this batch. Total checked: 48289.
# Fetched 200 properties this batch. Total checked: 48489.
# Fetched 200 properties this batch. Total checked: 48689.
# Fetched 200 properties this batch. Total checked: 48889.
# Fetched 200 properties this batch. Total checked: 49089.
# Fetched 200 properties this batch. Total checked: 49289.
# Fetched 200 properties this batch. Total checked: 49489.
# Fetched 200 properties this batch. Total checked: 49689.
# Fetched 200 properties this batch. Total checked: 49889.
# Fetched 200 properties this batch. Total checked: 50089.
# Fetched 200 properties this batch. Total checked: 50289.
# Fetched 200 properties this batch. Total checked: 50489.
# Fetched 200 properties this batch. Total checked: 50689.
# Fetched 200 properties this batch. Total checked: 50889.
# Fetched 200 properties this batch. Total checked: 51089.
# Fetched 200 properties this batch. Total checked: 51289.
# Fetched 200 properties this batch. Total checked: 51489.
# Fetched 200 properties this batch. Total checked: 51689.
# Fetched 200 properties this batch. Total checked: 51889.
# Fetched 200 properties this batch. Total checked: 52089.
# Fetched 200 properties this batch. Total checked: 52289.
# Fetched 200 properties this batch. Total checked: 52489.
# Fetched 200 properties this batch. Total checked: 52689.
# Fetched 200 properties this batch. Total checked: 52889.
# Fetched 200 properties this batch. Total checked: 53089.
# Fetched 200 properties this batch. Total checked: 53289.
# Fetched 200 properties this batch. Total checked: 53489.
# Fetched 200 properties this batch. Total checked: 53689.
# Fetched 200 properties this batch. Total checked: 53889.
# Fetched 200 properties this batch. Total checked: 54089.
# Fetched 200 properties this batch. Total checked: 54289.
# Fetched 200 properties this batch. Total checked: 54489.
# Fetched 200 properties this batch. Total checked: 54689.
# Fetched 200 properties this batch. Total checked: 54889.
# Fetched 108 properties this batch. Total checked: 54997.
# Total properties in Chicago, IL sold between 2018-02-09 and 2019-02-09: 9043
# Total properties in Chicago, IL sold between 2018-02-08 and 2019-02-09: 9053
# Total properties in Chicago, IL sold between 2018-02-07 and 2019-02-09: 9083
# Total properties in Chicago, IL sold between 2018-02-06 and 2019-02-09: 9117
# Total properties in Chicago, IL sold between 2018-02-05 and 2019-02-09: 9123
# Total properties in Chicago, IL sold between 2018-02-04 and 2019-02-09: 9123
# Fetched 200 properties this batch. Total checked: 55197.
# Fetched 200 properties this batch. Total checked: 55397.
# Fetched 200 properties this batch. Total checked: 55597.
# Fetched 200 properties this batch. Total checked: 55797.
# Fetched 200 properties this batch. Total checked: 55997.
# Fetched 200 properties this batch. Total checked: 56197.
# Fetched 200 properties this batch. Total checked: 56397.
# Fetched 200 properties this batch. Total checked: 56597.
# Fetched 200 properties this batch. Total checked: 56797.
# Fetched 200 properties this batch. Total checked: 56997.
# Fetched 200 properties this batch. Total checked: 57197.
# Fetched 200 properties this batch. Total checked: 57397.
# Fetched 200 properties this batch. Total checked: 57597.
# Fetched 200 properties this batch. Total checked: 57797.
# Fetched 200 properties this batch. Total checked: 57997.
# Fetched 200 properties this batch. Total checked: 58197.
# Fetched 200 properties this batch. Total checked: 58397.
# Fetched 200 properties this batch. Total checked: 58597.
# Fetched 200 properties this batch. Total checked: 58797.
# Fetched 200 properties this batch. Total checked: 58997.
# Fetched 200 properties this batch. Total checked: 59197.
# Fetched 200 properties this batch. Total checked: 59397.
# Fetched 200 properties this batch. Total checked: 59597.
# Fetched 200 properties this batch. Total checked: 59797.
# Fetched 200 properties this batch. Total checked: 59997.
# Fetched 200 properties this batch. Total checked: 60197.
# Fetched 200 properties this batch. Total checked: 60397.
# Fetched 200 properties this batch. Total checked: 60597.
# Fetched 200 properties this batch. Total checked: 60797.
# Fetched 200 properties this batch. Total checked: 60997.
# Fetched 200 properties this batch. Total checked: 61197.
# Fetched 200 properties this batch. Total checked: 61397.
# Fetched 200 properties this batch. Total checked: 61597.
# Fetched 200 properties this batch. Total checked: 61797.
# Fetched 200 properties this batch. Total checked: 61997.
# Fetched 200 properties this batch. Total checked: 62197.
# Fetched 200 properties this batch. Total checked: 62397.
# Fetched 200 properties this batch. Total checked: 62597.
# Fetched 200 properties this batch. Total checked: 62797.
# Fetched 200 properties this batch. Total checked: 62997.
# Fetched 200 properties this batch. Total checked: 63197.
# Fetched 200 properties this batch. Total checked: 63397.
# Fetched 200 properties this batch. Total checked: 63597.
# Fetched 200 properties this batch. Total checked: 63797.
# Fetched 200 properties this batch. Total checked: 63997.
# Fetched 123 properties this batch. Total checked: 64120.
# Total properties in Chicago, IL sold between 2017-02-03 and 2018-02-03: 7772
# Total properties in Chicago, IL sold between 2017-02-02 and 2018-02-03: 7794
# Total properties in Chicago, IL sold between 2017-02-01 and 2018-02-03: 7814
# Total properties in Chicago, IL sold between 2017-01-31 and 2018-02-03: 7844
# Total properties in Chicago, IL sold between 2017-01-30 and 2018-02-03: 7884
# Total properties in Chicago, IL sold between 2017-01-29 and 2018-02-03: 7884
# Fetched 200 properties this batch. Total checked: 64320.
# Fetched 200 properties this batch. Total checked: 64520.
# Fetched 200 properties this batch. Total checked: 64720.
# Fetched 200 properties this batch. Total checked: 64920.
# Fetched 200 properties this batch. Total checked: 65120.
# Fetched 200 properties this batch. Total checked: 65320.
# Fetched 200 properties this batch. Total checked: 65520.
# Fetched 200 properties this batch. Total checked: 65720.
# Fetched 200 properties this batch. Total checked: 65920.
# Fetched 200 properties this batch. Total checked: 66120.
# Fetched 200 properties this batch. Total checked: 66320.
# Fetched 200 properties this batch. Total checked: 66520.
# Fetched 200 properties this batch. Total checked: 66720.
# Fetched 200 properties this batch. Total checked: 66920.
# Fetched 200 properties this batch. Total checked: 67120.
# Fetched 200 properties this batch. Total checked: 67320.
# Fetched 200 properties this batch. Total checked: 67520.
# Fetched 200 properties this batch. Total checked: 67720.
# Fetched 200 properties this batch. Total checked: 67920.
# Fetched 200 properties this batch. Total checked: 68120.
# Fetched 200 properties this batch. Total checked: 68320.
# Fetched 200 properties this batch. Total checked: 68520.
# Fetched 200 properties this batch. Total checked: 68720.
# Fetched 200 properties this batch. Total checked: 68920.
# Fetched 200 properties this batch. Total checked: 69120.
# Fetched 200 properties this batch. Total checked: 69320.
# Fetched 200 properties this batch. Total checked: 69520.
# Fetched 200 properties this batch. Total checked: 69720.
# Fetched 200 properties this batch. Total checked: 69920.
# Fetched 200 properties this batch. Total checked: 70120.
# Fetched 200 properties this batch. Total checked: 70320.
# Fetched 200 properties this batch. Total checked: 70520.
# Fetched 200 properties this batch. Total checked: 70720.
# Fetched 200 properties this batch. Total checked: 70920.
# Fetched 200 properties this batch. Total checked: 71120.
# Fetched 200 properties this batch. Total checked: 71320.
# Fetched 200 properties this batch. Total checked: 71520.
# Fetched 200 properties this batch. Total checked: 71720.
# Fetched 200 properties this batch. Total checked: 71920.
# Fetched 84 properties this batch. Total checked: 72004.
# Total properties in Chicago, IL sold between 2016-01-29 and 2017-01-28: 7996
# Total properties in Chicago, IL sold between 2016-01-28 and 2017-01-28: 8013
# Total properties in Chicago, IL sold between 2016-01-27 and 2017-01-28: 8042
# Total properties in Chicago, IL sold between 2016-01-26 and 2017-01-28: 8066
# Total properties in Chicago, IL sold between 2016-01-25 and 2017-01-28: 8083
# Total properties in Chicago, IL sold between 2016-01-24 and 2017-01-28: 8083
# Fetched 200 properties this batch. Total checked: 72204.
# Fetched 200 properties this batch. Total checked: 72404.
# Fetched 200 properties this batch. Total checked: 72604.
# Fetched 200 properties this batch. Total checked: 72804.
# Fetched 200 properties this batch. Total checked: 73004.
# Fetched 200 properties this batch. Total checked: 73204.
# Fetched 200 properties this batch. Total checked: 73404.
# Fetched 200 properties this batch. Total checked: 73604.
# Fetched 200 properties this batch. Total checked: 73804.
# Fetched 200 properties this batch. Total checked: 74004.
# Fetched 200 properties this batch. Total checked: 74204.
# Fetched 200 properties this batch. Total checked: 74404.
# Fetched 200 properties this batch. Total checked: 74604.
# Fetched 200 properties this batch. Total checked: 74804.
# Fetched 200 properties this batch. Total checked: 75004.
# Fetched 200 properties this batch. Total checked: 75204.
# Fetched 200 properties this batch. Total checked: 75404.
# Fetched 200 properties this batch. Total checked: 75604.
# Fetched 200 properties this batch. Total checked: 75804.
# Fetched 200 properties this batch. Total checked: 76004.
# Fetched 200 properties this batch. Total checked: 76204.
# Fetched 200 properties this batch. Total checked: 76404.
# Fetched 200 properties this batch. Total checked: 76604.
# Fetched 200 properties this batch. Total checked: 76804.
# Fetched 200 properties this batch. Total checked: 77004.
# Fetched 200 properties this batch. Total checked: 77204.
# Fetched 200 properties this batch. Total checked: 77404.
# Fetched 200 properties this batch. Total checked: 77604.
# Fetched 200 properties this batch. Total checked: 77804.
# Fetched 200 properties this batch. Total checked: 78004.
# Fetched 200 properties this batch. Total checked: 78204.
# Fetched 200 properties this batch. Total checked: 78404.
# Fetched 200 properties this batch. Total checked: 78604.
# Fetched 200 properties this batch. Total checked: 78804.
# Fetched 200 properties this batch. Total checked: 79004.
# Fetched 200 properties this batch. Total checked: 79204.
# Fetched 200 properties this batch. Total checked: 79404.
# Fetched 200 properties this batch. Total checked: 79604.
# Fetched 200 properties this batch. Total checked: 79804.
# Fetched 200 properties this batch. Total checked: 80004.
# Fetched 83 properties this batch. Total checked: 80087.
# Total properties in Chicago, IL sold between 2015-01-23 and 2016-01-23: 7391
# Total properties in Chicago, IL sold between 2015-01-22 and 2016-01-23: 7416
# Total properties in Chicago, IL sold between 2015-01-21 and 2016-01-23: 7439
# Total properties in Chicago, IL sold between 2015-01-20 and 2016-01-23: 7453
# Total properties in Chicago, IL sold between 2015-01-19 and 2016-01-23: 7456
# Total properties in Chicago, IL sold between 2015-01-18 and 2016-01-23: 7456
# Fetched 200 properties this batch. Total checked: 80287.
# Fetched 200 properties this batch. Total checked: 80487.
# Fetched 200 properties this batch. Total checked: 80687.
# Fetched 200 properties this batch. Total checked: 80887.
# Fetched 200 properties this batch. Total checked: 81087.
# Fetched 200 properties this batch. Total checked: 81287.
# Fetched 200 properties this batch. Total checked: 81487.
# Fetched 200 properties this batch. Total checked: 81687.
# Fetched 200 properties this batch. Total checked: 81887.
# Fetched 200 properties this batch. Total checked: 82087.
# Fetched 200 properties this batch. Total checked: 82287.
# Fetched 200 properties this batch. Total checked: 82487.
# Fetched 200 properties this batch. Total checked: 82687.
# Fetched 200 properties this batch. Total checked: 82887.
# Fetched 200 properties this batch. Total checked: 83087.
# Fetched 200 properties this batch. Total checked: 83287.
# Fetched 200 properties this batch. Total checked: 83487.
# Fetched 200 properties this batch. Total checked: 83687.
# Fetched 200 properties this batch. Total checked: 83887.
# Fetched 200 properties this batch. Total checked: 84087.
# Fetched 200 properties this batch. Total checked: 84287.
# Fetched 200 properties this batch. Total checked: 84487.
# Fetched 200 properties this batch. Total checked: 84687.
# Fetched 200 properties this batch. Total checked: 84887.
# Fetched 200 properties this batch. Total checked: 85087.
# Fetched 200 properties this batch. Total checked: 85287.
# Fetched 200 properties this batch. Total checked: 85487.
# Fetched 200 properties this batch. Total checked: 85687.
# Fetched 200 properties this batch. Total checked: 85887.
# Fetched 200 properties this batch. Total checked: 86087.
# Fetched 200 properties this batch. Total checked: 86287.
# Fetched 200 properties this batch. Total checked: 86487.
# Fetched 200 properties this batch. Total checked: 86687.
# Fetched 200 properties this batch. Total checked: 86887.
# Fetched 200 properties this batch. Total checked: 87087.
# Fetched 200 properties this batch. Total checked: 87287.
# Fetched 200 properties this batch. Total checked: 87487.
# Fetched 56 properties this batch. Total checked: 87543.
# Total properties in Chicago, IL sold between 2014-01-17 and 2015-01-17: 4049
# Total properties in Chicago, IL sold between 2014-01-16 and 2015-01-17: 4049
# Fetched 200 properties this batch. Total checked: 87743.
# Fetched 200 properties this batch. Total checked: 87943.
# Fetched 200 properties this batch. Total checked: 88143.
# Fetched 200 properties this batch. Total checked: 88343.
# Fetched 200 properties this batch. Total checked: 88543.
# Fetched 200 properties this batch. Total checked: 88743.
# Fetched 200 properties this batch. Total checked: 88943.
# Fetched 200 properties this batch. Total checked: 89143.
# Fetched 200 properties this batch. Total checked: 89343.
# Fetched 200 properties this batch. Total checked: 89543.
# Fetched 200 properties this batch. Total checked: 89743.
# Fetched 200 properties this batch. Total checked: 89943.
# Fetched 200 properties this batch. Total checked: 90143.
# Fetched 200 properties this batch. Total checked: 90343.
# Fetched 200 properties this batch. Total checked: 90543.
# Fetched 200 properties this batch. Total checked: 90743.
# Fetched 200 properties this batch. Total checked: 90943.
# Fetched 200 properties this batch. Total checked: 91143.
# Fetched 200 properties this batch. Total checked: 91343.
# Fetched 200 properties this batch. Total checked: 91543.
# Fetched 49 properties this batch. Total checked: 91592.
# Total properties in Chicago, IL sold between 2013-01-15 and 2014-01-15: 0
# Total properties in Chicago, IL sold between 2013-01-14 and 2014-01-15: 0
# Total properties in Chicago, IL sold between 2012-01-14 and 2013-01-13: 0
# Total properties in Chicago, IL sold between 2012-01-13 and 2013-01-13: 0
# Total properties in Chicago, IL sold between 2011-01-12 and 2012-01-12: 0
# Total properties in Chicago, IL sold between 2011-01-11 and 2012-01-12: 0
# Total properties in Chicago, IL sold between 2010-01-10 and 2011-01-10: 0
# Total properties in Chicago, IL sold between 2010-01-09 and 2011-01-10: 0
# Total properties in Chicago, IL sold between 2009-01-08 and 2010-01-08: 0
# Total properties in Chicago, IL sold between 2009-01-07 and 2010-01-08: 0
# Total properties in Chicago, IL sold between 2008-01-07 and 2009-01-06: 0
# Total properties in Chicago, IL sold between 2008-01-06 and 2009-01-06: 0
# Total properties in Chicago, IL sold between 2007-01-05 and 2008-01-05: 0
# Total properties in Chicago, IL sold between 2007-01-04 and 2008-01-05: 0
# Total properties in Chicago, IL sold between 2006-01-03 and 2007-01-03: 0
# Total properties in Chicago, IL sold between 2006-01-02 and 2007-01-03: 0
# Total properties in Chicago, IL sold between 2005-01-01 and 2006-01-01: 0
# Total properties in Chicago, IL sold between 2004-12-31 and 2006-01-01: 0
# Total properties in Chicago, IL sold between 2003-12-31 and 2004-12-30: 0
# Total properties in Chicago, IL sold between 2003-12-30 and 2004-12-30: 0
# Total properties in Chicago, IL sold between 2002-12-29 and 2003-12-29: 0
# Total properties in Chicago, IL sold between 2002-12-28 and 2003-12-29: 0
# Total properties in Chicago, IL sold between 2001-12-27 and 2002-12-27: 0
# Total properties in Chicago, IL sold between 2001-12-26 and 2002-12-27: 0
# Total properties in Chicago, IL sold between 2000-12-25 and 2001-12-25: 0
# Total properties in Chicago, IL sold between 2000-12-24 and 2001-12-25: 0
# Total properties in Chicago, IL sold between 1999-12-24 and 2000-12-23: 0
# Total properties in Chicago, IL sold between 1999-12-23 and 2000-12-23: 0
# Total properties in Chicago, IL sold between 1998-12-22 and 1999-12-22: 0
# Total properties in Chicago, IL sold between 1998-12-21 and 1999-12-22: 0
# Total properties in Chicago, IL sold between 1997-12-20 and 1998-12-20: 0
# Total properties in Chicago, IL sold between 1997-12-19 and 1998-12-20: 0
# Total properties in Chicago, IL sold between 1996-12-18 and 1997-12-18: 0
# Total properties in Chicago, IL sold between 1996-12-17 and 1997-12-18: 0
# Total properties in Chicago, IL sold between 1995-12-17 and 1996-12-16: 0
# Total properties in Chicago, IL sold between 1995-12-16 and 1996-12-16: 0
# Total properties in Chicago, IL sold between 1994-12-15 and 1995-12-15: 0
# Total properties in Chicago, IL sold between 1994-12-14 and 1995-12-15: 0
# Done fetching 91592 sold properties in Chicago since 1995-01.
# Total properties available for sale in New York, NY: 4802
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 200.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 400.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 600.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 800.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 1000.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 1200.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 1400.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 1600.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 1800.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 2000.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 2200.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 2400.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 2600.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 2800.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 3000.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 3200.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 3400.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 3600.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 3800.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 4000.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 4200.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 4400.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 4600.
# Fetched 200 selling properties currently. Total available: 4802. Total checked: 4800.
# Fetched 2 selling properties currently. Total available: 4802. Total checked: 4802.
# Done fetching 4802 properties selling in New York.
# Total properties in New York, NY sold between 2023-07-06 and 2024-07-05: 4214
# Total properties in New York, NY sold between 2023-07-05 and 2024-07-05: 4236
# Total properties in New York, NY sold between 2023-07-04 and 2024-07-05: 4236
# Fetched 200 properties this batch. Total checked: 200.
# Fetched 200 properties this batch. Total checked: 400.
# Fetched 200 properties this batch. Total checked: 600.
# Fetched 200 properties this batch. Total checked: 800.
# Fetched 200 properties this batch. Total checked: 1000.
# Fetched 200 properties this batch. Total checked: 1200.
# Fetched 200 properties this batch. Total checked: 1400.
# Fetched 200 properties this batch. Total checked: 1600.
# Fetched 200 properties this batch. Total checked: 1800.
# Fetched 200 properties this batch. Total checked: 2000.
# Fetched 200 properties this batch. Total checked: 2200.
# Fetched 200 properties this batch. Total checked: 2400.
# Fetched 200 properties this batch. Total checked: 2600.
# Fetched 200 properties this batch. Total checked: 2800.
# Fetched 200 properties this batch. Total checked: 3000.
# Fetched 200 properties this batch. Total checked: 3200.
# Fetched 200 properties this batch. Total checked: 3400.
# Fetched 200 properties this batch. Total checked: 3600.
# Fetched 200 properties this batch. Total checked: 3800.
# Fetched 200 properties this batch. Total checked: 4000.
# Fetched 200 properties this batch. Total checked: 4200.
# Fetched 36 properties this batch. Total checked: 4236.
# Total properties in New York, NY sold between 2022-07-03 and 2023-07-03: 8239
# Total properties in New York, NY sold between 2022-07-02 and 2023-07-03: 8243
# Total properties in New York, NY sold between 2022-07-01 and 2023-07-03: 8299
# Total properties in New York, NY sold between 2022-06-30 and 2023-07-03: 8383
# Total properties in New York, NY sold between 2022-06-29 and 2023-07-03: 8468
# Total properties in New York, NY sold between 2022-06-28 and 2023-07-03: 8519
# Total properties in New York, NY sold between 2022-06-27 and 2023-07-03: 8561
# Total properties in New York, NY sold between 2022-06-26 and 2023-07-03: 8561
# Fetched 200 properties this batch. Total checked: 4436.
# Fetched 200 properties this batch. Total checked: 4636.
# Fetched 200 properties this batch. Total checked: 4836.
# Fetched 200 properties this batch. Total checked: 5036.
# Fetched 200 properties this batch. Total checked: 5236.
# Fetched 200 properties this batch. Total checked: 5436.
# Fetched 200 properties this batch. Total checked: 5636.
# Fetched 200 properties this batch. Total checked: 5836.
# Fetched 200 properties this batch. Total checked: 6036.
# Fetched 200 properties this batch. Total checked: 6236.
# Fetched 200 properties this batch. Total checked: 6436.
# Fetched 200 properties this batch. Total checked: 6636.
# Fetched 200 properties this batch. Total checked: 6836.
# Fetched 200 properties this batch. Total checked: 7036.
# Fetched 200 properties this batch. Total checked: 7236.
# Fetched 200 properties this batch. Total checked: 7436.
# Fetched 200 properties this batch. Total checked: 7636.
# Fetched 200 properties this batch. Total checked: 7836.
# Fetched 200 properties this batch. Total checked: 8036.
# Fetched 200 properties this batch. Total checked: 8236.
# Fetched 200 properties this batch. Total checked: 8436.
# Fetched 200 properties this batch. Total checked: 8636.
# Fetched 200 properties this batch. Total checked: 8836.
# Fetched 200 properties this batch. Total checked: 9036.
# Fetched 200 properties this batch. Total checked: 9236.
# Fetched 200 properties this batch. Total checked: 9436.
# Fetched 200 properties this batch. Total checked: 9636.
# Fetched 200 properties this batch. Total checked: 9836.
# Fetched 200 properties this batch. Total checked: 10036.
# Fetched 200 properties this batch. Total checked: 10236.
# Fetched 200 properties this batch. Total checked: 10436.
# Fetched 200 properties this batch. Total checked: 10636.
# Fetched 200 properties this batch. Total checked: 10836.
# Fetched 200 properties this batch. Total checked: 11036.
# Fetched 200 properties this batch. Total checked: 11236.
# Fetched 200 properties this batch. Total checked: 11436.
# Fetched 200 properties this batch. Total checked: 11636.
# Fetched 200 properties this batch. Total checked: 11836.
# Fetched 200 properties this batch. Total checked: 12036.
# Fetched 200 properties this batch. Total checked: 12236.
# Fetched 200 properties this batch. Total checked: 12436.
# Fetched 200 properties this batch. Total checked: 12636.
# Fetched 161 properties this batch. Total checked: 12797.
# Total properties in New York, NY sold between 2021-06-25 and 2022-06-25: 11718
# Total properties in New York, NY sold between 2021-07-25 and 2022-06-25: 10652
# Total properties in New York, NY sold between 2021-08-24 and 2022-06-25: 9554
# Total properties in New York, NY sold between 2021-08-23 and 2022-06-25: 9595
# Total properties in New York, NY sold between 2021-08-22 and 2022-06-25: 9596
# Total properties in New York, NY sold between 2021-08-21 and 2022-06-25: 9597
# Total properties in New York, NY sold between 2021-08-20 and 2022-06-25: 9645
# Total properties in New York, NY sold between 2021-08-19 and 2022-06-25: 9698
# Total properties in New York, NY sold between 2021-08-18 and 2022-06-25: 9741
# Total properties in New York, NY sold between 2021-08-17 and 2022-06-25: 9788
# Total properties in New York, NY sold between 2021-08-16 and 2022-06-25: 9849
# Total properties in New York, NY sold between 2021-08-15 and 2022-06-25: 9849
# Fetched 200 properties this batch. Total checked: 12997.
# Fetched 200 properties this batch. Total checked: 13197.
# Fetched 200 properties this batch. Total checked: 13397.
# Fetched 200 properties this batch. Total checked: 13597.
# Fetched 200 properties this batch. Total checked: 13797.
# Fetched 200 properties this batch. Total checked: 13997.
# Fetched 200 properties this batch. Total checked: 14197.
# Fetched 200 properties this batch. Total checked: 14397.
# Fetched 200 properties this batch. Total checked: 14597.
# Fetched 200 properties this batch. Total checked: 14797.
# Fetched 200 properties this batch. Total checked: 14997.
# Fetched 200 properties this batch. Total checked: 15197.
# Fetched 200 properties this batch. Total checked: 15397.
# Fetched 200 properties this batch. Total checked: 15597.
# Fetched 200 properties this batch. Total checked: 15797.
# Fetched 200 properties this batch. Total checked: 15997.
# Fetched 200 properties this batch. Total checked: 16197.
# Fetched 200 properties this batch. Total checked: 16397.
# Fetched 200 properties this batch. Total checked: 16597.
# Fetched 200 properties this batch. Total checked: 16797.
# Fetched 200 properties this batch. Total checked: 16997.
# Fetched 200 properties this batch. Total checked: 17197.
# Fetched 200 properties this batch. Total checked: 17397.
# Fetched 200 properties this batch. Total checked: 17597.
# Fetched 200 properties this batch. Total checked: 17797.
# Fetched 200 properties this batch. Total checked: 17997.
# Fetched 200 properties this batch. Total checked: 18197.
# Fetched 200 properties this batch. Total checked: 18397.
# Fetched 200 properties this batch. Total checked: 18597.
# Fetched 200 properties this batch. Total checked: 18797.
# Fetched 200 properties this batch. Total checked: 18997.
# Fetched 200 properties this batch. Total checked: 19197.
# Fetched 200 properties this batch. Total checked: 19397.
# Fetched 200 properties this batch. Total checked: 19597.
# Fetched 200 properties this batch. Total checked: 19797.
# Fetched 200 properties this batch. Total checked: 19997.
# Fetched 200 properties this batch. Total checked: 20197.
# Fetched 200 properties this batch. Total checked: 20397.
# Fetched 200 properties this batch. Total checked: 20597.
# Fetched 200 properties this batch. Total checked: 20797.
# Fetched 200 properties this batch. Total checked: 20997.
# Fetched 200 properties this batch. Total checked: 21197.
# Fetched 200 properties this batch. Total checked: 21397.
# Fetched 200 properties this batch. Total checked: 21597.
# Fetched 200 properties this batch. Total checked: 21797.
# Fetched 200 properties this batch. Total checked: 21997.
# Fetched 200 properties this batch. Total checked: 22197.
# Fetched 200 properties this batch. Total checked: 22397.
# Fetched 200 properties this batch. Total checked: 22597.
# Fetched 49 properties this batch. Total checked: 22646.
# Total properties in New York, NY sold between 2020-08-14 and 2021-08-14: 10502
# Total properties in New York, NY sold between 2020-09-13 and 2021-08-14: 10022
# Total properties in New York, NY sold between 2020-10-13 and 2021-08-14: 9389
# Total properties in New York, NY sold between 2020-10-12 and 2021-08-14: 9394
# Total properties in New York, NY sold between 2020-10-11 and 2021-08-14: 9394
# Fetched 200 properties this batch. Total checked: 22846.
# Fetched 200 properties this batch. Total checked: 23046.
# Fetched 200 properties this batch. Total checked: 23246.
# Fetched 200 properties this batch. Total checked: 23446.
# Fetched 200 properties this batch. Total checked: 23646.
# Fetched 200 properties this batch. Total checked: 23846.
# Fetched 200 properties this batch. Total checked: 24046.
# Fetched 200 properties this batch. Total checked: 24246.
# Fetched 200 properties this batch. Total checked: 24446.
# Fetched 200 properties this batch. Total checked: 24646.
# Fetched 200 properties this batch. Total checked: 24846.
# Fetched 200 properties this batch. Total checked: 25046.
# Fetched 200 properties this batch. Total checked: 25246.
# Fetched 200 properties this batch. Total checked: 25446.
# Fetched 200 properties this batch. Total checked: 25646.
# Fetched 200 properties this batch. Total checked: 25846.
# Fetched 200 properties this batch. Total checked: 26046.
# Fetched 200 properties this batch. Total checked: 26246.
# Fetched 200 properties this batch. Total checked: 26446.
# Fetched 200 properties this batch. Total checked: 26646.
# Fetched 200 properties this batch. Total checked: 26846.
# Fetched 200 properties this batch. Total checked: 27046.
# Fetched 200 properties this batch. Total checked: 27246.
# Fetched 200 properties this batch. Total checked: 27446.
# Fetched 200 properties this batch. Total checked: 27646.
# Fetched 200 properties this batch. Total checked: 27846.
# Fetched 200 properties this batch. Total checked: 28046.
# Fetched 200 properties this batch. Total checked: 28246.
# Fetched 200 properties this batch. Total checked: 28446.
# Fetched 200 properties this batch. Total checked: 28646.
# Fetched 200 properties this batch. Total checked: 28846.
# Fetched 200 properties this batch. Total checked: 29046.
# Fetched 200 properties this batch. Total checked: 29246.
# ...
# Fetched 200 properties this batch. Total checked: 44212.
# Fetched 200 properties this batch. Total checked: 44412.
# Fetched 200 properties this batch. Total checked: 44612.
# Fetched 200 properties this batch. Total checked: 44812.
# Fetched 200 properties this batch. Total checked: 45012.
# Fetched 200 properties this batch. Total checked: 45212.
# Fetched 200 properties this batch. Total checked: 45412.
# Fetched 200 properties this batch. Total checked: 45612.
# Fetched 200 properties this batch. Total checked: 45812.
# Fetched 200 properties this batch. Total checked: 46012.
# Fetched 200 properties this batch. Total checked: 46212.
# Fetched 158 properties this batch. Total checked: 46370.
# Total properties in New York, NY sold between 2017-09-29 and 2018-09-29: 8521
# Total properties in New York, NY sold between 2017-09-28 and 2018-09-29: 8553
# Total properties in New York, NY sold between 2017-09-27 and 2018-09-29: 8573
# Total properties in New York, NY sold between 2017-09-26 and 2018-09-29: 8611
# Total properties in New York, NY sold between 2017-09-25 and 2018-09-29: 8650
# Total properties in New York, NY sold between 2017-09-24 and 2018-09-29: 8650
# Fetched 200 properties this batch. Total checked: 46570.
# Fetched 200 properties this batch. Total checked: 46770.
# Fetched 200 properties this batch. Total checked: 46970.
# Fetched 200 properties this batch. Total checked: 47170.
# Fetched 200 properties this batch. Total checked: 47370.
# Fetched 200 properties this batch. Total checked: 47570.
# Fetched 200 properties this batch. Total checked: 47770.
# Fetched 200 properties this batch. Total checked: 47970.
# Fetched 200 properties this batch. Total checked: 48170.
# Fetched 200 properties this batch. Total checked: 48370.
# Fetched 200 properties this batch. Total checked: 48570.
# Fetched 200 properties this batch. Total checked: 48770.
# Fetched 200 properties this batch. Total checked: 48970.
# Fetched 200 properties this batch. Total checked: 49170.
# Fetched 200 properties this batch. Total checked: 49370.
# Fetched 200 properties this batch. Total checked: 49570.
# Fetched 200 properties this batch. Total checked: 49770.
# Fetched 200 properties this batch. Total checked: 49970.
# Fetched 200 properties this batch. Total checked: 50170.
# Fetched 200 properties this batch. Total checked: 50370.
# Fetched 200 properties this batch. Total checked: 50570.
# Fetched 200 properties this batch. Total checked: 50770.
# Fetched 200 properties this batch. Total checked: 50970.
# Fetched 200 properties this batch. Total checked: 51170.
# Fetched 200 properties this batch. Total checked: 51370.
# Fetched 200 properties this batch. Total checked: 51570.
# Fetched 200 properties this batch. Total checked: 51770.
# Fetched 200 properties this batch. Total checked: 51970.
# Fetched 200 properties this batch. Total checked: 52170.
# Fetched 200 properties this batch. Total checked: 52370.
# Fetched 200 properties this batch. Total checked: 52570.
# Fetched 200 properties this batch. Total checked: 52770.
# Fetched 200 properties this batch. Total checked: 52970.
# Fetched 200 properties this batch. Total checked: 53170.
# Fetched 200 properties this batch. Total checked: 53370.
# Fetched 200 properties this batch. Total checked: 53570.
# Fetched 200 properties this batch. Total checked: 53770.
# Fetched 200 properties this batch. Total checked: 53970.
# Fetched 200 properties this batch. Total checked: 54170.
# Fetched 200 properties this batch. Total checked: 54370.
# Fetched 200 properties this batch. Total checked: 54570.
# Fetched 200 properties this batch. Total checked: 54770.
# Fetched 200 properties this batch. Total checked: 54970.
# Fetched 50 properties this batch. Total checked: 55020.
# Total properties in New York, NY sold between 2016-09-23 and 2017-09-23: 8452
# Total properties in New York, NY sold between 2016-09-22 and 2017-09-23: 8484
# Total properties in New York, NY sold between 2016-09-21 and 2017-09-23: 8527
# Total properties in New York, NY sold between 2016-09-20 and 2017-09-23: 8564
# Total properties in New York, NY sold between 2016-09-19 and 2017-09-23: 8593
# Total properties in New York, NY sold between 2016-09-18 and 2017-09-23: 8593
# Fetched 200 properties this batch. Total checked: 55220.
# Fetched 200 properties this batch. Total checked: 55420.
# Fetched 200 properties this batch. Total checked: 55620.
# Fetched 200 properties this batch. Total checked: 55820.
# Fetched 200 properties this batch. Total checked: 56020.
# Fetched 200 properties this batch. Total checked: 56220.
# Fetched 200 properties this batch. Total checked: 56420.
# Fetched 200 properties this batch. Total checked: 56620.
# Fetched 200 properties this batch. Total checked: 56820.
# Fetched 200 properties this batch. Total checked: 57020.
# Fetched 200 properties this batch. Total checked: 57220.
# Fetched 200 properties this batch. Total checked: 57420.
# Fetched 200 properties this batch. Total checked: 57620.
# Fetched 200 properties this batch. Total checked: 57820.
# Fetched 200 properties this batch. Total checked: 58020.
# Fetched 200 properties this batch. Total checked: 58220.
# Fetched 200 properties this batch. Total checked: 58420.
# Fetched 200 properties this batch. Total checked: 58620.
# Fetched 200 properties this batch. Total checked: 58820.
# Fetched 200 properties this batch. Total checked: 59020.
# Fetched 200 properties this batch. Total checked: 59220.
# Fetched 200 properties this batch. Total checked: 59420.
# Fetched 200 properties this batch. Total checked: 59620.
# Fetched 200 properties this batch. Total checked: 59820.
# Fetched 200 properties this batch. Total checked: 60020.
# Fetched 200 properties this batch. Total checked: 60220.
# Fetched 200 properties this batch. Total checked: 60420.
# Fetched 200 properties this batch. Total checked: 60620.
# Fetched 200 properties this batch. Total checked: 60820.
# Fetched 200 properties this batch. Total checked: 61020.
# Fetched 200 properties this batch. Total checked: 61220.
# Fetched 200 properties this batch. Total checked: 61420.
# Fetched 200 properties this batch. Total checked: 61620.
# Fetched 200 properties this batch. Total checked: 61820.
# Fetched 200 properties this batch. Total checked: 62020.
# Fetched 200 properties this batch. Total checked: 62220.
# Fetched 200 properties this batch. Total checked: 62420.
# Fetched 200 properties this batch. Total checked: 62620.
# Fetched 200 properties this batch. Total checked: 62820.
# Fetched 200 properties this batch. Total checked: 63020.
# Fetched 200 properties this batch. Total checked: 63220.
# Fetched 200 properties this batch. Total checked: 63420.
# Fetched 193 properties this batch. Total checked: 63613.
# Total properties in New York, NY sold between 2015-09-18 and 2016-09-17: 8036
# Total properties in New York, NY sold between 2015-09-17 and 2016-09-17: 8080
# Total properties in New York, NY sold between 2015-09-16 and 2016-09-17: 8133
# Total properties in New York, NY sold between 2015-09-15 and 2016-09-17: 8171
# Total properties in New York, NY sold between 2015-09-14 and 2016-09-17: 8210
# Total properties in New York, NY sold between 2015-09-13 and 2016-09-17: 8210
# Fetched 200 properties this batch. Total checked: 63813.
# Fetched 200 properties this batch. Total checked: 64013.
# Fetched 200 properties this batch. Total checked: 64213.
# Fetched 200 properties this batch. Total checked: 64413.
# Fetched 200 properties this batch. Total checked: 64613.
# Fetched 200 properties this batch. Total checked: 64813.
# Fetched 200 properties this batch. Total checked: 65013.
# Fetched 200 properties this batch. Total checked: 65213.
# Fetched 200 properties this batch. Total checked: 65413.
# Fetched 200 properties this batch. Total checked: 65613.
# Fetched 200 properties this batch. Total checked: 65813.
# Fetched 200 properties this batch. Total checked: 66013.
# Fetched 200 properties this batch. Total checked: 66213.
# Fetched 200 properties this batch. Total checked: 66413.
# Fetched 200 properties this batch. Total checked: 66613.
# Fetched 200 properties this batch. Total checked: 66813.
# Fetched 200 properties this batch. Total checked: 67013.
# Fetched 200 properties this batch. Total checked: 67213.
# Fetched 200 properties this batch. Total checked: 67413.
# Fetched 200 properties this batch. Total checked: 67613.
# Fetched 200 properties this batch. Total checked: 67813.
# Fetched 200 properties this batch. Total checked: 68013.
# Fetched 200 properties this batch. Total checked: 68213.
# Fetched 200 properties this batch. Total checked: 68413.
# Fetched 200 properties this batch. Total checked: 68613.
# Fetched 200 properties this batch. Total checked: 68813.
# Fetched 200 properties this batch. Total checked: 69013.
# Fetched 200 properties this batch. Total checked: 69213.
# Fetched 200 properties this batch. Total checked: 69413.
# Fetched 200 properties this batch. Total checked: 69613.
# Fetched 200 properties this batch. Total checked: 69813.
# Fetched 200 properties this batch. Total checked: 70013.
# Fetched 200 properties this batch. Total checked: 70213.
# Fetched 200 properties this batch. Total checked: 70413.
# Fetched 200 properties this batch. Total checked: 70613.
# Fetched 200 properties this batch. Total checked: 70813.
# Fetched 200 properties this batch. Total checked: 71013.
# Fetched 200 properties this batch. Total checked: 71213.
# Fetched 200 properties this batch. Total checked: 71413.
# Fetched 200 properties this batch. Total checked: 71613.
# Fetched 200 properties this batch. Total checked: 71813.
# Fetched 10 properties this batch. Total checked: 71823.
# Total properties in New York, NY sold between 2014-09-12 and 2015-09-12: 7001
# Total properties in New York, NY sold between 2014-09-11 and 2015-09-12: 7025
# Total properties in New York, NY sold between 2014-09-10 and 2015-09-12: 7047
# Total properties in New York, NY sold between 2014-09-09 and 2015-09-12: 7067
# Total properties in New York, NY sold between 2014-09-08 and 2015-09-12: 7089
# Total properties in New York, NY sold between 2014-09-07 and 2015-09-12: 7090
# Total properties in New York, NY sold between 2014-09-06 and 2015-09-12: 7091
# Total properties in New York, NY sold between 2014-09-05 and 2015-09-12: 7117
# Total properties in New York, NY sold between 2014-09-04 and 2015-09-12: 7140
# Total properties in New York, NY sold between 2014-09-03 and 2015-09-12: 7171
# Total properties in New York, NY sold between 2014-09-02 and 2015-09-12: 7192
# Total properties in New York, NY sold between 2014-09-01 and 2015-09-12: 7195
# Total properties in New York, NY sold between 2014-08-31 and 2015-09-12: 7195
# Fetched 200 properties this batch. Total checked: 72023.
# Fetched 200 properties this batch. Total checked: 72223.
# Fetched 200 properties this batch. Total checked: 72423.
# Fetched 200 properties this batch. Total checked: 72623.
# Fetched 200 properties this batch. Total checked: 72823.
# Fetched 200 properties this batch. Total checked: 73023.
# Fetched 200 properties this batch. Total checked: 73223.
# Fetched 200 properties this batch. Total checked: 73423.
# Fetched 200 properties this batch. Total checked: 73623.
# Fetched 200 properties this batch. Total checked: 73823.
# Fetched 200 properties this batch. Total checked: 74023.
# Fetched 200 properties this batch. Total checked: 74223.
# Fetched 200 properties this batch. Total checked: 74423.
# Fetched 200 properties this batch. Total checked: 74623.
# Fetched 200 properties this batch. Total checked: 74823.
# Fetched 200 properties this batch. Total checked: 75023.
# Fetched 200 properties this batch. Total checked: 75223.
# Fetched 200 properties this batch. Total checked: 75423.
# Fetched 200 properties this batch. Total checked: 75623.
# Fetched 200 properties this batch. Total checked: 75823.
# Fetched 200 properties this batch. Total checked: 76023.
# Fetched 200 properties this batch. Total checked: 76223.
# Fetched 200 properties this batch. Total checked: 76423.
# Fetched 200 properties this batch. Total checked: 76623.
# Fetched 200 properties this batch. Total checked: 76823.
# Fetched 200 properties this batch. Total checked: 77023.
# Fetched 200 properties this batch. Total checked: 77223.
# Fetched 200 properties this batch. Total checked: 77423.
# Fetched 200 properties this batch. Total checked: 77623.
# Fetched 200 properties this batch. Total checked: 77823.
# Fetched 200 properties this batch. Total checked: 78023.
# Fetched 200 properties this batch. Total checked: 78223.
# Fetched 200 properties this batch. Total checked: 78423.
# Fetched 200 properties this batch. Total checked: 78623.
# Fetched 200 properties this batch. Total checked: 78823.
# Fetched 195 properties this batch. Total checked: 79018.
# Total properties in New York, NY sold between 2013-08-30 and 2014-08-30: 1313
# Total properties in New York, NY sold between 2013-08-29 and 2014-08-30: 1313
# Fetched 200 properties this batch. Total checked: 79218.
# Fetched 200 properties this batch. Total checked: 79418.
# Fetched 200 properties this batch. Total checked: 79618.
# Fetched 200 properties this batch. Total checked: 79818.
# Fetched 200 properties this batch. Total checked: 80018.
# Fetched 200 properties this batch. Total checked: 80218.
# Fetched 113 properties this batch. Total checked: 80331.
# Total properties in New York, NY sold between 2012-08-28 and 2013-08-28: 0
# Total properties in New York, NY sold between 2012-08-27 and 2013-08-28: 0
# Total properties in New York, NY sold between 2011-08-27 and 2012-08-26: 0
# Total properties in New York, NY sold between 2011-08-26 and 2012-08-26: 0
# Total properties in New York, NY sold between 2010-08-25 and 2011-08-25: 0
# Total properties in New York, NY sold between 2010-08-24 and 2011-08-25: 0
# Total properties in New York, NY sold between 2009-08-23 and 2010-08-23: 0
# Total properties in New York, NY sold between 2009-08-22 and 2010-08-23: 0
# Total properties in New York, NY sold between 2008-08-21 and 2009-08-21: 0
# Total properties in New York, NY sold between 2008-08-20 and 2009-08-21: 0
# Total properties in New York, NY sold between 2007-08-20 and 2008-08-19: 0
# Total properties in New York, NY sold between 2007-08-19 and 2008-08-19: 0
# Total properties in New York, NY sold between 2006-08-18 and 2007-08-18: 0
# Total properties in New York, NY sold between 2006-08-17 and 2007-08-18: 0
# Total properties in New York, NY sold between 2005-08-16 and 2006-08-16: 0
# Total properties in New York, NY sold between 2005-08-15 and 2006-08-16: 0
# Total properties in New York, NY sold between 2004-08-14 and 2005-08-14: 0
# Total properties in New York, NY sold between 2004-08-13 and 2005-08-14: 0
# Total properties in New York, NY sold between 2003-08-13 and 2004-08-12: 0
# Total properties in New York, NY sold between 2003-08-12 and 2004-08-12: 0
# Total properties in New York, NY sold between 2002-08-11 and 2003-08-11: 0
# Total properties in New York, NY sold between 2002-08-10 and 2003-08-11: 0
# Total properties in New York, NY sold between 2001-08-09 and 2002-08-09: 0
# Total properties in New York, NY sold between 2001-08-08 and 2002-08-09: 0
# Total properties in New York, NY sold between 2000-08-07 and 2001-08-07: 0
# Total properties in New York, NY sold between 2000-08-06 and 2001-08-07: 0
# Total properties in New York, NY sold between 1999-08-06 and 2000-08-05: 0
# Total properties in New York, NY sold between 1999-08-05 and 2000-08-05: 0
# Total properties in New York, NY sold between 1998-08-04 and 1999-08-04: 0
# Total properties in New York, NY sold between 1998-08-03 and 1999-08-04: 0
# Total properties in New York, NY sold between 1997-08-02 and 1998-08-02: 0
# Total properties in New York, NY sold between 1997-08-01 and 1998-08-02: 0
# Total properties in New York, NY sold between 1996-07-31 and 1997-07-31: 0
# Total properties in New York, NY sold between 1996-07-30 and 1997-07-31: 0
# Total properties in New York, NY sold between 1995-07-30 and 1996-07-29: 0
# Total properties in New York, NY sold between 1995-07-29 and 1996-07-29: 0
# Total properties in New York, NY sold between 1994-07-28 and 1995-07-28: 0
# Total properties in New York, NY sold between 1994-07-27 and 1995-07-28: 0
# Done fetching 80331 sold properties in New York since 1995-01.

# %%
chicago_json = chicago_data['properties']
chicago_selling = pd.DataFrame(chicago_json)
chicago_selling.head()
# Out:
#   property_id  list_price search_promotions  \
# 0  7109976785    215000.0              None
# 1  9462841010    340000.0              None
# 2  8027933003     79000.0              None
# 3  8854936353   1200000.0              None
# 4  7106444683   1075000.0              None
#
#                                        primary_photo rent_to_own  listing_id  \
# 0  {'href': 'https://ap.rdcpix.com/696e87b0527eda...        None  2966364640
# 1  {'href': 'https://ap.rdcpix.com/82ea120aaba299...        None  2968097446
# 2  {'href': 'https://ap.rdcpix.com/0bc6e301b88c58...        None  2969198384
# 3  {'href': 'https://ap.rdcpix.com/d8974be7019906...        None  2968439242
# 4  {'href': 'https://ap.rdcpix.com/4277ca39b90981...        None  2969200826
#
#    matterport                                      virtual_tours    status  \
# 0       False                                               None  for_sale
# 1       False  [{'href': 'https://kuula.co/share/5vfHt/collec...  for_sale
# 2       False                                               None  for_sale
# 3       False                                               None  for_sale
# 4       False                                               None  for_sale
#
#                                             products  ...  \
# 0  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 1  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 2  {'products': ['core.agent', 'core.broker', 'co...  ...
# 3  {'products': ['core.agent', 'core.broker', 'co...  ...
# 4  {'products': ['core.agent', 'co_broke'], 'bran...  ...
#
#                                            permalink price_reduced_amount  \
# 0    9906-S-Seeley-Ave_Chicago_IL_60643_M71099-76785                  NaN
# 1   650-N-Ridgeway-Ave_Chicago_IL_60624_M94628-41010                  NaN
# 2    11549-S-Church-St_Chicago_IL_60643_M80279-33003                  NaN
# 3    3015-N-Racine-Ave_Chicago_IL_60657_M88549-36353                  NaN
# 4  1316-N-Campbell-Ave_Chicago_IL_60622_M71064-44683                  NaN
#
#                                          description  \
# 0  {'name': None, 'beds': 3, 'baths_consolidated'...
# 1  {'name': None, 'beds': 3, 'baths_consolidated'...
# 2  {'name': None, 'beds': 4, 'baths_consolidated'...
# 3  {'name': None, 'beds': 4, 'baths_consolidated'...
# 4  {'name': None, 'beds': 3, 'baths_consolidated'...
#
#                                             location  open_houses  \
# 0  {'street_view_url': 'https://maps.googleapis.c...         None
# 1  {'street_view_url': 'https://maps.googleapis.c...         None
# 2  {'street_view_url': 'https://maps.googleapis.c...         None
# 3  {'street_view_url': 'https://maps.googleapis.c...         None
# 4  {'street_view_url': 'https://maps.googleapis.c...         None
#
#                                             branding  \
# 0  [{'type': 'Office', 'name': 'P.R.S. Associates...
# 1  [{'type': 'Office', 'name': 'Inherent Homes LL...
# 2  [{'type': 'Office', 'name': '@properties East ...
# 3  [{'type': 'Office', 'name': 'Dream Town Realty...
# 4  [{'type': 'Office', 'name': 'Cl3 Property Mana...
#
#                                                flags  \
# 0  {'is_coming_soon': None, 'is_new_listing': Fal...
# 1  {'is_coming_soon': None, 'is_new_listing': Fal...
# 2  {'is_coming_soon': None, 'is_new_listing': Tru...
# 3  {'is_coming_soon': None, 'is_new_listing': Tru...
# 4  {'is_coming_soon': None, 'is_new_listing': Tru...
#
#                      list_date  \
# 0  2024-04-18T17:33:51.000000Z
# 1  2024-06-03T19:03:15.000000Z
# 2  2024-07-03T22:27:08.000000Z
# 3  2024-07-04T01:36:50.000000Z
# 4  2024-07-04T00:06:40.000000Z
#
#                                               photos  \
# 0  [{'href': 'https://ap.rdcpix.com/696e87b0527ed...
# 1  [{'href': 'https://ap.rdcpix.com/82ea120aaba29...
# 2  [{'href': 'https://ap.rdcpix.com/0bc6e301b88c5...
# 3  [{'href': 'https://ap.rdcpix.com/d8974be701990...
# 4  [{'href': 'https://ap.rdcpix.com/4277ca39b9098...
#
#                              advertisers
# 0  [{'type': 'seller', 'builder': None}]
# 1  [{'type': 'seller', 'builder': None}]
# 2  [{'type': 'seller', 'builder': None}]
# 3  [{'type': 'seller', 'builder': None}]
# 4  [{'type': 'seller', 'builder': None}]
#
# [5 rows x 23 columns]

# %%
chicago_sold_json = chicago_data_sold['properties']
chicago_sold = pd.DataFrame(chicago_sold_json)
chicago_sold.head()
# Out:
#   property_id  list_price search_promotions  \
# 0  7638203850    250000.0              None
# 1  7712196342    149999.0              None
# 2  9484646484    950000.0              None
# 3  7710814353    168900.0              None
# 4  7259996874    155000.0              None
#
#                                        primary_photo rent_to_own  listing_id  \
# 0  {'href': 'https://ap.rdcpix.com/6b035feede013a...        None  2967945980
# 1  {'href': 'https://ap.rdcpix.com/88e1232627f628...        None  2967011441
# 2  {'href': 'https://ap.rdcpix.com/bc25dbc2800687...        None  2967971895
# 3  {'href': 'https://ap.rdcpix.com/d2c58a877f43a5...        None  2963176312
# 4  {'href': 'https://ap.rdcpix.com/6ad4bc9e3c6a18...        None  2965105516
#
#    matterport                                      virtual_tours status  \
# 0       False  [{'href': 'https://tours.databasedads.com/4605...   sold
# 1       False                                               None   sold
# 2       False                                               None   sold
# 3       False                                               None   sold
# 4       False                                               None   sold
#
#                                             products  ...  \
# 0  {'products': ['core.agent', 'core.broker', 'co...  ...
# 1  {'products': ['core.agent', 'core.broker', 'co...  ...
# 2  {'products': ['core.agent', 'core.broker', 'co...  ...
# 3  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 4  {'products': ['core.agent', 'co_broke'], 'bran...  ...
#
#                                            permalink price_reduced_amount  \
# 0   10330-S-Whipple-St_Chicago_IL_60655_M76382-03850                  NaN
# 1       455-W-126th-Pl_Chicago_IL_60628_M77121-96342                  NaN
# 2  3915-N-Monticello-Ave_Chicago_IL_60618_M94846-...                  NaN
# 3  9416-S-Michigan-Ave_Chicago_IL_60619_M77108-14353                  NaN
# 4  9425-S-Eberhart-Ave_Chicago_IL_60619_M72599-96874               4900.0
#
#                                          description  \
# 0  {'name': None, 'beds': 2, 'baths_consolidated'...
# 1  {'name': None, 'beds': 2, 'baths_consolidated'...
# 2  {'name': None, 'beds': 3, 'baths_consolidated'...
# 3  {'name': None, 'beds': 2, 'baths_consolidated'...
# 4  {'name': None, 'beds': 4, 'baths_consolidated'...
#
#                                             location  open_houses  \
# 0  {'street_view_url': 'https://maps.googleapis.c...         None
# 1  {'street_view_url': 'https://maps.googleapis.c...         None
# 2  {'street_view_url': 'https://maps.googleapis.c...         None
# 3  {'street_view_url': 'https://maps.googleapis.c...         None
# 4  {'street_view_url': 'https://maps.googleapis.c...         None
#
#                                             branding  \
# 0  [{'type': 'Office', 'name': 'Berkshire Hathawa...
# 1  [{'type': 'Office', 'name': 'Chicago - HomeSma...
# 2  [{'type': 'Office', 'name': 'Redfin Corporatio...
# 3  [{'type': 'Office', 'name': 'Coldwell Banker R...
# 4  [{'type': 'Office', 'name': 'HAMPTON REALTY & ...
#
#                                                flags  \
# 0  {'is_coming_soon': None, 'is_new_listing': Fal...
# 1  {'is_coming_soon': None, 'is_new_listing': Fal...
# 2  {'is_coming_soon': None, 'is_new_listing': Fal...
# 3  {'is_coming_soon': None, 'is_new_listing': Fal...
# 4  {'is_coming_soon': None, 'is_new_listing': Fal...
#
#                      list_date  \
# 0  2024-05-30T13:32:07.000000Z
# 1  2024-05-06T17:15:55.000000Z
# 2  2024-05-30T20:38:15.000000Z
# 3  2024-01-13T12:48:41.000000Z
# 4  2024-03-13T23:16:26.000000Z
#
#                                               photos  \
# 0  [{'href': 'https://ap.rdcpix.com/6b035feede013...
# 1  [{'href': 'https://ap.rdcpix.com/88e1232627f62...
# 2  [{'href': 'https://ap.rdcpix.com/bc25dbc280068...
# 3  [{'href': 'https://ap.rdcpix.com/d2c58a877f43a...
# 4  [{'href': 'https://ap.rdcpix.com/6ad4bc9e3c6a1...
#
#                              advertisers
# 0  [{'type': 'seller', 'builder': None}]
# 1  [{'type': 'seller', 'builder': None}]
# 2  [{'type': 'seller', 'builder': None}]
# 3  [{'type': 'seller', 'builder': None}]
# 4  [{'type': 'seller', 'builder': None}]
#
# [5 rows x 23 columns]

# %%
new_york_json = new_york_data['properties']
new_york_selling = pd.DataFrame(new_york_json)
new_york_selling.head()
# Out:
#   property_id  list_price search_promotions  \
# 0  3243883955      260000              None
# 1  3974591407       99000              None
# 2  3536803586      250000              None
# 3  3204384532      275000              None
# 4  3767233034      899000              None
#
#                                        primary_photo rent_to_own  listing_id  \
# 0  {'href': 'https://ap.rdcpix.com/777a0a838fb235...        None  2962223385
# 1  {'href': 'https://ap.rdcpix.com/625c0dbb654a69...        None  2965322798
# 2  {'href': 'https://ap.rdcpix.com/9febd1c13274aa...        None  2961898884
# 3  {'href': 'https://ap.rdcpix.com/bdbd7e0b94a143...        None  2926324318
# 4  {'href': 'https://ap.rdcpix.com/d345414133f77c...        None  2967745369
#
#    matterport                                      virtual_tours    status  \
# 0       False                                               None  for_sale
# 1       False                                               None  for_sale
# 2       False                                               None  for_sale
# 3       False                                               None  for_sale
# 4       False  [{'href': 'https://app.doaudiotours.com/unbran...  for_sale
#
#                                             products  ...  \
# 0  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 1  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 2  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 3  {'products': ['co_broke'], 'brand_name': 'basi...  ...
# 4  {'products': ['core.agent', 'co_broke'], 'bran...  ...
#
#                                            permalink price_reduced_amount  \
# 0  620-Sinclair-Ave_Staten-Island_NY_10312_M32438...                  NaN
# 1   77-City-Blvd_Staten-Island_NY_10301_M39745-91407                  NaN
# 2     24005-147th-Ave_Rosedale_NY_11422_M35368-03586                  NaN
# 3       579-E-29th-St_Brooklyn_NY_11210_M32043-84532                  NaN
# 4  182-Benedict-Ave_Staten-Island_NY_10314_M37672...                  NaN
#
#                                          description  \
# 0  {'name': None, 'beds': 4, 'baths_consolidated'...
# 1  {'name': None, 'beds': 3, 'baths_consolidated'...
# 2  {'name': None, 'beds': 4, 'baths_consolidated'...
# 3  {'name': None, 'beds': 4, 'baths_consolidated'...
# 4  {'name': None, 'beds': 4, 'baths_consolidated'...
#
#                                             location  open_houses  \
# 0  {'street_view_url': 'https://maps.googleapis.c...         None
# 1  {'street_view_url': 'https://maps.googleapis.c...         None
# 2  {'street_view_url': 'https://maps.googleapis.c...         None
# 3  {'street_view_url': 'https://maps.googleapis.c...         None
# 4  {'street_view_url': 'https://maps.googleapis.c...         None
#
#                                             branding  \
# 0  [{'type': 'Office', 'name': 'Sowae Corp', 'pho...
# 1  [{'type': 'Office', 'name': 'NYC SHORT SALES B...
# 2  [{'type': 'Office', 'name': 'Sowae Corp', 'pho...
# 3  [{'type': 'Office', 'name': 'ONLY NINE REALTY ...
# 4  [{'type': 'Office', 'name': 'Staten Island Pre...
#
#                                                flags  \
# 0  {'is_coming_soon': None, 'is_new_listing': Fal...
# 1  {'is_coming_soon': None, 'is_new_listing': Fal...
# 2  {'is_coming_soon': None, 'is_new_listing': Fal...
# 3  {'is_coming_soon': None, 'is_new_listing': Fal...
# 4  {'is_coming_soon': None, 'is_new_listing': Fal...
#
#                      list_date  \
# 0  2023-12-04T23:24:59.000000Z
# 1  2024-03-20T18:26:05.000000Z
# 2  2023-11-21T20:27:17.000000Z
# 3  2021-02-24T19:23:01.000000Z
# 4  2024-05-24T18:45:25.000000Z
#
#                                               photos  \
# 0  [{'href': 'https://ap.rdcpix.com/777a0a838fb23...
# 1  [{'href': 'https://ap.rdcpix.com/625c0dbb654a6...
# 2  [{'href': 'https://ap.rdcpix.com/9febd1c13274a...
# 3  [{'href': 'https://ap.rdcpix.com/bdbd7e0b94a14...
# 4  [{'href': 'https://ap.rdcpix.com/d345414133f77...
#
#                              advertisers
# 0  [{'type': 'seller', 'builder': None}]
# 1  [{'type': 'seller', 'builder': None}]
# 2  [{'type': 'seller', 'builder': None}]
# 3  [{'type': 'seller', 'builder': None}]
# 4  [{'type': 'seller', 'builder': None}]
#
# [5 rows x 23 columns]

# %%
new_york_sold_json = new_york_data_sold['properties']
new_york_sold = pd.DataFrame(new_york_sold_json)
new_york_sold.head()
# Out:
#   property_id  list_price search_promotions  \
# 0  4136891435   1500000.0              None
# 1  3476436735    549999.0              None
# 2  4877937449    559000.0              None
# 3  4669261316   1099000.0              None
# 4  4114846597    968000.0              None
#
#                                        primary_photo rent_to_own  listing_id  \
# 0  {'href': 'https://ap.rdcpix.com/1cc7bfa051a25c...        None  2959454563
# 1  {'href': 'https://ap.rdcpix.com/046e20b2fc7528...        None  2965831609
# 2  {'href': 'https://ap.rdcpix.com/f069417e235ee9...        None  2959829830
# 3  {'href': 'https://ap.rdcpix.com/0752b5f9fbeac8...        None  2958513934
# 4  {'href': 'https://ap.rdcpix.com/d2eadd13e0f856...        None  2965127141
#
#    matterport                                      virtual_tours status  \
# 0       False                                               None   sold
# 1       False  [{'href': 'https://youtu.be/yyKSXSQyIFc', 'typ...   sold
# 2       False                                               None   sold
# 3       False                                               None   sold
# 4       False                                               None   sold
#
#                                             products  ...  \
# 0  {'products': ['co_broke'], 'brand_name': 'basi...  ...
# 1  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 2  {'products': ['core.agent', 'co_broke'], 'bran...  ...
# 3  {'products': ['core.agent', 'core.broker', 'li...  ...
# 4  {'products': ['core.agent', 'core.broker', 'co...  ...
#
#                                            permalink price_reduced_amount  \
# 0      1273-E-10th-St_Brooklyn_NY_11230_M41368-91435                  NaN
# 1  274-Dixon-Ave_Staten-Island_NY_10303_M34764-36735                  NaN
# 2     132-Elm-St_Staten-Island_NY_10310_M48779-37449              10000.0
# 3      1714-E-29th-St_Brooklyn_NY_11229_M46692-61316              50000.0
# 4       4744-189th-St_Flushing_NY_11358_M41148-46597              30000.0
#
#                                          description  \
# 0  {'name': None, 'beds': 4, 'baths_consolidated'...
# 1  {'name': None, 'beds': 3, 'baths_consolidated'...
# 2  {'name': None, 'beds': 4, 'baths_consolidated'...
# 3  {'name': None, 'beds': 3, 'baths_consolidated'...
# 4  {'name': None, 'beds': 3, 'baths_consolidated'...
#
#                                             location  open_houses  \
# 0  {'street_view_url': 'https://maps.googleapis.c...         None
# 1  {'street_view_url': 'https://maps.googleapis.c...         None
# 2  {'street_view_url': 'https://maps.googleapis.c...         None
# 3  {'street_view_url': 'https://maps.googleapis.c...         None
# 4  {'street_view_url': 'https://maps.googleapis.c...         None
#
#                                             branding  \
# 0  [{'type': 'Office', 'name': 'BRISMAN REALTY', ...
# 1  [{'type': 'Office', 'name': 'Martino Realty Gr...
# 2  [{'type': 'Office', 'name': 'Coldwell Banker A...
# 3  [{'type': 'Office', 'name': 'RE MAX Edge', 'ph...
# 4  [{'type': 'Office', 'name': 'Maureen Folan R E...
#
#                                                flags  \
# 0  {'is_coming_soon': None, 'is_new_listing': Fal...
# 1  {'is_coming_soon': None, 'is_new_listing': Fal...
# 2  {'is_coming_soon': None, 'is_new_listing': Fal...
# 3  {'is_coming_soon': None, 'is_new_listing': Fal...
# 4  {'is_coming_soon': None, 'is_new_listing': Fal...
#
#                      list_date  \
# 0  2023-09-07T17:45:51.000000Z
# 1  2024-04-05T15:12:40.000000Z
# 2  2023-09-20T15:50:10.000000Z
# 3  2023-08-09T18:18:27.000000Z
# 4  2024-03-14T15:14:11.000000Z
#
#                                               photos  \
# 0  [{'href': 'https://ap.rdcpix.com/1cc7bfa051a25...
# 1  [{'href': 'https://ap.rdcpix.com/046e20b2fc752...
# 2  [{'href': 'https://ap.rdcpix.com/f069417e235ee...
# 3  [{'href': 'https://ap.rdcpix.com/0752b5f9fbeac...
# 4  [{'href': 'https://ap.rdcpix.com/d2eadd13e0f85...
#
#                              advertisers
# 0  [{'type': 'seller', 'builder': None}]
# 1  [{'type': 'seller', 'builder': None}]
# 2  [{'type': 'seller', 'builder': None}]
# 3  [{'type': 'seller', 'builder': None}]
# 4  [{'type': 'seller', 'builder': None}]
#
# [5 rows x 23 columns]

# %%
def extract_data(properties):
    extracted_data = []

    for property in properties:
        id = property.get('property_id', None)
        permalink = property.get('permalink', None)
        post_link = "https://www.realtor.com/realestateandhomes-detail/" + permalink if permalink else None
        price = property.get('list_price', None)

        list_date = property.get('list_date', None)
        list_date = list_date.split('T')[0] if list_date else None

        location = property.get('location', {})
        address_line = location.get('address', {}).get('line', None)
        city = location.get('address', {}).get('city', None)
        state_code = location.get('address', {}).get('state_code', None)
        postal_code = location.get('address', {}).get('postal_code', None)
        address = f"{address_line}, {city}, {state_code} {postal_code}" if all([address_line, city, state_code, postal_code]) else None

        status = property.get('status', None)
        status = status.upper() if status else None

        if status == "SOLD":
            sold_date = property.get('description', {}).get('sold_date', None)
            if list_date and sold_date:
                list_date = datetime.datetime.strptime(list_date, "%Y-%m-%d")
                sold_date = datetime.datetime.strptime(sold_date, "%Y-%m-%d")
                days_until_sold = (sold_date - list_date).days
                sold_date = sold_date.strftime("%Y-%m-%d")
                list_date = list_date.strftime("%Y-%m-%d")
            else:
                days_until_sold = None
        else:
            sold_date = "Not sold yet"
            days_until_sold = "Not sold yet"

        description = property.get('description', {})
        area = description.get('sqft', None)
        bedrooms = description.get('beds', None)
        bathrooms = description.get('baths_consolidated', None)

        coordinate = location.get('address', {}).get('coordinate', None)
        latitude = coordinate['lat'] if coordinate else None
        longitude = coordinate['lon'] if coordinate else None

        extracted_data.append({
            'Data Source': 'https://www.realtor.com/',
            'ID': id,
            'Post link': post_link,
            'List date': list_date,
            'Sold date': sold_date,
            'Days until sold': days_until_sold,
            'Price': price,
            'Address': address,
            'Status': status,
            'Area': area,
            'Bedrooms': bedrooms,
            'Bathrooms': bathrooms,
            'Latitude': latitude,
            'Longitude': longitude
        })

    return extracted_data

batch = [chicago_json, chicago_sold_json, new_york_json, new_york_sold_json]
extracted_batches = [[], [], [], []]

for i, properties in enumerate(batch):
    extracted_batches[i] = extract_data(properties)

# %%
chicago_selling_extracted = pd.DataFrame(extracted_batches[2])
chicago_selling_extracted.head()
# Out:
#                 Data Source          ID  \
# 0  https://www.realtor.com/  3243883955
# 1  https://www.realtor.com/  3974591407
# 2  https://www.realtor.com/  3536803586
# 3  https://www.realtor.com/  3204384532
# 4  https://www.realtor.com/  3767233034
#
#                                            Post link   List date  \
# 0  https://www.realtor.com/realestateandhomes-det...  2023-12-04
# 1  https://www.realtor.com/realestateandhomes-det...  2024-03-20
# 2  https://www.realtor.com/realestateandhomes-det...  2023-11-21
# 3  https://www.realtor.com/realestateandhomes-det...  2021-02-24
# 4  https://www.realtor.com/realestateandhomes-det...  2024-05-24
#
#       Sold date Days until sold   Price  \
# 0  Not sold yet    Not sold yet  260000
# 1  Not sold yet    Not sold yet   99000
# 2  Not sold yet    Not sold yet  250000
# 3  Not sold yet    Not sold yet  275000
# 4  Not sold yet    Not sold yet  899000
#
#                                      Address    Status    Area  Bedrooms  \
# 0  620 Sinclair Ave, Staten Island, NY 10312  FOR_SALE  2015.0         4
# 1      77 City Blvd, Staten Island, NY 10301  FOR_SALE  1176.0         3
# 2         240-05 147 Ave, Rosedale, NY 11422  FOR_SALE  2304.0         4
# 3          579 E 29th St, Brooklyn, NY 11210  FOR_SALE     NaN         4
# 4  182 Benedict Ave, Staten Island, NY 10314  FOR_SALE  2352.0         4
#
#   Bathrooms   Latitude  Longitude
# 0         2  40.541781 -74.196109
# 1         1  40.628757 -74.104166
# 2         2  40.657539 -73.743602
# 3         1  40.636665 -73.948744
# 4         5  40.622440 -74.128401

# %%
chicago_sold_extracted = pd.DataFrame(extracted_batches[3])
chicago_sold_extracted.head()
# Out:
#                 Data Source          ID  \
# 0  https://www.realtor.com/  4136891435
# 1  https://www.realtor.com/  3476436735
# 2  https://www.realtor.com/  4877937449
# 3  https://www.realtor.com/  4669261316
# 4  https://www.realtor.com/  4114846597
#
#                                            Post link   List date   Sold date  \
# 0  https://www.realtor.com/realestateandhomes-det...  2023-09-07  2024-07-03
# 1  https://www.realtor.com/realestateandhomes-det...  2024-04-05  2024-07-03
# 2  https://www.realtor.com/realestateandhomes-det...  2023-09-20  2024-07-03
# 3  https://www.realtor.com/realestateandhomes-det...  2023-08-09  2024-07-03
# 4  https://www.realtor.com/realestateandhomes-det...  2024-03-14  2024-07-03
#
#    Days until sold      Price                                 Address Status  \
# 0            300.0  1500000.0      1273 E 10th St, Brooklyn, NY 11230   SOLD
# 1             89.0   549999.0  274 Dixon Ave, Staten Island, NY 10303   SOLD
# 2            287.0   559000.0     132 Elm St, Staten Island, NY 10310   SOLD
# 3            329.0  1099000.0      1714 E 29th St, Brooklyn, NY 11229   SOLD
# 4            111.0   968000.0        47-44 189 St, Flushing, NY 11358   SOLD
#
#      Area  Bedrooms Bathrooms   Latitude  Longitude
# 0  2015.0       4.0       1.5  40.618168 -73.964649
# 1  1205.0       3.0       1.5  40.628432 -74.151338
# 2  1292.0       4.0         2  40.638510 -74.114339
# 3  1660.0       3.0       2.5  40.609290 -73.944877
# 4     NaN       3.0         2  40.749657 -73.790139

# %%
new_york_selling_extracted = pd.DataFrame(extracted_batches[0])
new_york_selling_extracted.head()
# Out:
#                 Data Source          ID  \
# 0  https://www.realtor.com/  7109976785
# 1  https://www.realtor.com/  9462841010
# 2  https://www.realtor.com/  8027933003
# 3  https://www.realtor.com/  8854936353
# 4  https://www.realtor.com/  7106444683
#
#                                            Post link   List date  \
# 0  https://www.realtor.com/realestateandhomes-det...  2024-04-18
# 1  https://www.realtor.com/realestateandhomes-det...  2024-06-03
# 2  https://www.realtor.com/realestateandhomes-det...  2024-07-03
# 3  https://www.realtor.com/realestateandhomes-det...  2024-07-04
# 4  https://www.realtor.com/realestateandhomes-det...  2024-07-04
#
#       Sold date Days until sold      Price  \
# 0  Not sold yet    Not sold yet   215000.0
# 1  Not sold yet    Not sold yet   340000.0
# 2  Not sold yet    Not sold yet    79000.0
# 3  Not sold yet    Not sold yet  1200000.0
# 4  Not sold yet    Not sold yet  1075000.0
#
#                                   Address    Status    Area  Bedrooms  \
# 0    9906 S Seeley Ave, Chicago, IL 60643  FOR_SALE  1567.0         3
# 1   650 N Ridgeway Ave, Chicago, IL 60624  FOR_SALE  1445.0         3
# 2    11549 S Church St, Chicago, IL 60643  FOR_SALE  1386.0         4
# 3    3015 N Racine Ave, Chicago, IL 60657  FOR_SALE  3100.0         4
# 4  1316 N Campbell Ave, Chicago, IL 60622  FOR_SALE  3976.0         3
#
#   Bathrooms   Latitude  Longitude
# 0         2  41.713489 -87.673732
# 1         2        NaN        NaN
# 2         2  41.683247 -87.669495
# 3         4  41.936740 -87.658509
# 4       3.5  41.905352 -87.689905

# %%
new_york_sold_extracted = pd.DataFrame(extracted_batches[1])
new_york_sold_extracted.head()
# Out:
#                 Data Source          ID  \
# 0  https://www.realtor.com/  7638203850
# 1  https://www.realtor.com/  7712196342
# 2  https://www.realtor.com/  9484646484
# 3  https://www.realtor.com/  7710814353
# 4  https://www.realtor.com/  7259996874
#
#                                            Post link   List date   Sold date  \
# 0  https://www.realtor.com/realestateandhomes-det...  2024-05-30  2024-07-03
# 1  https://www.realtor.com/realestateandhomes-det...  2024-05-06  2024-07-03
# 2  https://www.realtor.com/realestateandhomes-det...  2024-05-30  2024-07-03
# 3  https://www.realtor.com/realestateandhomes-det...  2024-01-13  2024-07-03
# 4  https://www.realtor.com/realestateandhomes-det...  2024-03-13  2024-07-03
#
#    Days until sold     Price                                   Address Status  \
# 0             34.0  250000.0     10330 S Whipple St, Chicago, IL 60655   SOLD
# 1             58.0  149999.0         455 W 126th Pl, Chicago, IL 60628   SOLD
# 2             34.0  950000.0  3915 N Monticello Ave, Chicago, IL 60618   SOLD
# 3            172.0  168900.0    9416 S Michigan Ave, Chicago, IL 60619   SOLD
# 4            112.0  155000.0    9425 S Eberhart Ave, Chicago, IL 60619   SOLD
#
#      Area  Bedrooms Bathrooms   Latitude  Longitude
# 0   926.0       2.0         1  41.705251 -87.698129
# 1   973.0       2.0         1  41.663994 -87.633883
# 2  3200.0       3.0       3.5  41.952424 -87.718648
# 3  1229.0       2.0      1.5+  41.723018 -87.621100
# 4  1674.0       4.0         3  41.722997 -87.611406

# %%
# for carefree data processing
chicago_selling_extracted = chicago_selling_extracted.dropna().drop_duplicates()
chicago_sold_extracted = chicago_sold_extracted.dropna().drop_duplicates()
new_york_selling_extracted = new_york_selling_extracted.dropna().drop_duplicates()
new_york_sold_extracted = new_york_sold_extracted.dropna().drop_duplicates()

# %%
chicago_selling_extracted.to_csv('chicago_realtor_selling.csv', index=False)
chicago_sold_extracted.to_csv('chicago_realtor_sold.csv', index=False)
new_york_selling_extracted.to_csv('new_york_realtor_selling.csv', index=False)
new_york_sold_extracted.to_csv('new_york_realtor_sold.csv', index=False)
